# %%
import redis 

client = redis.Redis('host.docker.internal', 6379, 0)

client.flushdb()
# Out:
# True

# %%
import json
import numpy as np
import threading
import time
from concurrent.futures import ThreadPoolExecutor
from pcomp.kafka_handlers import KafkaProducerHandler, KafkaConsumerHandler, KafkaConsumerHandlerNeuron
from pcomp.activation_functions import ACTIVATIONS, relu, softmax
from pcomp.redis_utils import RedisHandler
from pcomp.parser import parse_layer_coordinator_message, parse_layer_message
from pcomp.avro_utils import avro_serialize, avro_deserialize
from pcomp.neurons_accumulator import NeuronsAccumulator

# Kafka Configuration
KAFKA_BROKER = 'kafka:9092'

# %%
class Neuron(threading.Thread):
    def __init__(self, layer_id, neuron_id, weights, bias, activation, is_final_layer):
        threading.Thread.__init__(self)
        self.layer_id = layer_id
        self.layer_id_num = int(self.layer_id.replace("layer_", ""))
        self.neuron_id = neuron_id
        self.weights = np.array(weights)
        self.bias = np.array(bias)
        self.activation = activation
        self.activation_func = ACTIVATIONS.get(activation, relu)
        self.is_final_layer = is_final_layer
        self.producer = None
        self.executor = ThreadPoolExecutor(max_workers=4)
        

    def process_data(self, inputs):
        z = np.dot(inputs, self.weights) + self.bias
        return z if self.is_final_layer else self.activation_func(z)

    def process_and_send(self, image_id, input_data):
        z = np.dot(input_data, self.weights) + self.bias
        output = z if self.is_final_layer else self.activation_func(z)
        output_str = format(output, '.17g')
        msg = f"{self.neuron_id}|{image_id}|{output_str}"
        self.producer.send(msg)
        #self.producer.send(f'requests-responses', 'www.neuron.example')

    def run(self):
        # Instantiate Kafka consumer and producer inside the thread.
        consumer = KafkaConsumerHandlerNeuron(f'layer-{self.layer_id_num}', KAFKA_BROKER, group_id=f"{self.neuron_id}_{self.layer_id_num}_group")
        self.producer = KafkaProducerHandler(KAFKA_BROKER, f'layer-{self.layer_id_num}-complete')
        last_msg_time = time.time()
        while True:
            got_message = False
            for message in consumer.consume():
                got_message = True
                last_msg_time = time.time()
                message_dict = avro_deserialize(message.value())
                layer = message_dict["layer_id"]
                image_id = message_dict["image_id"]
                data_bytes = message_dict["data"]
                input_data = np.frombuffer(data_bytes, dtype=np.float64)
                if layer == self.layer_id:
                    self.executor.submit(self.process_and_send, image_id, input_data)
                    #self.process_and_send(image_id, input_data)
            if not got_message and (time.time() - last_msg_time > 10):
                consumer.commit()
                consumer.close()
                self.producer.close()
                break


class LayerCoordinator(threading.Thread):
    def __init__(self, layer_id, neuron_count, is_final_layer=False):
        threading.Thread.__init__(self)
        self.layer_id = layer_id
        self.layer_id_num = int(self.layer_id.replace("layer_", ""))
        self.neuron_count = neuron_count
        self.is_final_layer = is_final_layer
        self.accumulators = {}
        self.redis_handler = RedisHandler('host.docker.internal', 6379, 0)
        self.executor = ThreadPoolExecutor(max_workers=4)
        self.producer = None

    def run(self):
        consumer = KafkaConsumerHandler(f'layer-{self.layer_id_num}-complete', KAFKA_BROKER, group_id=f"{self.layer_id_num}_coord_group")
        self.producer = KafkaProducerHandler(KAFKA_BROKER, 'activate-layer')
        last_msg_time = time.time()
        while True:
            got_message = False
            for message in consumer.consume():
                got_message = True
                last_msg_time = time.time()
                #neuron_id, image_id, output_str = message.split('|')
                msg = parse_layer_coordinator_message(message)
                neuron_id = msg.neuron_id
                image_id = msg.image_id
                output = msg.output
                try:
                    acc = self.accumulators[image_id]
                except KeyError:
                    acc = self.accumulators[image_id] = NeuronsAccumulator(self.neuron_count)
                if acc.outputs[neuron_id] is None:
                    acc.outputs[neuron_id] = output
                    acc.completed += 1
                if acc.completed == self.neuron_count:
                    self.executor.submit(self.aggregate_neuron_outputs, image_id, acc.outputs.copy())
                    del self.accumulators[image_id]
            if not got_message and (time.time() - last_msg_time > 10):
                consumer.commit()
                consumer.close()
                self.producer.close()
                break

    def aggregate_neuron_outputs(self, image_id, local_outputs):
        outputs = np.array(local_outputs, dtype=np.float64)
        if not self.is_final_layer:
            self.redis_handler.set(f"streams:{image_id}:{self.layer_id_num}", outputs)
            self.activate_next_layer(image_id)
        else:
            prediction = int(np.argmax(outputs))
            self.redis_handler.hset('streams:predictions', image_id, prediction)
            self.redis_handler.delete_streams_keys(image_id)

    def activate_next_layer(self, image_id):
        next_layer = f'layer_{self.layer_id_num + 1}'
        self.producer.send(f"{next_layer}|{image_id}")
        #self.producer.send(f'requests-responses', 'www.layercoordinator.example')
            

class Layer(threading.Thread):
    def __init__(self, layer_id, neuron_count):
        threading.Thread.__init__(self)
        self.layer_id = layer_id
        self.neuron_count = neuron_count
        self.layer_id_num = int(self.layer_id.replace("layer_", ""))
        self.producer = None
        self.redis_handler = RedisHandler('host.docker.internal', 6379, 0)

    def fetch_input(self, image_id):
        key = f"streams:{image_id}:initial_data" if self.layer_id == 'layer_0' else f"streams:{image_id}:{self.layer_id_num - 1}"
        # Poll Redis until the data is available.
        while True:
            data = self.redis_handler.get(key)
            if data is not None:
                return data

    def activate_neurons(self, image_id):
        input_data = self.fetch_input(image_id).tobytes()
        message_dict = {
            "layer_id": self.layer_id,
            "image_id": image_id,
            "data": input_data
        }
        msg = avro_serialize(message_dict)
        self.producer.send_neuron(msg)

    def run(self):
        consumer = KafkaConsumerHandler('activate-layer', KAFKA_BROKER, group_id=f"{self.layer_id_num}_group")
        self.producer = KafkaProducerHandler(KAFKA_BROKER, f'layer-{self.layer_id_num}')
        last_msg_time = time.time()
        while True:
            got_message = False
            for message in consumer.consume():
                got_message = True
                last_msg_time = time.time()
                #layer, image_id_str = message.split('|')
                msg = parse_layer_message(message)
                layer = msg.layer
                image_id= msg.image_id
                if layer == self.layer_id:
                    #image_id = int(image_id_str)
                    self.activate_neurons(image_id)
            if not got_message and (time.time() - last_msg_time > 10):
                consumer.commit()
                consumer.close()
                self.producer.close()
                break

def store_initial_input_data(image_np, image_id):
    redis_handler = RedisHandler('host.docker.internal', 6379, 0)
    key = f"initial_data:{image_id}"
    redis_handler.set(key, image_np)
    print(f"📥 Initial input data stored in Redis.")

def activate_network(image_id):
    producer = KafkaProducerHandler(KAFKA_BROKER)
    producer.send('activate-layer', {'layer': 'layer_0', 'image_id': image_id}, 0)
    #self.producer.send(f'requests-responses', 'www.layer.example')
    print(f"🚀 Initial activation sent to activate-layer for layer_0 and image {image_id}")
    producer.close()

# Load network and dataset
data = json.load(open("node_based_model.json"))
#df = pd.read_csv('data/mnist.csv').head(10)

neurons = []
layers = []
coordinators = []

for layer_name, layer_info in data.items():
    neurons += [Neuron(layer_id=layer_name, neuron_id=i, weights=node['weights'], bias=node['biases'], activation=node['activation'], is_final_layer=(layer_name == list(data.keys())[-1])) for i, node in enumerate(layer_info['nodes'])]
    layers.append(Layer(layer_id=layer_name, neuron_count=len(layer_info['nodes'])))
    coordinators.append(LayerCoordinator(layer_id=layer_name, neuron_count=len(layer_info['nodes']), is_final_layer=(layer_name == list(data.keys())[-1])))

# Start all threads
for thread in neurons + layers + coordinators:
    thread.start()

print("Threads started")
# Out:
# Threads started
# %4|1743380742.119|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [101]: offset reset (at offset 97 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.119|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [2]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.119|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [3]: offset reset (at offset 93 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.119|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [7]: offset reset (at offset 142 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.119|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [10]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.119|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [20]: offset reset (at offset 108 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.119|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [101]: offset reset (at offset END (leader epoch -1), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.119|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [23]: offset reset (at offset 122 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.119|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [26]: offset reset (at offset 124 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.119|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [1]: offset reset (at offset 117 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.119|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [28]: offset reset (at offset 105 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.119|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [2]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.119|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [29]: offset reset (at offset 92 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.119|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [3]: offset reset (at offset 93 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.119|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [31]: offset reset (at offset 126 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.119|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [7]: offset reset (at offset 142 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.119|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [34]: offset reset (at offset 113 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.119|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [9]: offset reset (at offset 124 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.119|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [37]: offset reset (at offset 67 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.119|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [10]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.119|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [20]: offset reset (at offset 108 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.119|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [23]: offset reset (at offset 122 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.119|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [101]: offset reset (at offset 97 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [26]: offset reset (at offset 124 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [39]: offset reset (at offset 96 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [28]: offset reset (at offset 124 (leader epoch 0), broker 1) to offset 124 (leader epoch 0): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [1]: offset reset (at offset END (leader epoch -1), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [40]: offset reset (at offset 87 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [2]: offset reset (at offset END (leader epoch -1), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [29]: offset reset (at offset 92 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [3]: offset reset (at offset 93 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [43]: offset reset (at offset 87 (leader epoch 0), broker 1) to offset 91 (leader epoch 0): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [7]: offset reset (at offset 142 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [9]: offset reset (at offset 142 (leader epoch 0), broker 1) to offset 124 (leader epoch 0): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [10]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [20]: offset reset (at offset 108 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [31]: offset reset (at offset 126 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [23]: offset reset (at offset 122 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [34]: offset reset (at offset 113 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [44]: offset reset (at offset 78 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [37]: offset reset (at offset 67 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [26]: offset reset (at offset 124 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [39]: offset reset (at offset 96 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [28]: offset reset (at offset 105 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [40]: offset reset (at offset 87 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [29]: offset reset (at offset 92 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [43]: offset reset (at offset 91 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [31]: offset reset (at offset 126 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [34]: offset reset (at offset 113 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [44]: offset reset (at offset 78 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [37]: offset reset (at offset 67 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [39]: offset reset (at offset 96 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [46]: offset reset (at offset END (leader epoch -1), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [40]: offset reset (at offset 87 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [46]: offset reset (at offset 85 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [47]: offset reset (at offset 76 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [43]: offset reset (at offset 91 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [47]: offset reset (at offset END (leader epoch -1), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [44]: offset reset (at offset 78 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [46]: offset reset (at offset 85 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [47]: offset reset (at offset 76 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [48]: offset reset (at offset 97 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [48]: offset reset (at offset 97 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [52]: offset reset (at offset 67 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [54]: offset reset (at offset 92 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [59]: offset reset (at offset 108 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [67]: offset reset (at offset 101 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [73]: offset reset (at offset 112 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [48]: offset reset (at offset 76 (leader epoch 0), broker 1) to offset 97 (leader epoch 0): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [81]: offset reset (at offset 111 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [52]: offset reset (at offset 67 (leader epoch 0), broker 1) to offset 67 (leader epoch 0): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [52]: offset reset (at offset 67 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [54]: offset reset (at offset 92 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [54]: offset reset (at offset 92 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [88]: offset reset (at offset 96 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [59]: offset reset (at offset 108 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [67]: offset reset (at offset 101 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [73]: offset reset (at offset 112 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [81]: offset reset (at offset 111 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [88]: offset reset (at offset END (leader epoch -1), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [59]: offset reset (at offset 108 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [98]: offset reset (at offset 83 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [67]: offset reset (at offset 101 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [98]: offset reset (at offset 83 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [68]: offset reset (at offset 134 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [103]: offset reset (at offset 115 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [103]: offset reset (at offset 115 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [71]: offset reset (at offset 112 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [73]: offset reset (at offset 112 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [81]: offset reset (at offset 111 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [110]: offset reset (at offset 132 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [86]: offset reset (at offset END (leader epoch -1), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [116]: offset reset (at offset 86 (leader epoch 0), broker 1) to offset 86 (leader epoch 0): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [110]: offset reset (at offset 132 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [88]: offset reset (at offset 96 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-1| [thrd:main]: layer-0 [121]: offset reset (at offset 98 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [116]: offset reset (at offset 86 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-4| [thrd:main]: layer-0 [121]: offset reset (at offset 98 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [92]: offset reset (at offset 103 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [98]: offset reset (at offset 83 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [103]: offset reset (at offset 115 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [110]: offset reset (at offset 132 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [116]: offset reset (at offset 86 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [118]: offset reset (at offset 101 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.120|OFFSET|rdkafka#consumer-2| [thrd:main]: layer-0 [121]: offset reset (at offset 98 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [37]: offset reset (at offset 67 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [46]: offset reset (at offset 85 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [81]: offset reset (at offset 111 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [101]: offset reset (at offset 97 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [1]: offset reset (at offset 117 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [2]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [3]: offset reset (at offset 93 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [7]: offset reset (at offset 142 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [9]: offset reset (at offset 124 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [10]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [20]: offset reset (at offset 108 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [23]: offset reset (at offset 122 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [26]: offset reset (at offset 124 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [28]: offset reset (at offset 105 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [29]: offset reset (at offset 92 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [31]: offset reset (at offset 126 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [34]: offset reset (at offset 113 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [39]: offset reset (at offset 96 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [40]: offset reset (at offset 87 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [43]: offset reset (at offset 91 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [44]: offset reset (at offset 78 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [47]: offset reset (at offset 76 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [48]: offset reset (at offset 97 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [52]: offset reset (at offset 67 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [54]: offset reset (at offset 92 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [59]: offset reset (at offset 108 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [67]: offset reset (at offset 101 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [73]: offset reset (at offset 112 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [88]: offset reset (at offset 96 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [98]: offset reset (at offset 83 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [103]: offset reset (at offset 115 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [110]: offset reset (at offset 132 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [116]: offset reset (at offset 86 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.121|OFFSET|rdkafka#consumer-5| [thrd:main]: layer-0 [121]: offset reset (at offset 98 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-11| [thrd:main]: layer-0 [7]: offset reset (at offset 142 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-11| [thrd:main]: layer-0 [20]: offset reset (at offset 108 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-11| [thrd:main]: layer-0 [23]: offset reset (at offset 122 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-11| [thrd:main]: layer-0 [28]: offset reset (at offset 105 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-11| [thrd:main]: layer-0 [29]: offset reset (at offset 92 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [101]: offset reset (at offset 97 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [1]: offset reset (at offset 117 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [2]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [3]: offset reset (at offset 93 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-11| [thrd:main]: layer-0 [31]: offset reset (at offset 126 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-11| [thrd:main]: layer-0 [37]: offset reset (at offset 67 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-11| [thrd:main]: layer-0 [43]: offset reset (at offset 91 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [7]: offset reset (at offset 142 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [9]: offset reset (at offset 124 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [10]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [20]: offset reset (at offset 108 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [23]: offset reset (at offset 122 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [26]: offset reset (at offset 124 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-11| [thrd:main]: layer-0 [44]: offset reset (at offset 91 (leader epoch 0), broker 1) to offset 78 (leader epoch 0): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-11| [thrd:main]: layer-0 [46]: offset reset (at offset 85 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-11| [thrd:main]: layer-0 [47]: offset reset (at offset 76 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-11| [thrd:main]: layer-0 [52]: offset reset (at offset 67 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-11| [thrd:main]: layer-0 [54]: offset reset (at offset 92 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [28]: offset reset (at offset 105 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [29]: offset reset (at offset 92 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [31]: offset reset (at offset 126 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [34]: offset reset (at offset 113 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [37]: offset reset (at offset 67 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [39]: offset reset (at offset 96 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-11| [thrd:main]: layer-0 [59]: offset reset (at offset END (leader epoch -1), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [40]: offset reset (at offset 87 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [43]: offset reset (at offset 91 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-11| [thrd:main]: layer-0 [67]: offset reset (at offset END (leader epoch -1), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [44]: offset reset (at offset 78 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-11| [thrd:main]: layer-0 [68]: offset reset (at offset 134 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [46]: offset reset (at offset 85 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [47]: offset reset (at offset 76 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [48]: offset reset (at offset 97 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [52]: offset reset (at offset 67 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [54]: offset reset (at offset 92 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [59]: offset reset (at offset 108 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [67]: offset reset (at offset 101 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-11| [thrd:main]: layer-0 [71]: offset reset (at offset 112 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [73]: offset reset (at offset 112 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-11| [thrd:main]: layer-0 [73]: offset reset (at offset 112 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [81]: offset reset (at offset 111 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [88]: offset reset (at offset 96 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [98]: offset reset (at offset 83 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.207|OFFSET|rdkafka#consumer-9| [thrd:main]: layer-0 [103]: offset reset (at offset 115 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# ...
# %4|1743380742.774|OFFSET|rdkafka#consumer-258| [thrd:main]: layer-1 [1]: offset reset (at offset 1282 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.774|OFFSET|rdkafka#consumer-259| [thrd:main]: layer-1 [3]: offset reset (at offset END (leader epoch -1), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.774|OFFSET|rdkafka#consumer-258| [thrd:main]: layer-1 [2]: offset reset (at offset 1212 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.774|OFFSET|rdkafka#consumer-259| [thrd:main]: layer-1 [6]: offset reset (at offset 1206 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.779|OFFSET|rdkafka#consumer-262| [thrd:main]: layer-1 [1]: offset reset (at offset 1282 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.779|OFFSET|rdkafka#consumer-262| [thrd:main]: layer-1 [2]: offset reset (at offset 1212 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.779|OFFSET|rdkafka#consumer-262| [thrd:main]: layer-1 [3]: offset reset (at offset 1303 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.779|OFFSET|rdkafka#consumer-262| [thrd:main]: layer-1 [5]: offset reset (at offset 1142 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.779|OFFSET|rdkafka#consumer-262| [thrd:main]: layer-1 [6]: offset reset (at offset 1206 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.779|OFFSET|rdkafka#consumer-262| [thrd:main]: layer-1 [8]: offset reset (at offset 1173 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.783|OFFSET|rdkafka#consumer-265| [thrd:main]: layer-1 [5]: offset reset (at offset 1145 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.783|OFFSET|rdkafka#consumer-265| [thrd:main]: layer-1 [6]: offset reset (at offset 1206 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.783|OFFSET|rdkafka#consumer-265| [thrd:main]: layer-1 [8]: offset reset (at offset 1173 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.783|OFFSET|rdkafka#consumer-265| [thrd:main]: layer-1 [1]: offset reset (at offset 1282 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.783|OFFSET|rdkafka#consumer-265| [thrd:main]: layer-1 [2]: offset reset (at offset 1212 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.783|OFFSET|rdkafka#consumer-265| [thrd:main]: layer-1 [3]: offset reset (at offset 1303 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.787|OFFSET|rdkafka#consumer-266| [thrd:main]: layer-1 [1]: offset reset (at offset 1282 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.787|OFFSET|rdkafka#consumer-266| [thrd:main]: layer-1 [2]: offset reset (at offset 1212 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.787|OFFSET|rdkafka#consumer-266| [thrd:main]: layer-1 [3]: offset reset (at offset 1303 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.787|OFFSET|rdkafka#consumer-266| [thrd:main]: layer-1 [5]: offset reset (at offset 1145 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.787|OFFSET|rdkafka#consumer-266| [thrd:main]: layer-1 [6]: offset reset (at offset 1206 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.787|OFFSET|rdkafka#consumer-266| [thrd:main]: layer-1 [8]: offset reset (at offset 1173 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.800|OFFSET|rdkafka#consumer-269| [thrd:main]: layer-1 [1]: offset reset (at offset 1282 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.800|OFFSET|rdkafka#consumer-269| [thrd:main]: layer-1 [2]: offset reset (at offset 1212 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.800|OFFSET|rdkafka#consumer-269| [thrd:main]: layer-1 [3]: offset reset (at offset 1303 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.800|OFFSET|rdkafka#consumer-269| [thrd:main]: layer-1 [5]: offset reset (at offset 1145 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.800|OFFSET|rdkafka#consumer-269| [thrd:main]: layer-1 [6]: offset reset (at offset 1206 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.800|OFFSET|rdkafka#consumer-269| [thrd:main]: layer-1 [8]: offset reset (at offset 1173 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.812|OFFSET|rdkafka#consumer-272| [thrd:main]: layer-1 [1]: offset reset (at offset 1282 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.812|OFFSET|rdkafka#consumer-272| [thrd:main]: layer-1 [2]: offset reset (at offset 1212 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.812|OFFSET|rdkafka#consumer-272| [thrd:main]: layer-1 [3]: offset reset (at offset 1303 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.812|OFFSET|rdkafka#consumer-272| [thrd:main]: layer-1 [5]: offset reset (at offset 1142 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.812|OFFSET|rdkafka#consumer-272| [thrd:main]: layer-1 [6]: offset reset (at offset 1206 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.812|OFFSET|rdkafka#consumer-272| [thrd:main]: layer-1 [8]: offset reset (at offset 1173 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.814|OFFSET|rdkafka#consumer-271| [thrd:main]: layer-1 [1]: offset reset (at offset 1282 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.814|OFFSET|rdkafka#consumer-271| [thrd:main]: layer-1 [2]: offset reset (at offset 1212 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.814|OFFSET|rdkafka#consumer-271| [thrd:main]: layer-1 [3]: offset reset (at offset 1303 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.814|OFFSET|rdkafka#consumer-271| [thrd:main]: layer-1 [5]: offset reset (at offset 1145 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.814|OFFSET|rdkafka#consumer-271| [thrd:main]: layer-1 [6]: offset reset (at offset 1206 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.814|OFFSET|rdkafka#consumer-271| [thrd:main]: layer-1 [8]: offset reset (at offset 1173 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.816|OFFSET|rdkafka#consumer-274| [thrd:main]: layer-1 [1]: offset reset (at offset 1282 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.816|OFFSET|rdkafka#consumer-274| [thrd:main]: layer-1 [2]: offset reset (at offset 1212 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.816|OFFSET|rdkafka#consumer-274| [thrd:main]: layer-1 [3]: offset reset (at offset 1303 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.816|OFFSET|rdkafka#consumer-274| [thrd:main]: layer-1 [5]: offset reset (at offset 1145 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.816|OFFSET|rdkafka#consumer-274| [thrd:main]: layer-1 [6]: offset reset (at offset 1206 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.816|OFFSET|rdkafka#consumer-274| [thrd:main]: layer-1 [8]: offset reset (at offset 1173 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.817|OFFSET|rdkafka#consumer-282| [thrd:main]: layer-1-complete [0]: offset reset (at offset 23458 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.817|OFFSET|rdkafka#consumer-282| [thrd:main]: layer-1-complete [1]: offset reset (at offset 23682 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.817|OFFSET|rdkafka#consumer-282| [thrd:main]: layer-1-complete [2]: offset reset (at offset 23357 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.817|OFFSET|rdkafka#consumer-282| [thrd:main]: layer-1-complete [3]: offset reset (at offset 22992 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.817|OFFSET|rdkafka#consumer-282| [thrd:main]: layer-1-complete [4]: offset reset (at offset 23641 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.825|OFFSET|rdkafka#consumer-276| [thrd:main]: activate-layer [0]: offset reset (at offset 24052 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.825|OFFSET|rdkafka#consumer-276| [thrd:main]: activate-layer [1]: offset reset (at offset 5849 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.826|OFFSET|rdkafka#consumer-278| [thrd:main]: activate-layer [0]: offset reset (at offset 24052 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.826|OFFSET|rdkafka#consumer-278| [thrd:main]: activate-layer [1]: offset reset (at offset 5849 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.832|OFFSET|rdkafka#consumer-281| [thrd:main]: layer-0-complete [11]: offset reset (at offset 24990 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.832|OFFSET|rdkafka#consumer-281| [thrd:main]: layer-0-complete [13]: offset reset (at offset 25718 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.832|OFFSET|rdkafka#consumer-281| [thrd:main]: layer-0-complete [30]: offset reset (at offset 25336 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.832|OFFSET|rdkafka#consumer-281| [thrd:main]: layer-0-complete [50]: offset reset (at offset 25038 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.832|OFFSET|rdkafka#consumer-281| [thrd:main]: layer-0-complete [56]: offset reset (at offset 25788 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743380742.832|OFFSET|rdkafka#consumer-281| [thrd:main]: layer-0-complete [59]: offset reset (at offset 25707 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range

# %%
# Wait for all threads to complete
for thread in neurons + coordinators:
    thread.join()

print("Threads finished")
# Out:
# Threads finished

# %%
import redis

# Connect to Redis
r = RedisHandler('host.docker.internal', 6379, 0)

# Get hashes from Redis
images_label = r.hgetall('images_label')
predictions = r.hgetall('streams:predictions')

# Decode bytes to string
images_label = {k.decode(): v.decode() for k, v in images_label.items()}
predictions = {k.decode(): v.decode() for k, v in predictions.items()}

# Calculate accuracy
correct = 0
total = len(images_label)

for field, label_val in images_label.items():
    pred_val = predictions.get(field, None)
    if pred_val == label_val:
        correct += 1

accuracy = (correct / total) * 100 if total > 0 else 0

print(f'Accuracy: {accuracy:.2f}% ({correct}/{total})')
# Out:
# Accuracy: 96.20% (962/1000)
