# %%
import redis 

client = redis.Redis('host.docker.internal', 6379, 0)

client.flushdb()
# Out:
# True

# %%
import json
import numpy as np
import threading
import time
from concurrent.futures import ThreadPoolExecutor
from pcomp.kafka_handlers import KafkaProducerHandler, KafkaConsumerHandler, KafkaConsumerHandlerNeuron
from pcomp.activation_functions import ACTIVATIONS, relu, softmax
from pcomp.redis_utils import RedisHandler
from pcomp.parser import parse_layer_coordinator_message, parse_layer_message
from pcomp.avro_utils import avro_serialize, avro_deserialize
from pcomp.neurons_accumulator import NeuronsAccumulator

# Kafka Configuration
KAFKA_BROKER = 'kafka:9092'

# %%
class Neuron(threading.Thread):
    def __init__(self, layer_id, neuron_id, weights, bias, activation, is_final_layer):
        threading.Thread.__init__(self)
        self.layer_id = layer_id
        self.layer_id_num = int(self.layer_id.replace("layer_", ""))
        self.neuron_id = neuron_id
        self.weights = np.array(weights)
        self.bias = np.array(bias)
        self.activation = activation
        self.activation_func = ACTIVATIONS.get(activation, relu)
        self.is_final_layer = is_final_layer
        self.producer = None
        self.executor = ThreadPoolExecutor(max_workers=4)
        

    def process_data(self, inputs):
        z = np.dot(inputs, self.weights) + self.bias
        return z if self.is_final_layer else self.activation_func(z)

    def process_and_send(self, image_id, input_data):
        z = np.dot(input_data, self.weights) + self.bias
        output = z if self.is_final_layer else self.activation_func(z)
        output_str = format(output, '.17g')
        msg = f"{self.neuron_id}|{image_id}|{output_str}"
        self.producer.send(msg)
        #self.producer.send(f'requests-responses', 'www.neuron.example')

    def run(self):
        # Instantiate Kafka consumer and producer inside the thread.
        consumer = KafkaConsumerHandlerNeuron(f'layer-{self.layer_id_num}', KAFKA_BROKER, group_id=f"{self.neuron_id}_{self.layer_id_num}_group")
        self.producer = KafkaProducerHandler(KAFKA_BROKER, f'layer-{self.layer_id_num}-complete')
        last_msg_time = time.time()
        while True:
            got_message = False
            for message in consumer.consume():
                got_message = True
                last_msg_time = time.time()
                message_dict = avro_deserialize(message.value())
                layer = message_dict["layer_id"]
                image_id = message_dict["image_id"]
                data_bytes = message_dict["data"]
                input_data = np.frombuffer(data_bytes, dtype=np.float64)
                if layer == self.layer_id:
                    self.executor.submit(self.process_and_send, image_id, input_data)
                    #self.process_and_send(image_id, input_data)
            if not got_message and (time.time() - last_msg_time > 10):
                consumer.commit()
                consumer.close()
                self.producer.close()
                break


class LayerCoordinator(threading.Thread):
    def __init__(self, layer_id, neuron_count, is_final_layer=False):
        threading.Thread.__init__(self)
        self.layer_id = layer_id
        self.layer_id_num = int(self.layer_id.replace("layer_", ""))
        self.neuron_count = neuron_count
        self.is_final_layer = is_final_layer
        self.accumulators = {}
        self.redis_handler = RedisHandler('host.docker.internal', 6379, 0)
        self.executor = ThreadPoolExecutor(max_workers=4)
        self.producer = None

    def run(self):
        consumer = KafkaConsumerHandler(f'layer-{self.layer_id_num}-complete', KAFKA_BROKER, group_id=f"{self.layer_id_num}_coord_group")
        self.producer = KafkaProducerHandler(KAFKA_BROKER, 'activate-layer')
        last_msg_time = time.time()
        while True:
            got_message = False
            for message in consumer.consume():
                got_message = True
                last_msg_time = time.time()
                #neuron_id, image_id, output_str = message.split('|')
                msg = parse_layer_coordinator_message(message)
                neuron_id = msg.neuron_id
                image_id = msg.image_id
                output = msg.output
                try:
                    acc = self.accumulators[image_id]
                except KeyError:
                    acc = self.accumulators[image_id] = NeuronsAccumulator(self.neuron_count)
                if acc.outputs[neuron_id] is None:
                    acc.outputs[neuron_id] = output
                    acc.completed += 1
                if acc.completed == self.neuron_count:
                    self.executor.submit(self.aggregate_neuron_outputs, image_id, acc.outputs.copy())
                    del self.accumulators[image_id]
            if not got_message and (time.time() - last_msg_time > 10):
                consumer.commit()
                consumer.close()
                self.producer.close()
                break

    def aggregate_neuron_outputs(self, image_id, local_outputs):
        outputs = np.array(local_outputs, dtype=np.float64)
        if not self.is_final_layer:
            self.redis_handler.set(f"streams:{image_id}:{self.layer_id_num}", outputs)
            self.activate_next_layer(image_id)
        else:
            prediction = int(np.argmax(outputs))
            self.redis_handler.hset('streams:predictions', image_id, prediction)
            self.redis_handler.delete_streams_keys(image_id)

    def activate_next_layer(self, image_id):
        next_layer = f'layer_{self.layer_id_num + 1}'
        self.producer.send(f"{next_layer}|{image_id}")
        #self.producer.send(f'requests-responses', 'www.layercoordinator.example')
            

class Layer(threading.Thread):
    def __init__(self, layer_id, neuron_count):
        threading.Thread.__init__(self)
        self.layer_id = layer_id
        self.neuron_count = neuron_count
        self.layer_id_num = int(self.layer_id.replace("layer_", ""))
        self.producer = None
        self.redis_handler = RedisHandler('host.docker.internal', 6379, 0)

    def fetch_input(self, image_id):
        key = f"streams:{image_id}:initial_data" if self.layer_id == 'layer_0' else f"streams:{image_id}:{self.layer_id_num - 1}"
        # Poll Redis until the data is available.
        while True:
            data = self.redis_handler.get(key)
            if data is not None:
                return data

    def activate_neurons(self, image_id):
        input_data = self.fetch_input(image_id).tobytes()
        message_dict = {
            "layer_id": self.layer_id,
            "image_id": image_id,
            "data": input_data
        }
        msg = avro_serialize(message_dict)
        self.producer.send_neuron(msg)

    def run(self):
        consumer = KafkaConsumerHandler('activate-layer', KAFKA_BROKER, group_id=f"{self.layer_id_num}_group")
        self.producer = KafkaProducerHandler(KAFKA_BROKER, f'layer-{self.layer_id_num}')
        last_msg_time = time.time()
        while True:
            got_message = False
            for message in consumer.consume():
                got_message = True
                last_msg_time = time.time()
                #layer, image_id_str = message.split('|')
                msg = parse_layer_message(message)
                layer = msg.layer
                image_id= msg.image_id
                if layer == self.layer_id:
                    #image_id = int(image_id_str)
                    self.activate_neurons(image_id)
            if not got_message and (time.time() - last_msg_time > 10):
                consumer.commit()
                consumer.close()
                self.producer.close()
                break

def store_initial_input_data(image_np, image_id):
    redis_handler = RedisHandler('host.docker.internal', 6379, 0)
    key = f"initial_data:{image_id}"
    redis_handler.set(key, image_np)
    print(f"📥 Initial input data stored in Redis.")

def activate_network(image_id):
    producer = KafkaProducerHandler(KAFKA_BROKER)
    producer.send('activate-layer', {'layer': 'layer_0', 'image_id': image_id}, 0)
    #self.producer.send(f'requests-responses', 'www.layer.example')
    print(f"🚀 Initial activation sent to activate-layer for layer_0 and image {image_id}")
    producer.close()

# Load network and dataset
data = json.load(open("node_based_model.json"))
#df = pd.read_csv('data/mnist.csv').head(10)

neurons = []
layers = []
coordinators = []

for layer_name, layer_info in data.items():
    neurons += [Neuron(layer_id=layer_name, neuron_id=i, weights=node['weights'], bias=node['biases'], activation=node['activation'], is_final_layer=(layer_name == list(data.keys())[-1])) for i, node in enumerate(layer_info['nodes'])]
    layers.append(Layer(layer_id=layer_name, neuron_count=len(layer_info['nodes'])))
    coordinators.append(LayerCoordinator(layer_id=layer_name, neuron_count=len(layer_info['nodes']), is_final_layer=(layer_name == list(data.keys())[-1])))

# Start all threads
for thread in neurons + layers + coordinators:
    thread.start()

print("Threads started")
# Out:
# Threads started
# %4|1743465892.399|OFFSET|rdkafka#consumer-285| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.399|OFFSET|rdkafka#consumer-285| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.399|OFFSET|rdkafka#consumer-285| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.399|OFFSET|rdkafka#consumer-285| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.399|OFFSET|rdkafka#consumer-285| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.399|OFFSET|rdkafka#consumer-285| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.399|OFFSET|rdkafka#consumer-285| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.401|OFFSET|rdkafka#consumer-287| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.401|OFFSET|rdkafka#consumer-287| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.401|OFFSET|rdkafka#consumer-287| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.401|OFFSET|rdkafka#consumer-287| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.401|OFFSET|rdkafka#consumer-287| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.401|OFFSET|rdkafka#consumer-287| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.401|OFFSET|rdkafka#consumer-287| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.404|OFFSET|rdkafka#consumer-289| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.404|OFFSET|rdkafka#consumer-289| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.404|OFFSET|rdkafka#consumer-289| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.404|OFFSET|rdkafka#consumer-289| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.404|OFFSET|rdkafka#consumer-289| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.404|OFFSET|rdkafka#consumer-289| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.404|OFFSET|rdkafka#consumer-289| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.407|OFFSET|rdkafka#consumer-291| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.407|OFFSET|rdkafka#consumer-291| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.407|OFFSET|rdkafka#consumer-291| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.407|OFFSET|rdkafka#consumer-291| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.407|OFFSET|rdkafka#consumer-291| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.407|OFFSET|rdkafka#consumer-291| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.407|OFFSET|rdkafka#consumer-291| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.409|OFFSET|rdkafka#consumer-292| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.409|OFFSET|rdkafka#consumer-292| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.409|OFFSET|rdkafka#consumer-292| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.409|OFFSET|rdkafka#consumer-292| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.409|OFFSET|rdkafka#consumer-292| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.409|OFFSET|rdkafka#consumer-292| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.409|OFFSET|rdkafka#consumer-292| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.410|OFFSET|rdkafka#consumer-293| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.410|OFFSET|rdkafka#consumer-293| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.410|OFFSET|rdkafka#consumer-293| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.410|OFFSET|rdkafka#consumer-293| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.410|OFFSET|rdkafka#consumer-293| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.410|OFFSET|rdkafka#consumer-293| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.410|OFFSET|rdkafka#consumer-293| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.418|OFFSET|rdkafka#consumer-296| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.418|OFFSET|rdkafka#consumer-296| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.418|OFFSET|rdkafka#consumer-296| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.418|OFFSET|rdkafka#consumer-296| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.418|OFFSET|rdkafka#consumer-296| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.418|OFFSET|rdkafka#consumer-296| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.418|OFFSET|rdkafka#consumer-296| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.422|OFFSET|rdkafka#consumer-298| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.422|OFFSET|rdkafka#consumer-298| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.422|OFFSET|rdkafka#consumer-298| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.422|OFFSET|rdkafka#consumer-298| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.422|OFFSET|rdkafka#consumer-298| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.422|OFFSET|rdkafka#consumer-298| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.422|OFFSET|rdkafka#consumer-298| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.425|OFFSET|rdkafka#consumer-301| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.425|OFFSET|rdkafka#consumer-301| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.425|OFFSET|rdkafka#consumer-301| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.425|OFFSET|rdkafka#consumer-301| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.425|OFFSET|rdkafka#consumer-301| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.425|OFFSET|rdkafka#consumer-301| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.425|OFFSET|rdkafka#consumer-301| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.428|OFFSET|rdkafka#consumer-303| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.428|OFFSET|rdkafka#consumer-303| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.428|OFFSET|rdkafka#consumer-303| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.428|OFFSET|rdkafka#consumer-303| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.428|OFFSET|rdkafka#consumer-303| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.428|OFFSET|rdkafka#consumer-303| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.428|OFFSET|rdkafka#consumer-303| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.434|OFFSET|rdkafka#consumer-304| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.434|OFFSET|rdkafka#consumer-304| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.434|OFFSET|rdkafka#consumer-304| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.434|OFFSET|rdkafka#consumer-304| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.434|OFFSET|rdkafka#consumer-304| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.434|OFFSET|rdkafka#consumer-304| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.434|OFFSET|rdkafka#consumer-304| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.435|OFFSET|rdkafka#consumer-306| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.435|OFFSET|rdkafka#consumer-306| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.435|OFFSET|rdkafka#consumer-306| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.435|OFFSET|rdkafka#consumer-306| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.435|OFFSET|rdkafka#consumer-306| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.435|OFFSET|rdkafka#consumer-306| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.435|OFFSET|rdkafka#consumer-306| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.450|OFFSET|rdkafka#consumer-307| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.450|OFFSET|rdkafka#consumer-307| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.450|OFFSET|rdkafka#consumer-307| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.450|OFFSET|rdkafka#consumer-307| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.450|OFFSET|rdkafka#consumer-307| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.450|OFFSET|rdkafka#consumer-307| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.450|OFFSET|rdkafka#consumer-307| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.450|OFFSET|rdkafka#consumer-310| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.450|OFFSET|rdkafka#consumer-310| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.450|OFFSET|rdkafka#consumer-310| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.450|OFFSET|rdkafka#consumer-310| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.450|OFFSET|rdkafka#consumer-310| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.450|OFFSET|rdkafka#consumer-310| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.450|OFFSET|rdkafka#consumer-310| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.454|OFFSET|rdkafka#consumer-316| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.454|OFFSET|rdkafka#consumer-316| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.454|OFFSET|rdkafka#consumer-316| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.454|OFFSET|rdkafka#consumer-316| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.454|OFFSET|rdkafka#consumer-316| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.454|OFFSET|rdkafka#consumer-316| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.454|OFFSET|rdkafka#consumer-316| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.455|OFFSET|rdkafka#consumer-313| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.455|OFFSET|rdkafka#consumer-313| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.455|OFFSET|rdkafka#consumer-313| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.455|OFFSET|rdkafka#consumer-313| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.455|OFFSET|rdkafka#consumer-313| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.455|OFFSET|rdkafka#consumer-313| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.455|OFFSET|rdkafka#consumer-313| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.458|OFFSET|rdkafka#consumer-314| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.458|OFFSET|rdkafka#consumer-314| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.458|OFFSET|rdkafka#consumer-314| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.458|OFFSET|rdkafka#consumer-314| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.458|OFFSET|rdkafka#consumer-314| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.458|OFFSET|rdkafka#consumer-314| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.458|OFFSET|rdkafka#consumer-314| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.472|OFFSET|rdkafka#consumer-322| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.472|OFFSET|rdkafka#consumer-322| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.472|OFFSET|rdkafka#consumer-322| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.472|OFFSET|rdkafka#consumer-322| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.472|OFFSET|rdkafka#consumer-322| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.472|OFFSET|rdkafka#consumer-322| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.472|OFFSET|rdkafka#consumer-322| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.474|OFFSET|rdkafka#consumer-318| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.474|OFFSET|rdkafka#consumer-318| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.474|OFFSET|rdkafka#consumer-318| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.474|OFFSET|rdkafka#consumer-318| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.474|OFFSET|rdkafka#consumer-318| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.474|OFFSET|rdkafka#consumer-318| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.474|OFFSET|rdkafka#consumer-318| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.475|OFFSET|rdkafka#consumer-325| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.475|OFFSET|rdkafka#consumer-325| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.475|OFFSET|rdkafka#consumer-325| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.475|OFFSET|rdkafka#consumer-325| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.475|OFFSET|rdkafka#consumer-325| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.475|OFFSET|rdkafka#consumer-325| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.475|OFFSET|rdkafka#consumer-325| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.482|OFFSET|rdkafka#consumer-323| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.482|OFFSET|rdkafka#consumer-323| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.482|OFFSET|rdkafka#consumer-323| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.482|OFFSET|rdkafka#consumer-323| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.482|OFFSET|rdkafka#consumer-323| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.482|OFFSET|rdkafka#consumer-323| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.482|OFFSET|rdkafka#consumer-323| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.482|OFFSET|rdkafka#consumer-320| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.482|OFFSET|rdkafka#consumer-320| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.482|OFFSET|rdkafka#consumer-320| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.482|OFFSET|rdkafka#consumer-320| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.482|OFFSET|rdkafka#consumer-320| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.482|OFFSET|rdkafka#consumer-320| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.482|OFFSET|rdkafka#consumer-320| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.484|OFFSET|rdkafka#consumer-326| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.484|OFFSET|rdkafka#consumer-326| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.484|OFFSET|rdkafka#consumer-326| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.484|OFFSET|rdkafka#consumer-326| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.484|OFFSET|rdkafka#consumer-326| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.484|OFFSET|rdkafka#consumer-326| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.484|OFFSET|rdkafka#consumer-326| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.485|OFFSET|rdkafka#consumer-330| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.485|OFFSET|rdkafka#consumer-330| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.485|OFFSET|rdkafka#consumer-330| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.485|OFFSET|rdkafka#consumer-330| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.485|OFFSET|rdkafka#consumer-330| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.485|OFFSET|rdkafka#consumer-330| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.485|OFFSET|rdkafka#consumer-330| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.486|OFFSET|rdkafka#consumer-332| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.487|OFFSET|rdkafka#consumer-332| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.487|OFFSET|rdkafka#consumer-332| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.487|OFFSET|rdkafka#consumer-332| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.487|OFFSET|rdkafka#consumer-332| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.487|OFFSET|rdkafka#consumer-332| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.487|OFFSET|rdkafka#consumer-332| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.489|OFFSET|rdkafka#consumer-334| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.489|OFFSET|rdkafka#consumer-334| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.489|OFFSET|rdkafka#consumer-334| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.489|OFFSET|rdkafka#consumer-334| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.489|OFFSET|rdkafka#consumer-334| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.489|OFFSET|rdkafka#consumer-334| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.489|OFFSET|rdkafka#consumer-334| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.490|OFFSET|rdkafka#consumer-336| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.490|OFFSET|rdkafka#consumer-336| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.490|OFFSET|rdkafka#consumer-336| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.490|OFFSET|rdkafka#consumer-336| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.490|OFFSET|rdkafka#consumer-336| [thrd:main]: layer-0 [67]: offset reset (at offset 102 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# ...
# %4|1743465892.759|OFFSET|rdkafka#consumer-533| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.759|OFFSET|rdkafka#consumer-423| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.759|OFFSET|rdkafka#consumer-533| [thrd:main]: layer-0 [67]: offset reset (at offset END (leader epoch -1), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.759|OFFSET|rdkafka#consumer-535| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.759|OFFSET|rdkafka#consumer-423| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.759|OFFSET|rdkafka#consumer-533| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.759|OFFSET|rdkafka#consumer-535| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.759|OFFSET|rdkafka#consumer-533| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.725|OFFSET|rdkafka#consumer-429| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.759|OFFSET|rdkafka#consumer-429| [thrd:main]: layer-0 [67]: offset reset (at offset 106 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.759|OFFSET|rdkafka#consumer-429| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.759|OFFSET|rdkafka#consumer-429| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.759|OFFSET|rdkafka#consumer-471| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset 55 (leader epoch 0): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.697|OFFSET|rdkafka#consumer-438| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.759|OFFSET|rdkafka#consumer-438| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.759|OFFSET|rdkafka#consumer-438| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.759|OFFSET|rdkafka#consumer-438| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.759|OFFSET|rdkafka#consumer-438| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.759|OFFSET|rdkafka#consumer-438| [thrd:main]: layer-0 [67]: offset reset (at offset 106 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.759|OFFSET|rdkafka#consumer-438| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.755|OFFSET|rdkafka#consumer-424| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.760|OFFSET|rdkafka#consumer-424| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.760|OFFSET|rdkafka#consumer-424| [thrd:main]: layer-0 [67]: offset reset (at offset 106 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.760|OFFSET|rdkafka#consumer-424| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.760|OFFSET|rdkafka#consumer-424| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.761|OFFSET|rdkafka#consumer-506| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.761|OFFSET|rdkafka#consumer-506| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.761|OFFSET|rdkafka#consumer-506| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.761|OFFSET|rdkafka#consumer-506| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.761|OFFSET|rdkafka#consumer-506| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.761|OFFSET|rdkafka#consumer-506| [thrd:main]: layer-0 [67]: offset reset (at offset 106 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.761|OFFSET|rdkafka#consumer-506| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.755|OFFSET|rdkafka#consumer-450| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.761|OFFSET|rdkafka#consumer-450| [thrd:main]: layer-0 [67]: offset reset (at offset 106 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.761|OFFSET|rdkafka#consumer-450| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.761|OFFSET|rdkafka#consumer-450| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.762|OFFSET|rdkafka#consumer-499| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.762|OFFSET|rdkafka#consumer-499| [thrd:main]: layer-0 [67]: offset reset (at offset 106 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.762|OFFSET|rdkafka#consumer-499| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.762|OFFSET|rdkafka#consumer-499| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.762|OFFSET|rdkafka#consumer-499| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.762|OFFSET|rdkafka#consumer-499| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.762|OFFSET|rdkafka#consumer-499| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.763|OFFSET|rdkafka#consumer-548| [thrd:main]: layer-1 [5]: offset reset (at offset 962 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.763|OFFSET|rdkafka#consumer-548| [thrd:main]: layer-1 [9]: offset reset (at offset 786 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.763|OFFSET|rdkafka#consumer-548| [thrd:main]: layer-1 [2]: offset reset (at offset 832 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.763|OFFSET|rdkafka#consumer-548| [thrd:main]: layer-1 [3]: offset reset (at offset 671 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.763|OFFSET|rdkafka#consumer-548| [thrd:main]: layer-1 [7]: offset reset (at offset 811 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.764|OFFSET|rdkafka#consumer-524| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.764|OFFSET|rdkafka#consumer-524| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.764|OFFSET|rdkafka#consumer-524| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.764|OFFSET|rdkafka#consumer-524| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.764|OFFSET|rdkafka#consumer-524| [thrd:main]: layer-0 [67]: offset reset (at offset 106 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.764|OFFSET|rdkafka#consumer-524| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.764|OFFSET|rdkafka#consumer-524| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.767|OFFSET|rdkafka#consumer-511| [thrd:main]: layer-0 [6]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.767|OFFSET|rdkafka#consumer-511| [thrd:main]: layer-0 [12]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.767|OFFSET|rdkafka#consumer-511| [thrd:main]: layer-0 [24]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.767|OFFSET|rdkafka#consumer-511| [thrd:main]: layer-0 [63]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.767|OFFSET|rdkafka#consumer-511| [thrd:main]: layer-0 [67]: offset reset (at offset 106 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.767|OFFSET|rdkafka#consumer-511| [thrd:main]: layer-0 [76]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1743465892.767|OFFSET|rdkafka#consumer-511| [thrd:main]: layer-0 [87]: offset reset (at offset 55 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range

# %%
# Wait for all threads to complete
for thread in neurons + coordinators:
    thread.join()

print("Threads finished")
# Out:
# Threads finished

# %%
import redis

# Connect to Redis
r = RedisHandler('host.docker.internal', 6379, 0)

# Get hashes from Redis
images_label = r.hgetall('streams:images_label')
predictions = r.hgetall('streams:predictions')

# Decode bytes to string
images_label = {k.decode(): v.decode() for k, v in images_label.items()}
predictions = {k.decode(): v.decode() for k, v in predictions.items()}

# Calculate accuracy
correct = 0
total = len(images_label)

for field, label_val in images_label.items():
    pred_val = predictions.get(field, None)
    if pred_val == label_val:
        correct += 1

accuracy = (correct / total) * 100 if total > 0 else 0

print(f'Accuracy: {accuracy:.2f}% ({correct}/{total})')
# Out:
# Accuracy: 96.20% (962/1000)
