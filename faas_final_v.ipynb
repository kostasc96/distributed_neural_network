# %%
import redis 

client = redis.Redis('host.docker.internal', 6379, 0)

client.flushdb()
# Out:
# True

# %%
import json
import numpy as np
import threading
import time
from concurrent.futures import ThreadPoolExecutor
from pcomp.kafka_handlers import KafkaProducerHandler, KafkaConsumerHandler, KafkaConsumerHandlerNeuron
from pcomp.activation_functions import ACTIVATIONS, relu, softmax
from pcomp.redis_utils import RedisHandler
from pcomp.parser import parse_layer_coordinator_message, parse_layer_message
from pcomp.avro_utils import avro_serialize, avro_deserialize
from pcomp.neurons_accumulator import NeuronsAccumulator

# Kafka Configuration
KAFKA_BROKER = 'kafka:29092'

# %%
class Neuron(threading.Thread):
    def __init__(self, layer_id, neuron_id, weights, bias, activation, is_final_layer):
        threading.Thread.__init__(self)
        self.layer_id = layer_id
        self.layer_id_num = int(self.layer_id.replace("layer_", ""))
        self.neuron_id = neuron_id
        self.weights = np.array(weights)
        self.bias = np.array(bias)
        self.activation = activation
        self.activation_func = ACTIVATIONS.get(activation, relu)
        self.is_final_layer = is_final_layer
        self.redis_handler = RedisHandler('host.docker.internal', 6379, 0, 8)
        self.producer = None
        self.accumulators = {}
        self.neurons_rec = 128 if self.layer_id_num == 1 else 10
        

    def fetch_input_0(self, image_id):
        key = f"streams:{image_id}:initial_data"
        return np.frombuffer(self.redis_handler.get(key), dtype=np.float64)

    def process_0(self, message):
        image_id_str = message
        image_id = image_id_str
        input_data = self.fetch_input_0(image_id)
        z = np.dot(input_data, self.weights) + self.bias
        output = z if self.is_final_layer else self.activation_func(z)
        msg = f"{self.neuron_id}|{image_id}|{format(output, '.17g')}"
        self.producer.send(msg)

    def process(self, message):
        msg = parse_layer_coordinator_message(message)
        image_id = msg.image_id
        neuron_id = msg.neuron_id
        output = msg.output
        try:
            acc = self.accumulators[image_id]
        except KeyError as e:
            acc = self.accumulators[image_id] = NeuronsAccumulator(self.neurons_rec)
        if acc.outputs[neuron_id] is None:
            acc.outputs[neuron_id] = output
            acc.completed += 1
        if acc.completed == self.neurons_rec:
            input_data = np.array(acc.outputs, dtype=np.float64)
            z = np.dot(input_data, self.weights) + self.bias
            output = z if self.is_final_layer else self.activation_func(z)
            msg = f"{self.neuron_id}|{image_id}|{format(output, '.17g')}"
            self.producer.send(msg)
            del self.accumulators[image_id]

    def run(self):
        # Instantiate Kafka consumer and producer inside the thread.
        consumer = KafkaConsumerHandler(f'layer-{self.layer_id_num}', KAFKA_BROKER, group_id=f"{self.neuron_id}_{self.layer_id_num}_group")
        self.producer = KafkaProducerHandler(KAFKA_BROKER, f'layer-{self.layer_id_num + 1}') if not self.is_final_layer else KafkaProducerHandler(KAFKA_BROKER, 'predictions')
        last_msg_time = time.time()
        while True:
            got_message = False
            for message in consumer.consume():
                got_message = True
                last_msg_time = time.time()
                if self.layer_id_num == 0:
                    self.process_0(message)
                else:
                    self.process(message)
            if not got_message and (time.time() - last_msg_time > 10):
                consumer.commit()
                consumer.close()
                self.producer.close()
                break


class OutputLayer(threading.Thread):
    def __init__(self):
        threading.Thread.__init__(self)
        self.neurons_rec = 10
        self.redis_handler = RedisHandler('host.docker.internal', 6379, 0, 50)
        self.producer = None
        self.accumulators = {}

    def run(self):
        consumer = KafkaConsumerHandler('predictions', KAFKA_BROKER, group_id=f"predictions_coord_group")
        last_msg_time = time.time()
        while True:
            got_message = False
            for message in consumer.consume():
                got_message = True
                last_msg_time = time.time()
                msg = parse_layer_coordinator_message(message)
                neuron_id = msg.neuron_id
                image_id = msg.image_id
                output = msg.output
                try:
                    acc = self.accumulators[image_id]
                except KeyError:
                    acc = self.accumulators[image_id] = NeuronsAccumulator(self.neurons_rec)
                if acc.outputs[neuron_id] is None:
                    acc.outputs[neuron_id] = output
                    acc.completed += 1
                print(acc.completed)
                if acc.completed == self.neurons_rec:
                    self.aggregate_neuron_outputs(image_id, acc.outputs)
                    del self.accumulators[image_id]
            if not got_message and (time.time() - last_msg_time > 10):
                consumer.commit()
                consumer.close()
                if self.producer:
                    self.producer.close()
                break

    def aggregate_neuron_outputs(self, image_id, local_outputs):
        outputs = np.array(local_outputs, dtype=np.float64)
        prediction = int(np.argmax(outputs))
        self.redis_handler.hset('streams:predictions', image_id, prediction)
        self.redis_handler.delete_streams_keys(image_id)

# Load network and dataset
data = json.load(open("node_based_model.json"))
#df = pd.read_csv('data/mnist.csv').head(10)

neurons = []
output_layer = OutputLayer()

for layer_name, layer_info in data.items():
    neurons += [Neuron(layer_id=layer_name, neuron_id=i, weights=node['weights'], bias=node['biases'], activation=node['activation'], is_final_layer=(layer_name == list(data.keys())[-1])) for i, node in enumerate(layer_info['nodes'])]

# Start all threads
for thread in neurons:
    thread.start()

output_layer.start()

print("Threads started")
# Out:
# Threads started
# %4|1744102746.784|OFFSET|rdkafka#consumer-275| [thrd:main]: predictions [5]: offset reset (at offset 1 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102746.784|OFFSET|rdkafka#consumer-275| [thrd:main]: predictions [8]: offset reset (at offset 4 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.042|OFFSET|rdkafka#consumer-1671| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.043|OFFSET|rdkafka#consumer-1671| [thrd:main]: layer-0 [9]: offset reset (at offset 95 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.055|OFFSET|rdkafka#consumer-1676| [thrd:main]: layer-0 [46]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.055|OFFSET|rdkafka#consumer-1676| [thrd:main]: layer-0 [9]: offset reset (at offset 80 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.055|OFFSET|rdkafka#consumer-1676| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.065|OFFSET|rdkafka#consumer-1681| [thrd:main]: layer-0 [9]: offset reset (at offset 92 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.065|OFFSET|rdkafka#consumer-1681| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.083|OFFSET|rdkafka#consumer-1686| [thrd:main]: layer-0 [46]: offset reset (at offset 63 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.083|OFFSET|rdkafka#consumer-1686| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.083|OFFSET|rdkafka#consumer-1687| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.083|OFFSET|rdkafka#consumer-1687| [thrd:main]: layer-0 [9]: offset reset (at offset 96 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.088|OFFSET|rdkafka#consumer-1692| [thrd:main]: layer-0 [46]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.088|OFFSET|rdkafka#consumer-1692| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.088|OFFSET|rdkafka#consumer-1692| [thrd:main]: layer-0 [9]: offset reset (at offset 71 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.092|OFFSET|rdkafka#consumer-1694| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.092|OFFSET|rdkafka#consumer-1694| [thrd:main]: layer-0 [9]: offset reset (at offset 31 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.095|OFFSET|rdkafka#consumer-1699| [thrd:main]: layer-0 [46]: offset reset (at offset 56 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.096|OFFSET|rdkafka#consumer-1699| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.097|OFFSET|rdkafka#consumer-1701| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.097|OFFSET|rdkafka#consumer-1701| [thrd:main]: layer-0 [46]: offset reset (at offset 64 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.098|OFFSET|rdkafka#consumer-1701| [thrd:main]: layer-0 [9]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.114|OFFSET|rdkafka#consumer-1714| [thrd:main]: layer-0 [9]: offset reset (at offset 72 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.114|OFFSET|rdkafka#consumer-1714| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.114|OFFSET|rdkafka#consumer-1714| [thrd:main]: layer-0 [46]: offset reset (at offset 59 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.117|OFFSET|rdkafka#consumer-1718| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.117|OFFSET|rdkafka#consumer-1718| [thrd:main]: layer-0 [21]: offset reset (at offset 5 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.122|OFFSET|rdkafka#consumer-1721| [thrd:main]: layer-0 [46]: offset reset (at offset 64 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.122|OFFSET|rdkafka#consumer-1721| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.122|OFFSET|rdkafka#consumer-1721| [thrd:main]: layer-0 [9]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.122|OFFSET|rdkafka#consumer-1721| [thrd:main]: layer-0 [21]: offset reset (at offset 4 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.126|OFFSET|rdkafka#consumer-1726| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.132|OFFSET|rdkafka#consumer-1731| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.141|OFFSET|rdkafka#consumer-1663| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.141|OFFSET|rdkafka#consumer-1665| [thrd:main]: layer-0 [9]: offset reset (at offset 56 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.141|OFFSET|rdkafka#consumer-1665| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.151|OFFSET|rdkafka#consumer-1675| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.151|OFFSET|rdkafka#consumer-1675| [thrd:main]: layer-0 [9]: offset reset (at offset 8 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.151|OFFSET|rdkafka#consumer-1675| [thrd:main]: layer-0 [21]: offset reset (at offset 7 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.153|OFFSET|rdkafka#consumer-1748| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.157|OFFSET|rdkafka#consumer-1669| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.163|OFFSET|rdkafka#consumer-1754| [thrd:main]: layer-0 [46]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.163|OFFSET|rdkafka#consumer-1754| [thrd:main]: layer-0 [9]: offset reset (at offset 92 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.176|OFFSET|rdkafka#consumer-1678| [thrd:main]: layer-0 [9]: offset reset (at offset 80 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.176|OFFSET|rdkafka#consumer-1678| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.187|OFFSET|rdkafka#consumer-1682| [thrd:main]: layer-0 [9]: offset reset (at offset 26 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.187|OFFSET|rdkafka#consumer-1682| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.188|OFFSET|rdkafka#consumer-1691| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.192|OFFSET|rdkafka#consumer-1684| [thrd:main]: layer-0 [9]: offset reset (at offset 65 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.192|OFFSET|rdkafka#consumer-1684| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.193|OFFSET|rdkafka#consumer-1696| [thrd:main]: layer-0 [9]: offset reset (at offset 77 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.199|OFFSET|rdkafka#consumer-1702| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.201|OFFSET|rdkafka#consumer-1704| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.205|OFFSET|rdkafka#consumer-1709| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.205|OFFSET|rdkafka#consumer-1709| [thrd:main]: layer-0 [9]: offset reset (at offset 54 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.209|OFFSET|rdkafka#consumer-1713| [thrd:main]: layer-0 [9]: offset reset (at offset 15 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.209|OFFSET|rdkafka#consumer-1713| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.215|OFFSET|rdkafka#consumer-1710| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.221|OFFSET|rdkafka#consumer-1722| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.221|OFFSET|rdkafka#consumer-1722| [thrd:main]: layer-0 [9]: offset reset (at offset 84 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.231|OFFSET|rdkafka#consumer-1814| [thrd:main]: layer-0 [9]: offset reset (at offset 76 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.231|OFFSET|rdkafka#consumer-1814| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.232|OFFSET|rdkafka#consumer-1716| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.232|OFFSET|rdkafka#consumer-1716| [thrd:main]: layer-0 [9]: offset reset (at offset 76 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.237|OFFSET|rdkafka#consumer-1706| [thrd:main]: layer-0 [9]: offset reset (at offset 98 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.238|OFFSET|rdkafka#consumer-1724| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.238|OFFSET|rdkafka#consumer-1724| [thrd:main]: layer-0 [21]: offset reset (at offset 8 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.241|OFFSET|rdkafka#consumer-1740| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.241|OFFSET|rdkafka#consumer-1740| [thrd:main]: layer-0 [9]: offset reset (at offset 90 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.245|OFFSET|rdkafka#consumer-1742| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.245|OFFSET|rdkafka#consumer-1742| [thrd:main]: layer-0 [9]: offset reset (at offset 92 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.247|OFFSET|rdkafka#consumer-1737| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.247|OFFSET|rdkafka#consumer-1728| [thrd:main]: layer-0 [9]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.249|OFFSET|rdkafka#consumer-1746| [thrd:main]: layer-0 [46]: offset reset (at offset 53 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.249|OFFSET|rdkafka#consumer-1746| [thrd:main]: layer-0 [9]: offset reset (at offset 59 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.249|OFFSET|rdkafka#consumer-1830| [thrd:main]: layer-0 [9]: offset reset (at offset 51 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.249|OFFSET|rdkafka#consumer-1830| [thrd:main]: layer-0 [21]: offset reset (at offset 2 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.249|OFFSET|rdkafka#consumer-1830| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.249|OFFSET|rdkafka#consumer-1830| [thrd:main]: layer-0 [46]: offset reset (at offset 80 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.253|OFFSET|rdkafka#consumer-1739| [thrd:main]: layer-0 [46]: offset reset (at offset 36 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.253|OFFSET|rdkafka#consumer-1739| [thrd:main]: layer-0 [9]: offset reset (at offset 53 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.256|OFFSET|rdkafka#consumer-1744| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.256|OFFSET|rdkafka#consumer-1751| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.257|OFFSET|rdkafka#consumer-1751| [thrd:main]: layer-0 [9]: offset reset (at offset 79 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.259|OFFSET|rdkafka#consumer-1734| [thrd:main]: layer-0 [9]: offset reset (at offset 96 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.260|OFFSET|rdkafka#consumer-1753| [thrd:main]: layer-0 [9]: offset reset (at offset 20 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.261|OFFSET|rdkafka#consumer-1756| [thrd:main]: layer-0 [9]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.265|OFFSET|rdkafka#consumer-1758| [thrd:main]: layer-0 [9]: offset reset (at offset 60 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.276|OFFSET|rdkafka#consumer-1732| [thrd:main]: layer-0 [9]: offset reset (at offset 67 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.278|OFFSET|rdkafka#consumer-1770| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.278|OFFSET|rdkafka#consumer-1770| [thrd:main]: layer-0 [9]: offset reset (at offset 92 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.281|OFFSET|rdkafka#consumer-1773| [thrd:main]: layer-0 [9]: offset reset (at offset 52 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.283|OFFSET|rdkafka#consumer-1774| [thrd:main]: layer-0 [46]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.283|OFFSET|rdkafka#consumer-1774| [thrd:main]: layer-0 [9]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.287|OFFSET|rdkafka#consumer-1767| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.287|OFFSET|rdkafka#consumer-1767| [thrd:main]: layer-0 [9]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.287|OFFSET|rdkafka#consumer-1767| [thrd:main]: layer-0 [21]: offset reset (at offset 8 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.288|OFFSET|rdkafka#consumer-1768| [thrd:main]: layer-0 [9]: offset reset (at offset 8 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.288|OFFSET|rdkafka#consumer-1768| [thrd:main]: layer-0 [46]: offset reset (at offset 40 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.289|OFFSET|rdkafka#consumer-1781| [thrd:main]: layer-0 [46]: offset reset (at offset 49 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.292|OFFSET|rdkafka#consumer-1760| [thrd:main]: layer-0 [9]: offset reset (at offset 83 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.298|OFFSET|rdkafka#consumer-1788| [thrd:main]: layer-0 [46]: offset reset (at offset 45 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.298|OFFSET|rdkafka#consumer-1788| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.307|OFFSET|rdkafka#consumer-1880| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.311|OFFSET|rdkafka#consumer-1762| [thrd:main]: layer-0 [46]: offset reset (at offset 56 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.311|OFFSET|rdkafka#consumer-1762| [thrd:main]: layer-0 [9]: offset reset (at offset 80 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.313|OFFSET|rdkafka#consumer-1800| [thrd:main]: layer-0 [9]: offset reset (at offset 96 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.313|OFFSET|rdkafka#consumer-1886| [thrd:main]: layer-0 [46]: offset reset (at offset 82 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.315|OFFSET|rdkafka#consumer-1886| [thrd:main]: layer-0 [21]: offset reset (at offset 2 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.320|OFFSET|rdkafka#consumer-1891| [thrd:main]: layer-0 [46]: offset reset (at offset 76 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.322|OFFSET|rdkafka#consumer-1784| [thrd:main]: layer-0 [9]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.324|OFFSET|rdkafka#consumer-1894| [thrd:main]: layer-0 [46]: offset reset (at offset 20 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.324|OFFSET|rdkafka#consumer-1894| [thrd:main]: layer-0 [9]: offset reset (at offset 67 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.324|OFFSET|rdkafka#consumer-1804| [thrd:main]: layer-0 [9]: offset reset (at offset 56 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.326|OFFSET|rdkafka#consumer-1809| [thrd:main]: layer-0 [46]: offset reset (at offset 59 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.326|OFFSET|rdkafka#consumer-1809| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.327|OFFSET|rdkafka#consumer-1898| [thrd:main]: layer-0 [46]: offset reset (at offset 71 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.328|OFFSET|rdkafka#consumer-1778| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.332|OFFSET|rdkafka#consumer-1816| [thrd:main]: layer-0 [9]: offset reset (at offset 65 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.334|OFFSET|rdkafka#consumer-1782| [thrd:main]: layer-0 [46]: offset reset (at offset 64 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.334|OFFSET|rdkafka#consumer-1782| [thrd:main]: layer-0 [9]: offset reset (at offset 31 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.338|OFFSET|rdkafka#consumer-1807| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.338|OFFSET|rdkafka#consumer-1807| [thrd:main]: layer-0 [9]: offset reset (at offset 64 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.338|OFFSET|rdkafka#consumer-1905| [thrd:main]: layer-0 [46]: offset reset (at offset 54 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.340|OFFSET|rdkafka#consumer-1908| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.341|OFFSET|rdkafka#consumer-1812| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.341|OFFSET|rdkafka#consumer-1812| [thrd:main]: layer-0 [46]: offset reset (at offset 44 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.343|OFFSET|rdkafka#consumer-1795| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.347|OFFSET|rdkafka#consumer-1828| [thrd:main]: layer-0 [46]: offset reset (at offset 58 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.347|OFFSET|rdkafka#consumer-1828| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.352|OFFSET|rdkafka#consumer-1833| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.354|OFFSET|rdkafka#consumer-1796| [thrd:main]: layer-0 [46]: offset reset (at offset 41 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.354|OFFSET|rdkafka#consumer-1796| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.355|OFFSET|rdkafka#consumer-1834| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.355|OFFSET|rdkafka#consumer-1834| [thrd:main]: layer-0 [9]: offset reset (at offset 51 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.355|OFFSET|rdkafka#consumer-1834| [thrd:main]: layer-0 [21]: offset reset (at offset 3 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.356|OFFSET|rdkafka#consumer-1798| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.356|OFFSET|rdkafka#consumer-1798| [thrd:main]: layer-0 [9]: offset reset (at offset 9 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.356|OFFSET|rdkafka#consumer-1798| [thrd:main]: layer-0 [21]: offset reset (at offset 8 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.362|OFFSET|rdkafka#consumer-1841| [thrd:main]: layer-0 [9]: offset reset (at offset 38 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.363|OFFSET|rdkafka#consumer-1839| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.363|OFFSET|rdkafka#consumer-1839| [thrd:main]: layer-0 [9]: offset reset (at offset 83 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.366|OFFSET|rdkafka#consumer-1820| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.368|OFFSET|rdkafka#consumer-1806| [thrd:main]: layer-0 [9]: offset reset (at offset 67 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.369|OFFSET|rdkafka#consumer-1846| [thrd:main]: layer-0 [9]: offset reset (at offset 11 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.369|OFFSET|rdkafka#consumer-1846| [thrd:main]: layer-0 [21]: offset reset (at offset 8 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.369|OFFSET|rdkafka#consumer-1846| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.369|OFFSET|rdkafka#consumer-1846| [thrd:main]: layer-0 [46]: offset reset (at offset 76 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.374|OFFSET|rdkafka#consumer-1836| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.375|OFFSET|rdkafka#consumer-1851| [thrd:main]: layer-0 [9]: offset reset (at offset 72 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.382|OFFSET|rdkafka#consumer-1822| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.383|OFFSET|rdkafka#consumer-1858| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.383|OFFSET|rdkafka#consumer-1858| [thrd:main]: layer-0 [9]: offset reset (at offset 33 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.390|OFFSET|rdkafka#consumer-1861| [thrd:main]: layer-0 [46]: offset reset (at offset 68 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.390|OFFSET|rdkafka#consumer-1861| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.390|OFFSET|rdkafka#consumer-1861| [thrd:main]: layer-0 [9]: offset reset (at offset 60 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.393|OFFSET|rdkafka#consumer-1869| [thrd:main]: layer-0 [46]: offset reset (at offset 74 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.393|OFFSET|rdkafka#consumer-1869| [thrd:main]: layer-0 [9]: offset reset (at offset 72 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.396|OFFSET|rdkafka#consumer-1874| [thrd:main]: layer-0 [46]: offset reset (at offset 48 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.396|OFFSET|rdkafka#consumer-1872| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.403|OFFSET|rdkafka#consumer-1844| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.405|OFFSET|rdkafka#consumer-1865| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.409|OFFSET|rdkafka#consumer-1881| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.409|OFFSET|rdkafka#consumer-1848| [thrd:main]: layer-0 [9]: offset reset (at offset 76 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.415|OFFSET|rdkafka#consumer-1877| [thrd:main]: layer-0 [38]: offset reset (at offset 10 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.422|OFFSET|rdkafka#consumer-1862| [thrd:main]: layer-0 [9]: offset reset (at offset 37 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.422|OFFSET|rdkafka#consumer-1893| [thrd:main]: layer-0 [9]: offset reset (at offset 41 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.432|OFFSET|rdkafka#consumer-1902| [thrd:main]: layer-0 [9]: offset reset (at offset 92 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.449|OFFSET|rdkafka#consumer-1901| [thrd:main]: layer-0 [9]: offset reset (at offset 78 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.465|OFFSET|rdkafka#consumer-1915| [thrd:main]: layer-0 [9]: offset reset (at offset 88 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.473|OFFSET|rdkafka#consumer-1896| [thrd:main]: layer-0 [9]: offset reset (at offset 81 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102748.485|OFFSET|rdkafka#consumer-1906| [thrd:main]: layer-0 [9]: offset reset (at offset 97 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# 1
# 2
# 3
# %4|1744102800.832|OFFSET|rdkafka#consumer-275| [thrd:main]: predictions [5]: offset reset (at offset 1 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
# %4|1744102800.832|OFFSET|rdkafka#consumer-275| [thrd:main]: predictions [8]: offset reset (at offset 4 (leader epoch 0), broker 1) to offset END (leader epoch -1): fetch failed due to requested offset not available on the broker: Broker: Offset out of range
