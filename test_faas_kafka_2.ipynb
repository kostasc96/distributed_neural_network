# %%
import json
import numpy as np
from torchvision import datasets, transforms
from kafka import KafkaProducer, KafkaConsumer
import redis
import time

# Redis setup
redis_client = redis.Redis(host='host.docker.internal', port=6379, db=0)

# Activation functions
def relu(x):
    return np.maximum(0, x)

def softmax(x):
    e_x = np.exp(x - np.max(x))  # Stability trick
    return e_x / e_x.sum()

ACTIVATIONS = {
    "relu": relu,
    "softmax": softmax
}

class Neuron:
    def __init__(self, layer_id, neuron_id, weights, bias, activation, is_final_layer=False):
        self.layer_id = layer_id
        self.neuron_id = neuron_id
        self.weights = np.array(weights)
        self.bias = np.array(bias)
        self.activation_func = None if is_final_layer else ACTIVATIONS.get(activation, relu)
        self.is_final_layer = is_final_layer

    def forward(self, inputs):
        """Wait for activation message from Kafka before processing"""
        topic = f'layer-{self.layer_id[-1]}'
        consumer = KafkaConsumer(topic,
                                 bootstrap_servers='kafka:9092',
                                 value_deserializer=lambda m: json.loads(m.decode('utf-8')),
                                 auto_offset_reset='earliest',
                                 enable_auto_commit=True)

        print(f"🕒 Neuron {self.neuron_id} in {self.layer_id} waiting for activation on topic {topic}...")

        timeout_counter = 0
        for message in consumer:
            print(f"✅ Neuron {self.neuron_id} received message: {message.value}")
            if 'layer' in message.value and message.value['layer'] == self.layer_id:
                print(f"🚀 Neuron {self.neuron_id} in {self.layer_id} activated!")
                break

            timeout_counter += 1
            if timeout_counter > 10:
                print(f"⚠️ Timeout: No activation received for Neuron {self.neuron_id} in {self.layer_id}")
                break

        consumer.close()

        z = np.dot(inputs, self.weights) + self.bias
        return z if self.is_final_layer else self.activation_func(z)

class Layer:
    def __init__(self, layer_id, neurons, is_final_layer=False):
        self.layer_id = layer_id
        self.neurons = neurons
        self.is_final_layer = is_final_layer

    def forward(self, input_data):
        """Trigger neuron activations via Kafka"""
        producer = KafkaProducer(bootstrap_servers='kafka:9092',
                                 value_serializer=lambda v: json.dumps(v).encode('utf-8'),
                                 retries=5, request_timeout_ms=10000)
    
        topic = f'layer-{self.layer_id[-1]}'
        activation_message = {'layer': self.layer_id}
    
        print(f"📤 Layer {self.layer_id} sending activation message to topic {topic}...")
    
        try:
            future = producer.send(topic, activation_message)
            result = future.get(timeout=10)
            print(f"✅ Kafka message sent to {topic}")
        except Exception as e:
            print(f"❌ Kafka send failed: {e}")
    
        producer.flush()
        producer.close()
    
        outputs = np.array([neuron.forward(input_data) for neuron in self.neurons])
        if self.is_final_layer:
            outputs = softmax(outputs)
    
        redis_client.set(self.layer_id, outputs.astype(np.float32).tobytes())
        return outputs

# Load JSON file
def load_network(filename):
    with open(filename, 'r') as f:
        return json.load(f)

# Build network
def build_network(json_data):
    layers = []
    sorted_layers = sorted(json_data.keys(), key=lambda x: int(x.split('_')[-1]))
    for i, layer_name in enumerate(sorted_layers):
        layer_info = json_data[layer_name]
        neurons = [
            Neuron(
                layer_id=layer_name,
                neuron_id=idx,
                weights=np.array(node['weights']),
                bias=np.array(node['biases']),
                activation=node['activation'],
                is_final_layer=(i == len(sorted_layers) - 1)
            )
            for idx, node in enumerate(layer_info['nodes'])
        ]
        layers.append(Layer(layer_id=layer_name, neurons=neurons, is_final_layer=(i == len(sorted_layers) - 1)))
    return layers

# Forward pass for single image
def forward_pass(layers, input_data):
    producer = KafkaProducer(bootstrap_servers='kafka:9092',
                             value_serializer=lambda v: json.dumps(v).encode('utf-8'))
    print("🔥 Sending initial activation message to layer-0...")
    producer.send('layer-0', {'layer': 'layer-0'})
    producer.flush()
    producer.close()
    
    for layer in layers:
        input_data = layer.forward(input_data)
    redis_client.set('results', json.dumps(int(np.argmax(input_data))))
    return int(np.argmax(input_data))

# Load network
data = load_network("node_based_model.json")
network = build_network(data)

# Load MNIST dataset
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])
mnist_test = datasets.MNIST(root="./data", train=False, transform=transform, download=True)

# Test first 10 images one by one
correct_predictions = 0
for i in range(10):
    image, label = mnist_test[i]
    image_np = image.view(-1).numpy()
    redis_client.delete('results')
    prediction = forward_pass(network, image_np)

    print(f"Image {i} Prediction: {prediction}, Label: {label}")
    if prediction == label:
        correct_predictions += 1

accuracy = correct_predictions / 10
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# 🔥 Sending initial activation message to layer-0...
# 📤 Layer layer_0 sending activation message to topic layer-0...
# ✅ Kafka message sent to layer-0
# 🕒 Neuron 0 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 0 received message: {'layer': 'layer_0'}
# 🚀 Neuron 0 in layer_0 activated!
# 🕒 Neuron 1 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 1 received message: {'layer': 'layer-0'}
# ✅ Neuron 1 received message: {'layer': 'layer_0'}
# 🚀 Neuron 1 in layer_0 activated!
# 🕒 Neuron 2 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 2 received message: {'layer': 'layer_0'}
# 🚀 Neuron 2 in layer_0 activated!
# 🕒 Neuron 3 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 3 received message: {'layer': 'layer_0'}
# 🚀 Neuron 3 in layer_0 activated!
# 🕒 Neuron 4 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 4 received message: {'layer': 'layer_0'}
# 🚀 Neuron 4 in layer_0 activated!
# 🕒 Neuron 5 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 5 received message: {'layer': 'layer_0'}
# 🚀 Neuron 5 in layer_0 activated!
# 🕒 Neuron 6 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 6 received message: {'layer': 'layer-0'}
# ✅ Neuron 6 received message: {'layer': 'layer_0'}
# 🚀 Neuron 6 in layer_0 activated!
# 🕒 Neuron 7 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 7 received message: {'layer': 'layer-0'}
# ✅ Neuron 7 received message: {'layer': 'layer_0'}
# 🚀 Neuron 7 in layer_0 activated!
# 🕒 Neuron 8 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 8 received message: {'layer': 'layer_0'}
# 🚀 Neuron 8 in layer_0 activated!
# 🕒 Neuron 9 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 9 received message: {'layer': 'layer_0'}
# 🚀 Neuron 9 in layer_0 activated!
# 🕒 Neuron 10 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 10 received message: {'layer': 'layer-0'}
# ✅ Neuron 10 received message: {'layer': 'layer_0'}
# 🚀 Neuron 10 in layer_0 activated!
# 🕒 Neuron 11 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 11 received message: {'layer': 'layer-0'}
# ✅ Neuron 11 received message: {'layer': 'layer_0'}
# 🚀 Neuron 11 in layer_0 activated!
# 🕒 Neuron 12 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 12 received message: {'layer': 'layer-0'}
# ✅ Neuron 12 received message: {'layer': 'layer_0'}
# 🚀 Neuron 12 in layer_0 activated!
# 🕒 Neuron 13 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 13 received message: {'layer': 'layer-0'}
# ✅ Neuron 13 received message: {'layer': 'layer_0'}
# 🚀 Neuron 13 in layer_0 activated!
# 🕒 Neuron 14 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 14 received message: {'layer': 'layer-0'}
# ✅ Neuron 14 received message: {'layer': 'layer_0'}
# 🚀 Neuron 14 in layer_0 activated!
# 🕒 Neuron 15 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 15 received message: {'layer': 'layer_0'}
# 🚀 Neuron 15 in layer_0 activated!
# 🕒 Neuron 16 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 16 received message: {'layer': 'layer-0'}
# ✅ Neuron 16 received message: {'layer': 'layer_0'}
# 🚀 Neuron 16 in layer_0 activated!
# 🕒 Neuron 17 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 17 received message: {'layer': 'layer-0'}
# ✅ Neuron 17 received message: {'layer': 'layer_0'}
# 🚀 Neuron 17 in layer_0 activated!
# 🕒 Neuron 18 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 18 received message: {'layer': 'layer-0'}
# ✅ Neuron 18 received message: {'layer': 'layer_0'}
# 🚀 Neuron 18 in layer_0 activated!
# 🕒 Neuron 19 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 19 received message: {'layer': 'layer-0'}
# ✅ Neuron 19 received message: {'layer': 'layer_0'}
# 🚀 Neuron 19 in layer_0 activated!
# 🕒 Neuron 20 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 20 received message: {'layer': 'layer-0'}
# ✅ Neuron 20 received message: {'layer': 'layer_0'}
# 🚀 Neuron 20 in layer_0 activated!
# 🕒 Neuron 21 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 21 received message: {'layer': 'layer_0'}
# 🚀 Neuron 21 in layer_0 activated!
# 🕒 Neuron 22 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 22 received message: {'layer': 'layer_0'}
# 🚀 Neuron 22 in layer_0 activated!
# 🕒 Neuron 23 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 23 received message: {'layer': 'layer-0'}
# ✅ Neuron 23 received message: {'layer': 'layer_0'}
# 🚀 Neuron 23 in layer_0 activated!
# 🕒 Neuron 24 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 24 received message: {'layer': 'layer-0'}
# ✅ Neuron 24 received message: {'layer': 'layer_0'}
# 🚀 Neuron 24 in layer_0 activated!
# 🕒 Neuron 25 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 25 received message: {'layer': 'layer_0'}
# 🚀 Neuron 25 in layer_0 activated!
# 🕒 Neuron 26 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 26 received message: {'layer': 'layer_0'}
# 🚀 Neuron 26 in layer_0 activated!
# 🕒 Neuron 27 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 27 received message: {'layer': 'layer_0'}
# 🚀 Neuron 27 in layer_0 activated!
# 🕒 Neuron 28 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 28 received message: {'layer': 'layer-0'}
# ✅ Neuron 28 received message: {'layer': 'layer_0'}
# 🚀 Neuron 28 in layer_0 activated!
# 🕒 Neuron 29 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 29 received message: {'layer': 'layer-0'}
# ✅ Neuron 29 received message: {'layer': 'layer_0'}
# 🚀 Neuron 29 in layer_0 activated!
# 🕒 Neuron 30 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 30 received message: {'layer': 'layer_0'}
# 🚀 Neuron 30 in layer_0 activated!
# 🕒 Neuron 31 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 31 received message: {'layer': 'layer-0'}
# ✅ Neuron 31 received message: {'layer': 'layer_0'}
# 🚀 Neuron 31 in layer_0 activated!
# 🕒 Neuron 32 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 32 received message: {'layer': 'layer-0'}
# ✅ Neuron 32 received message: {'layer': 'layer_0'}
# 🚀 Neuron 32 in layer_0 activated!
# 🕒 Neuron 33 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 33 received message: {'layer': 'layer-0'}
# ✅ Neuron 33 received message: {'layer': 'layer_0'}
# 🚀 Neuron 33 in layer_0 activated!
# 🕒 Neuron 34 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 34 received message: {'layer': 'layer-0'}
# ✅ Neuron 34 received message: {'layer': 'layer_0'}
# 🚀 Neuron 34 in layer_0 activated!
# 🕒 Neuron 35 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 35 received message: {'layer': 'layer-0'}
# ✅ Neuron 35 received message: {'layer': 'layer_0'}
# 🚀 Neuron 35 in layer_0 activated!
# 🕒 Neuron 36 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 36 received message: {'layer': 'layer-0'}
# ✅ Neuron 36 received message: {'layer': 'layer_0'}
# 🚀 Neuron 36 in layer_0 activated!
# 🕒 Neuron 37 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 37 received message: {'layer': 'layer_0'}
# 🚀 Neuron 37 in layer_0 activated!
# 🕒 Neuron 38 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 38 received message: {'layer': 'layer-0'}
# ✅ Neuron 38 received message: {'layer': 'layer_0'}
# 🚀 Neuron 38 in layer_0 activated!
# 🕒 Neuron 39 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 39 received message: {'layer': 'layer-0'}
# ✅ Neuron 39 received message: {'layer': 'layer_0'}
# 🚀 Neuron 39 in layer_0 activated!
# 🕒 Neuron 40 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 40 received message: {'layer': 'layer_0'}
# 🚀 Neuron 40 in layer_0 activated!
# 🕒 Neuron 41 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 41 received message: {'layer': 'layer-0'}
# ✅ Neuron 41 received message: {'layer': 'layer_0'}
# 🚀 Neuron 41 in layer_0 activated!
# 🕒 Neuron 42 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 42 received message: {'layer': 'layer_0'}
# 🚀 Neuron 42 in layer_0 activated!
# 🕒 Neuron 43 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 43 received message: {'layer': 'layer_0'}
# 🚀 Neuron 43 in layer_0 activated!
# 🕒 Neuron 44 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 44 received message: {'layer': 'layer-0'}
# ✅ Neuron 44 received message: {'layer': 'layer_0'}
# 🚀 Neuron 44 in layer_0 activated!
# 🕒 Neuron 45 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 45 received message: {'layer': 'layer_0'}
# 🚀 Neuron 45 in layer_0 activated!
# 🕒 Neuron 46 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 46 received message: {'layer': 'layer_0'}
# 🚀 Neuron 46 in layer_0 activated!
# 🕒 Neuron 47 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 47 received message: {'layer': 'layer-0'}
# ✅ Neuron 47 received message: {'layer': 'layer_0'}
# 🚀 Neuron 47 in layer_0 activated!
# 🕒 Neuron 48 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 48 received message: {'layer': 'layer-0'}
# ✅ Neuron 48 received message: {'layer': 'layer_0'}
# 🚀 Neuron 48 in layer_0 activated!
# 🕒 Neuron 49 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 49 received message: {'layer': 'layer_0'}
# 🚀 Neuron 49 in layer_0 activated!
# 🕒 Neuron 50 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 50 received message: {'layer': 'layer_0'}
# 🚀 Neuron 50 in layer_0 activated!
# 🕒 Neuron 51 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 51 received message: {'layer': 'layer_0'}
# 🚀 Neuron 51 in layer_0 activated!
# 🕒 Neuron 52 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 52 received message: {'layer': 'layer-0'}
# ✅ Neuron 52 received message: {'layer': 'layer_0'}
# 🚀 Neuron 52 in layer_0 activated!
# 🕒 Neuron 53 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 53 received message: {'layer': 'layer_0'}
# 🚀 Neuron 53 in layer_0 activated!
# 🕒 Neuron 54 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 54 received message: {'layer': 'layer_0'}
# 🚀 Neuron 54 in layer_0 activated!
# 🕒 Neuron 55 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 55 received message: {'layer': 'layer-0'}
# ✅ Neuron 55 received message: {'layer': 'layer_0'}
# 🚀 Neuron 55 in layer_0 activated!
# 🕒 Neuron 56 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 56 received message: {'layer': 'layer_0'}
# 🚀 Neuron 56 in layer_0 activated!
# 🕒 Neuron 57 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 57 received message: {'layer': 'layer_0'}
# 🚀 Neuron 57 in layer_0 activated!
# 🕒 Neuron 58 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 58 received message: {'layer': 'layer_0'}
# 🚀 Neuron 58 in layer_0 activated!
# 🕒 Neuron 59 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 59 received message: {'layer': 'layer_0'}
# 🚀 Neuron 59 in layer_0 activated!
# 🕒 Neuron 60 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 60 received message: {'layer': 'layer_0'}
# 🚀 Neuron 60 in layer_0 activated!
# 🕒 Neuron 61 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 61 received message: {'layer': 'layer-0'}
# ✅ Neuron 61 received message: {'layer': 'layer_0'}
# 🚀 Neuron 61 in layer_0 activated!
# 🕒 Neuron 62 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 62 received message: {'layer': 'layer-0'}
# ✅ Neuron 62 received message: {'layer': 'layer_0'}
# 🚀 Neuron 62 in layer_0 activated!
# 🕒 Neuron 63 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 63 received message: {'layer': 'layer-0'}
# ✅ Neuron 63 received message: {'layer': 'layer_0'}
# 🚀 Neuron 63 in layer_0 activated!
# 🕒 Neuron 64 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 64 received message: {'layer': 'layer_0'}
# 🚀 Neuron 64 in layer_0 activated!
# 🕒 Neuron 65 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 65 received message: {'layer': 'layer_0'}
# 🚀 Neuron 65 in layer_0 activated!
# 🕒 Neuron 66 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 66 received message: {'layer': 'layer_0'}
# 🚀 Neuron 66 in layer_0 activated!
# 🕒 Neuron 67 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 67 received message: {'layer': 'layer_0'}
# 🚀 Neuron 67 in layer_0 activated!
# 🕒 Neuron 68 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 68 received message: {'layer': 'layer_0'}
# 🚀 Neuron 68 in layer_0 activated!
# 🕒 Neuron 69 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 69 received message: {'layer': 'layer_0'}
# 🚀 Neuron 69 in layer_0 activated!
# 🕒 Neuron 70 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 70 received message: {'layer': 'layer_0'}
# 🚀 Neuron 70 in layer_0 activated!
# 🕒 Neuron 71 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 71 received message: {'layer': 'layer_0'}
# 🚀 Neuron 71 in layer_0 activated!
# 🕒 Neuron 72 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 72 received message: {'layer': 'layer_0'}
# 🚀 Neuron 72 in layer_0 activated!
# 🕒 Neuron 73 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 73 received message: {'layer': 'layer_0'}
# 🚀 Neuron 73 in layer_0 activated!
# 🕒 Neuron 74 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 74 received message: {'layer': 'layer-0'}
# ✅ Neuron 74 received message: {'layer': 'layer_0'}
# 🚀 Neuron 74 in layer_0 activated!
# 🕒 Neuron 75 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 75 received message: {'layer': 'layer-0'}
# ✅ Neuron 75 received message: {'layer': 'layer_0'}
# 🚀 Neuron 75 in layer_0 activated!
# 🕒 Neuron 76 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 76 received message: {'layer': 'layer-0'}
# ✅ Neuron 76 received message: {'layer': 'layer_0'}
# 🚀 Neuron 76 in layer_0 activated!
# 🕒 Neuron 77 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 77 received message: {'layer': 'layer_0'}
# 🚀 Neuron 77 in layer_0 activated!
# 🕒 Neuron 78 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 78 received message: {'layer': 'layer-0'}
# ✅ Neuron 78 received message: {'layer': 'layer_0'}
# 🚀 Neuron 78 in layer_0 activated!
# 🕒 Neuron 79 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 79 received message: {'layer': 'layer_0'}
# 🚀 Neuron 79 in layer_0 activated!
# 🕒 Neuron 80 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 80 received message: {'layer': 'layer-0'}
# ✅ Neuron 80 received message: {'layer': 'layer_0'}
# 🚀 Neuron 80 in layer_0 activated!
# 🕒 Neuron 81 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 81 received message: {'layer': 'layer_0'}
# 🚀 Neuron 81 in layer_0 activated!
# 🕒 Neuron 82 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 82 received message: {'layer': 'layer_0'}
# 🚀 Neuron 82 in layer_0 activated!
# 🕒 Neuron 83 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 83 received message: {'layer': 'layer_0'}
# 🚀 Neuron 83 in layer_0 activated!
# 🕒 Neuron 84 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 84 received message: {'layer': 'layer_0'}
# 🚀 Neuron 84 in layer_0 activated!
# 🕒 Neuron 85 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 85 received message: {'layer': 'layer-0'}
# ✅ Neuron 85 received message: {'layer': 'layer_0'}
# 🚀 Neuron 85 in layer_0 activated!
# 🕒 Neuron 86 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 86 received message: {'layer': 'layer_0'}
# 🚀 Neuron 86 in layer_0 activated!
# 🕒 Neuron 87 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 87 received message: {'layer': 'layer-0'}
# ✅ Neuron 87 received message: {'layer': 'layer_0'}
# 🚀 Neuron 87 in layer_0 activated!
# 🕒 Neuron 88 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 88 received message: {'layer': 'layer-0'}
# ✅ Neuron 88 received message: {'layer': 'layer_0'}
# 🚀 Neuron 88 in layer_0 activated!
# 🕒 Neuron 89 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 89 received message: {'layer': 'layer_0'}
# 🚀 Neuron 89 in layer_0 activated!
# 🕒 Neuron 90 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 90 received message: {'layer': 'layer_0'}
# 🚀 Neuron 90 in layer_0 activated!
# 🕒 Neuron 91 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 91 received message: {'layer': 'layer-0'}
# ✅ Neuron 91 received message: {'layer': 'layer_0'}
# 🚀 Neuron 91 in layer_0 activated!
# 🕒 Neuron 92 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 92 received message: {'layer': 'layer_0'}
# 🚀 Neuron 92 in layer_0 activated!
# 🕒 Neuron 93 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 93 received message: {'layer': 'layer_0'}
# 🚀 Neuron 93 in layer_0 activated!
# 🕒 Neuron 94 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 94 received message: {'layer': 'layer-0'}
# ✅ Neuron 94 received message: {'layer': 'layer_0'}
# 🚀 Neuron 94 in layer_0 activated!
# 🕒 Neuron 95 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 95 received message: {'layer': 'layer_0'}
# 🚀 Neuron 95 in layer_0 activated!
# 🕒 Neuron 96 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 96 received message: {'layer': 'layer-0'}
# ✅ Neuron 96 received message: {'layer': 'layer_0'}
# 🚀 Neuron 96 in layer_0 activated!
# 🕒 Neuron 97 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 97 received message: {'layer': 'layer-0'}
# ✅ Neuron 97 received message: {'layer': 'layer_0'}
# 🚀 Neuron 97 in layer_0 activated!
# 🕒 Neuron 98 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 98 received message: {'layer': 'layer-0'}
# ✅ Neuron 98 received message: {'layer': 'layer_0'}
# 🚀 Neuron 98 in layer_0 activated!
# 🕒 Neuron 99 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 99 received message: {'layer': 'layer_0'}
# 🚀 Neuron 99 in layer_0 activated!
# 🕒 Neuron 100 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 100 received message: {'layer': 'layer-0'}
# ✅ Neuron 100 received message: {'layer': 'layer_0'}
# 🚀 Neuron 100 in layer_0 activated!
# 🕒 Neuron 101 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 101 received message: {'layer': 'layer_0'}
# 🚀 Neuron 101 in layer_0 activated!
# 🕒 Neuron 102 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 102 received message: {'layer': 'layer_0'}
# 🚀 Neuron 102 in layer_0 activated!
# 🕒 Neuron 103 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 103 received message: {'layer': 'layer-0'}
# ✅ Neuron 103 received message: {'layer': 'layer_0'}
# 🚀 Neuron 103 in layer_0 activated!
# 🕒 Neuron 104 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 104 received message: {'layer': 'layer_0'}
# 🚀 Neuron 104 in layer_0 activated!
# 🕒 Neuron 105 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 105 received message: {'layer': 'layer-0'}
# ✅ Neuron 105 received message: {'layer': 'layer_0'}
# 🚀 Neuron 105 in layer_0 activated!
# 🕒 Neuron 106 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 106 received message: {'layer': 'layer_0'}
# 🚀 Neuron 106 in layer_0 activated!
# 🕒 Neuron 107 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 107 received message: {'layer': 'layer_0'}
# 🚀 Neuron 107 in layer_0 activated!
# 🕒 Neuron 108 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 108 received message: {'layer': 'layer-0'}
# ✅ Neuron 108 received message: {'layer': 'layer_0'}
# 🚀 Neuron 108 in layer_0 activated!
# 🕒 Neuron 109 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 109 received message: {'layer': 'layer_0'}
# 🚀 Neuron 109 in layer_0 activated!
# 🕒 Neuron 110 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 110 received message: {'layer': 'layer-0'}
# ✅ Neuron 110 received message: {'layer': 'layer_0'}
# 🚀 Neuron 110 in layer_0 activated!
# 🕒 Neuron 111 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 111 received message: {'layer': 'layer_0'}
# 🚀 Neuron 111 in layer_0 activated!
# 🕒 Neuron 112 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 112 received message: {'layer': 'layer_0'}
# 🚀 Neuron 112 in layer_0 activated!
# 🕒 Neuron 113 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 113 received message: {'layer': 'layer_0'}
# 🚀 Neuron 113 in layer_0 activated!
# 🕒 Neuron 114 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 114 received message: {'layer': 'layer-0'}
# ✅ Neuron 114 received message: {'layer': 'layer_0'}
# 🚀 Neuron 114 in layer_0 activated!
# 🕒 Neuron 115 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 115 received message: {'layer': 'layer-0'}
# ✅ Neuron 115 received message: {'layer': 'layer_0'}
# 🚀 Neuron 115 in layer_0 activated!
# 🕒 Neuron 116 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 116 received message: {'layer': 'layer_0'}
# 🚀 Neuron 116 in layer_0 activated!
# 🕒 Neuron 117 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 117 received message: {'layer': 'layer_0'}
# 🚀 Neuron 117 in layer_0 activated!
# 🕒 Neuron 118 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 118 received message: {'layer': 'layer-0'}
# ✅ Neuron 118 received message: {'layer': 'layer_0'}
# 🚀 Neuron 118 in layer_0 activated!
# 🕒 Neuron 119 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 119 received message: {'layer': 'layer_0'}
# 🚀 Neuron 119 in layer_0 activated!
# 🕒 Neuron 120 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 120 received message: {'layer': 'layer_0'}
# 🚀 Neuron 120 in layer_0 activated!
# 🕒 Neuron 121 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 121 received message: {'layer': 'layer_0'}
# 🚀 Neuron 121 in layer_0 activated!
# 🕒 Neuron 122 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 122 received message: {'layer': 'layer_0'}
# 🚀 Neuron 122 in layer_0 activated!
# 🕒 Neuron 123 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 123 received message: {'layer': 'layer-0'}
# ✅ Neuron 123 received message: {'layer': 'layer_0'}
# 🚀 Neuron 123 in layer_0 activated!
# 🕒 Neuron 124 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 124 received message: {'layer': 'layer-0'}
# ✅ Neuron 124 received message: {'layer': 'layer_0'}
# 🚀 Neuron 124 in layer_0 activated!
# 🕒 Neuron 125 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 125 received message: {'layer': 'layer-0'}
# ✅ Neuron 125 received message: {'layer': 'layer_0'}
# 🚀 Neuron 125 in layer_0 activated!
# 🕒 Neuron 126 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 126 received message: {'layer': 'layer_0'}
# 🚀 Neuron 126 in layer_0 activated!
# 🕒 Neuron 127 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 127 received message: {'layer': 'layer-0'}
# ✅ Neuron 127 received message: {'layer': 'layer_0'}
# 🚀 Neuron 127 in layer_0 activated!
# 📤 Layer layer_1 sending activation message to topic layer-1...
# ✅ Kafka message sent to layer-1
# 🕒 Neuron 0 in layer_1 waiting for activation on topic layer-1...
# ✅ Neuron 0 received message: {'layer': 'layer_1'}
# 🚀 Neuron 0 in layer_1 activated!
# 🕒 Neuron 1 in layer_1 waiting for activation on topic layer-1...
# ✅ Neuron 1 received message: {'layer': 'layer_1'}
# 🚀 Neuron 1 in layer_1 activated!
# 🕒 Neuron 2 in layer_1 waiting for activation on topic layer-1...
# ✅ Neuron 2 received message: {'layer': 'layer_1'}
# 🚀 Neuron 2 in layer_1 activated!
# 🕒 Neuron 3 in layer_1 waiting for activation on topic layer-1...
# ✅ Neuron 3 received message: {'layer': 'layer_1'}
# 🚀 Neuron 3 in layer_1 activated!
# 🕒 Neuron 4 in layer_1 waiting for activation on topic layer-1...
# ✅ Neuron 4 received message: {'layer': 'layer_1'}
# 🚀 Neuron 4 in layer_1 activated!
# 🕒 Neuron 5 in layer_1 waiting for activation on topic layer-1...
# ✅ Neuron 5 received message: {'layer': 'layer_1'}
# 🚀 Neuron 5 in layer_1 activated!
# 🕒 Neuron 6 in layer_1 waiting for activation on topic layer-1...
# ✅ Neuron 6 received message: {'layer': 'layer_1'}
# 🚀 Neuron 6 in layer_1 activated!
# 🕒 Neuron 7 in layer_1 waiting for activation on topic layer-1...
# ✅ Neuron 7 received message: {'layer': 'layer_1'}
# 🚀 Neuron 7 in layer_1 activated!
# 🕒 Neuron 8 in layer_1 waiting for activation on topic layer-1...
# ✅ Neuron 8 received message: {'layer': 'layer_1'}
# 🚀 Neuron 8 in layer_1 activated!
# 🕒 Neuron 9 in layer_1 waiting for activation on topic layer-1...
# ✅ Neuron 9 received message: {'layer': 'layer_1'}
# 🚀 Neuron 9 in layer_1 activated!
# Image 0 Prediction: 7, Label: 7
# 🔥 Sending initial activation message to layer-0...
# 📤 Layer layer_0 sending activation message to topic layer-0...
# ✅ Kafka message sent to layer-0
# 🕒 Neuron 0 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 0 received message: {'layer': 'layer-0'}
# ✅ Neuron 0 received message: {'layer': 'layer_0'}
# 🚀 Neuron 0 in layer_0 activated!
# 🕒 Neuron 1 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 1 received message: {'layer': 'layer_0'}
# 🚀 Neuron 1 in layer_0 activated!
# 🕒 Neuron 2 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 2 received message: {'layer': 'layer_0'}
# 🚀 Neuron 2 in layer_0 activated!
# 🕒 Neuron 3 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 3 received message: {'layer': 'layer_0'}
# 🚀 Neuron 3 in layer_0 activated!
# 🕒 Neuron 4 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 4 received message: {'layer': 'layer-0'}
# ✅ Neuron 4 received message: {'layer': 'layer_0'}
# 🚀 Neuron 4 in layer_0 activated!
# 🕒 Neuron 5 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 5 received message: {'layer': 'layer_0'}
# 🚀 Neuron 5 in layer_0 activated!
# 🕒 Neuron 6 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 6 received message: {'layer': 'layer_0'}
# 🚀 Neuron 6 in layer_0 activated!
# 🕒 Neuron 7 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 7 received message: {'layer': 'layer-0'}
# ✅ Neuron 7 received message: {'layer': 'layer_0'}
# 🚀 Neuron 7 in layer_0 activated!
# 🕒 Neuron 8 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 8 received message: {'layer': 'layer-0'}
# ✅ Neuron 8 received message: {'layer': 'layer-0'}
# ✅ Neuron 8 received message: {'layer': 'layer_0'}
# 🚀 Neuron 8 in layer_0 activated!
# 🕒 Neuron 9 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 9 received message: {'layer': 'layer-0'}
# ✅ Neuron 9 received message: {'layer': 'layer-0'}
# ✅ Neuron 9 received message: {'layer': 'layer_0'}
# 🚀 Neuron 9 in layer_0 activated!
# 🕒 Neuron 10 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 10 received message: {'layer': 'layer-0'}
# ✅ Neuron 10 received message: {'layer': 'layer_0'}
# 🚀 Neuron 10 in layer_0 activated!
# 🕒 Neuron 11 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 11 received message: {'layer': 'layer_0'}
# 🚀 Neuron 11 in layer_0 activated!
# 🕒 Neuron 12 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 12 received message: {'layer': 'layer_0'}
# 🚀 Neuron 12 in layer_0 activated!
# 🕒 Neuron 13 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 13 received message: {'layer': 'layer-0'}
# ✅ Neuron 13 received message: {'layer': 'layer_0'}
# 🚀 Neuron 13 in layer_0 activated!
# 🕒 Neuron 14 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 14 received message: {'layer': 'layer_0'}
# 🚀 Neuron 14 in layer_0 activated!
# 🕒 Neuron 15 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 15 received message: {'layer': 'layer_0'}
# 🚀 Neuron 15 in layer_0 activated!
# 🕒 Neuron 16 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 16 received message: {'layer': 'layer_0'}
# 🚀 Neuron 16 in layer_0 activated!
# 🕒 Neuron 17 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 17 received message: {'layer': 'layer_0'}
# 🚀 Neuron 17 in layer_0 activated!
# 🕒 Neuron 18 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 18 received message: {'layer': 'layer-0'}
# ✅ Neuron 18 received message: {'layer': 'layer_0'}
# 🚀 Neuron 18 in layer_0 activated!
# 🕒 Neuron 19 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 19 received message: {'layer': 'layer-0'}
# ✅ Neuron 19 received message: {'layer': 'layer-0'}
# ✅ Neuron 19 received message: {'layer': 'layer_0'}
# 🚀 Neuron 19 in layer_0 activated!
# 🕒 Neuron 20 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 20 received message: {'layer': 'layer-0'}
# ✅ Neuron 20 received message: {'layer': 'layer-0'}
# ✅ Neuron 20 received message: {'layer': 'layer_0'}
# 🚀 Neuron 20 in layer_0 activated!
# 🕒 Neuron 21 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 21 received message: {'layer': 'layer-0'}
# ✅ Neuron 21 received message: {'layer': 'layer_0'}
# 🚀 Neuron 21 in layer_0 activated!
# 🕒 Neuron 22 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 22 received message: {'layer': 'layer-0'}
# ✅ Neuron 22 received message: {'layer': 'layer_0'}
# 🚀 Neuron 22 in layer_0 activated!
# 🕒 Neuron 23 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 23 received message: {'layer': 'layer_0'}
# 🚀 Neuron 23 in layer_0 activated!
# 🕒 Neuron 24 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 24 received message: {'layer': 'layer_0'}
# 🚀 Neuron 24 in layer_0 activated!
# 🕒 Neuron 25 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 25 received message: {'layer': 'layer-0'}
# ✅ Neuron 25 received message: {'layer': 'layer-0'}
# ✅ Neuron 25 received message: {'layer': 'layer_0'}
# 🚀 Neuron 25 in layer_0 activated!
# 🕒 Neuron 26 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 26 received message: {'layer': 'layer-0'}
# ✅ Neuron 26 received message: {'layer': 'layer_0'}
# 🚀 Neuron 26 in layer_0 activated!
# 🕒 Neuron 27 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 27 received message: {'layer': 'layer-0'}
# ✅ Neuron 27 received message: {'layer': 'layer_0'}
# 🚀 Neuron 27 in layer_0 activated!
# 🕒 Neuron 28 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 28 received message: {'layer': 'layer-0'}
# ✅ Neuron 28 received message: {'layer': 'layer_0'}
# 🚀 Neuron 28 in layer_0 activated!
# 🕒 Neuron 29 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 29 received message: {'layer': 'layer_0'}
# 🚀 Neuron 29 in layer_0 activated!
# 🕒 Neuron 30 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 30 received message: {'layer': 'layer_0'}
# 🚀 Neuron 30 in layer_0 activated!
# 🕒 Neuron 31 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 31 received message: {'layer': 'layer_0'}
# 🚀 Neuron 31 in layer_0 activated!
# 🕒 Neuron 32 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 32 received message: {'layer': 'layer_0'}
# 🚀 Neuron 32 in layer_0 activated!
# 🕒 Neuron 33 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 33 received message: {'layer': 'layer_0'}
# 🚀 Neuron 33 in layer_0 activated!
# 🕒 Neuron 34 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 34 received message: {'layer': 'layer-0'}
# ✅ Neuron 34 received message: {'layer': 'layer_0'}
# 🚀 Neuron 34 in layer_0 activated!
# 🕒 Neuron 35 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 35 received message: {'layer': 'layer_0'}
# 🚀 Neuron 35 in layer_0 activated!
# 🕒 Neuron 36 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 36 received message: {'layer': 'layer-0'}
# ✅ Neuron 36 received message: {'layer': 'layer-0'}
# ✅ Neuron 36 received message: {'layer': 'layer_0'}
# 🚀 Neuron 36 in layer_0 activated!
# 🕒 Neuron 37 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 37 received message: {'layer': 'layer_0'}
# 🚀 Neuron 37 in layer_0 activated!
# 🕒 Neuron 38 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 38 received message: {'layer': 'layer-0'}
# ✅ Neuron 38 received message: {'layer': 'layer_0'}
# 🚀 Neuron 38 in layer_0 activated!
# 🕒 Neuron 39 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 39 received message: {'layer': 'layer-0'}
# ✅ Neuron 39 received message: {'layer': 'layer_0'}
# 🚀 Neuron 39 in layer_0 activated!
# 🕒 Neuron 40 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 40 received message: {'layer': 'layer-0'}
# ✅ Neuron 40 received message: {'layer': 'layer-0'}
# ✅ Neuron 40 received message: {'layer': 'layer_0'}
# 🚀 Neuron 40 in layer_0 activated!
# 🕒 Neuron 41 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 41 received message: {'layer': 'layer-0'}
# ✅ Neuron 41 received message: {'layer': 'layer-0'}
# ✅ Neuron 41 received message: {'layer': 'layer_0'}
# 🚀 Neuron 41 in layer_0 activated!
# 🕒 Neuron 42 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 42 received message: {'layer': 'layer-0'}
# ✅ Neuron 42 received message: {'layer': 'layer-0'}
# ✅ Neuron 42 received message: {'layer': 'layer_0'}
# 🚀 Neuron 42 in layer_0 activated!
# 🕒 Neuron 43 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 43 received message: {'layer': 'layer_0'}
# 🚀 Neuron 43 in layer_0 activated!
# 🕒 Neuron 44 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 44 received message: {'layer': 'layer_0'}
# 🚀 Neuron 44 in layer_0 activated!
# 🕒 Neuron 45 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 45 received message: {'layer': 'layer_0'}
# 🚀 Neuron 45 in layer_0 activated!
# 🕒 Neuron 46 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 46 received message: {'layer': 'layer_0'}
# 🚀 Neuron 46 in layer_0 activated!
# 🕒 Neuron 47 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 47 received message: {'layer': 'layer_0'}
# 🚀 Neuron 47 in layer_0 activated!
# 🕒 Neuron 48 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 48 received message: {'layer': 'layer-0'}
# ✅ Neuron 48 received message: {'layer': 'layer_0'}
# 🚀 Neuron 48 in layer_0 activated!
# 🕒 Neuron 49 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 49 received message: {'layer': 'layer-0'}
# ✅ Neuron 49 received message: {'layer': 'layer_0'}
# 🚀 Neuron 49 in layer_0 activated!
# 🕒 Neuron 50 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 50 received message: {'layer': 'layer-0'}
# ✅ Neuron 50 received message: {'layer': 'layer_0'}
# 🚀 Neuron 50 in layer_0 activated!
# 🕒 Neuron 51 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 51 received message: {'layer': 'layer_0'}
# 🚀 Neuron 51 in layer_0 activated!
# 🕒 Neuron 52 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 52 received message: {'layer': 'layer_0'}
# 🚀 Neuron 52 in layer_0 activated!
# 🕒 Neuron 53 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 53 received message: {'layer': 'layer-0'}
# ✅ Neuron 53 received message: {'layer': 'layer-0'}
# ✅ Neuron 53 received message: {'layer': 'layer_0'}
# 🚀 Neuron 53 in layer_0 activated!
# 🕒 Neuron 54 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 54 received message: {'layer': 'layer_0'}
# 🚀 Neuron 54 in layer_0 activated!
# 🕒 Neuron 55 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 55 received message: {'layer': 'layer-0'}
# ✅ Neuron 55 received message: {'layer': 'layer_0'}
# 🚀 Neuron 55 in layer_0 activated!
# 🕒 Neuron 56 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 56 received message: {'layer': 'layer_0'}
# 🚀 Neuron 56 in layer_0 activated!
# 🕒 Neuron 57 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 57 received message: {'layer': 'layer-0'}
# ✅ Neuron 57 received message: {'layer': 'layer_0'}
# 🚀 Neuron 57 in layer_0 activated!
# 🕒 Neuron 58 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 58 received message: {'layer': 'layer-0'}
# ✅ Neuron 58 received message: {'layer': 'layer_0'}
# 🚀 Neuron 58 in layer_0 activated!
# 🕒 Neuron 59 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 59 received message: {'layer': 'layer-0'}
# ✅ Neuron 59 received message: {'layer': 'layer_0'}
# 🚀 Neuron 59 in layer_0 activated!
# 🕒 Neuron 60 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 60 received message: {'layer': 'layer_0'}
# 🚀 Neuron 60 in layer_0 activated!
# 🕒 Neuron 61 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 61 received message: {'layer': 'layer-0'}
# ✅ Neuron 61 received message: {'layer': 'layer_0'}
# 🚀 Neuron 61 in layer_0 activated!
# 🕒 Neuron 62 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 62 received message: {'layer': 'layer-0'}
# ✅ Neuron 62 received message: {'layer': 'layer_0'}
# 🚀 Neuron 62 in layer_0 activated!
# 🕒 Neuron 63 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 63 received message: {'layer': 'layer-0'}
# ✅ Neuron 63 received message: {'layer': 'layer-0'}
# ✅ Neuron 63 received message: {'layer': 'layer_0'}
# 🚀 Neuron 63 in layer_0 activated!
# 🕒 Neuron 64 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 64 received message: {'layer': 'layer_0'}
# 🚀 Neuron 64 in layer_0 activated!
# 🕒 Neuron 65 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 65 received message: {'layer': 'layer_0'}
# 🚀 Neuron 65 in layer_0 activated!
# 🕒 Neuron 66 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 66 received message: {'layer': 'layer_0'}
# 🚀 Neuron 66 in layer_0 activated!
# 🕒 Neuron 67 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 67 received message: {'layer': 'layer_0'}
# 🚀 Neuron 67 in layer_0 activated!
# 🕒 Neuron 68 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 68 received message: {'layer': 'layer_0'}
# 🚀 Neuron 68 in layer_0 activated!
# 🕒 Neuron 69 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 69 received message: {'layer': 'layer_0'}
# 🚀 Neuron 69 in layer_0 activated!
# 🕒 Neuron 70 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 70 received message: {'layer': 'layer-0'}
# ✅ Neuron 70 received message: {'layer': 'layer_0'}
# 🚀 Neuron 70 in layer_0 activated!
# 🕒 Neuron 71 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 71 received message: {'layer': 'layer-0'}
# ✅ Neuron 71 received message: {'layer': 'layer-0'}
# ✅ Neuron 71 received message: {'layer': 'layer_0'}
# 🚀 Neuron 71 in layer_0 activated!
# 🕒 Neuron 72 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 72 received message: {'layer': 'layer-0'}
# ✅ Neuron 72 received message: {'layer': 'layer_0'}
# 🚀 Neuron 72 in layer_0 activated!
# 🕒 Neuron 73 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 73 received message: {'layer': 'layer-0'}
# ✅ Neuron 73 received message: {'layer': 'layer-0'}
# ✅ Neuron 73 received message: {'layer': 'layer_0'}
# 🚀 Neuron 73 in layer_0 activated!
# 🕒 Neuron 74 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 74 received message: {'layer': 'layer-0'}
# ✅ Neuron 74 received message: {'layer': 'layer_0'}
# 🚀 Neuron 74 in layer_0 activated!
# 🕒 Neuron 75 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 75 received message: {'layer': 'layer_0'}
# 🚀 Neuron 75 in layer_0 activated!
# 🕒 Neuron 76 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 76 received message: {'layer': 'layer_0'}
# 🚀 Neuron 76 in layer_0 activated!
# 🕒 Neuron 77 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 77 received message: {'layer': 'layer_0'}
# 🚀 Neuron 77 in layer_0 activated!
# 🕒 Neuron 78 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 78 received message: {'layer': 'layer_0'}
# 🚀 Neuron 78 in layer_0 activated!
# 🕒 Neuron 79 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 79 received message: {'layer': 'layer_0'}
# 🚀 Neuron 79 in layer_0 activated!
# 🕒 Neuron 80 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 80 received message: {'layer': 'layer-0'}
# ✅ Neuron 80 received message: {'layer': 'layer_0'}
# 🚀 Neuron 80 in layer_0 activated!
# 🕒 Neuron 81 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 81 received message: {'layer': 'layer-0'}
# ✅ Neuron 81 received message: {'layer': 'layer_0'}
# 🚀 Neuron 81 in layer_0 activated!
# 🕒 Neuron 82 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 82 received message: {'layer': 'layer-0'}
# ✅ Neuron 82 received message: {'layer': 'layer_0'}
# 🚀 Neuron 82 in layer_0 activated!
# 🕒 Neuron 83 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 83 received message: {'layer': 'layer-0'}
# ✅ Neuron 83 received message: {'layer': 'layer_0'}
# 🚀 Neuron 83 in layer_0 activated!
# 🕒 Neuron 84 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 84 received message: {'layer': 'layer-0'}
# ✅ Neuron 84 received message: {'layer': 'layer_0'}
# 🚀 Neuron 84 in layer_0 activated!
# 🕒 Neuron 85 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 85 received message: {'layer': 'layer-0'}
# ✅ Neuron 85 received message: {'layer': 'layer-0'}
# ✅ Neuron 85 received message: {'layer': 'layer_0'}
# 🚀 Neuron 85 in layer_0 activated!
# 🕒 Neuron 86 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 86 received message: {'layer': 'layer_0'}
# 🚀 Neuron 86 in layer_0 activated!
# 🕒 Neuron 87 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 87 received message: {'layer': 'layer_0'}
# 🚀 Neuron 87 in layer_0 activated!
# 🕒 Neuron 88 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 88 received message: {'layer': 'layer-0'}
# ✅ Neuron 88 received message: {'layer': 'layer_0'}
# 🚀 Neuron 88 in layer_0 activated!
# 🕒 Neuron 89 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 89 received message: {'layer': 'layer-0'}
# ✅ Neuron 89 received message: {'layer': 'layer-0'}
# ✅ Neuron 89 received message: {'layer': 'layer_0'}
# 🚀 Neuron 89 in layer_0 activated!
# 🕒 Neuron 90 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 90 received message: {'layer': 'layer-0'}
# ✅ Neuron 90 received message: {'layer': 'layer-0'}
# ✅ Neuron 90 received message: {'layer': 'layer_0'}
# 🚀 Neuron 90 in layer_0 activated!
# 🕒 Neuron 91 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 91 received message: {'layer': 'layer_0'}
# 🚀 Neuron 91 in layer_0 activated!
# 🕒 Neuron 92 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 92 received message: {'layer': 'layer-0'}
# ✅ Neuron 92 received message: {'layer': 'layer-0'}
# ✅ Neuron 92 received message: {'layer': 'layer_0'}
# 🚀 Neuron 92 in layer_0 activated!
# 🕒 Neuron 93 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 93 received message: {'layer': 'layer_0'}
# 🚀 Neuron 93 in layer_0 activated!
# 🕒 Neuron 94 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 94 received message: {'layer': 'layer_0'}
# 🚀 Neuron 94 in layer_0 activated!
# 🕒 Neuron 95 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 95 received message: {'layer': 'layer-0'}
# ✅ Neuron 95 received message: {'layer': 'layer_0'}
# 🚀 Neuron 95 in layer_0 activated!
# 🕒 Neuron 96 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 96 received message: {'layer': 'layer-0'}
# ✅ Neuron 96 received message: {'layer': 'layer_0'}
# 🚀 Neuron 96 in layer_0 activated!
# 🕒 Neuron 97 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 97 received message: {'layer': 'layer_0'}
# 🚀 Neuron 97 in layer_0 activated!
# 🕒 Neuron 98 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 98 received message: {'layer': 'layer_0'}
# 🚀 Neuron 98 in layer_0 activated!
# 🕒 Neuron 99 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 99 received message: {'layer': 'layer-0'}
# ✅ Neuron 99 received message: {'layer': 'layer_0'}
# 🚀 Neuron 99 in layer_0 activated!
# 🕒 Neuron 100 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 100 received message: {'layer': 'layer-0'}
# ✅ Neuron 100 received message: {'layer': 'layer_0'}
# 🚀 Neuron 100 in layer_0 activated!
# 🕒 Neuron 101 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 101 received message: {'layer': 'layer-0'}
# ✅ Neuron 101 received message: {'layer': 'layer_0'}
# 🚀 Neuron 101 in layer_0 activated!
# 🕒 Neuron 102 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 102 received message: {'layer': 'layer-0'}
# ✅ Neuron 102 received message: {'layer': 'layer-0'}
# ✅ Neuron 102 received message: {'layer': 'layer_0'}
# 🚀 Neuron 102 in layer_0 activated!
# 🕒 Neuron 103 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 103 received message: {'layer': 'layer_0'}
# 🚀 Neuron 103 in layer_0 activated!
# 🕒 Neuron 104 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 104 received message: {'layer': 'layer_0'}
# 🚀 Neuron 104 in layer_0 activated!
# 🕒 Neuron 105 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 105 received message: {'layer': 'layer-0'}
# ✅ Neuron 105 received message: {'layer': 'layer_0'}
# 🚀 Neuron 105 in layer_0 activated!
# 🕒 Neuron 106 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 106 received message: {'layer': 'layer_0'}
# 🚀 Neuron 106 in layer_0 activated!
# 🕒 Neuron 107 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 107 received message: {'layer': 'layer-0'}
# ✅ Neuron 107 received message: {'layer': 'layer_0'}
# 🚀 Neuron 107 in layer_0 activated!
# 🕒 Neuron 108 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 108 received message: {'layer': 'layer_0'}
# 🚀 Neuron 108 in layer_0 activated!
# 🕒 Neuron 109 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 109 received message: {'layer': 'layer_0'}
# 🚀 Neuron 109 in layer_0 activated!
# 🕒 Neuron 110 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 110 received message: {'layer': 'layer_0'}
# 🚀 Neuron 110 in layer_0 activated!
# 🕒 Neuron 111 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 111 received message: {'layer': 'layer-0'}
# ✅ Neuron 111 received message: {'layer': 'layer_0'}
# 🚀 Neuron 111 in layer_0 activated!
# 🕒 Neuron 112 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 112 received message: {'layer': 'layer-0'}
# ✅ Neuron 112 received message: {'layer': 'layer_0'}
# 🚀 Neuron 112 in layer_0 activated!
# 🕒 Neuron 113 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 113 received message: {'layer': 'layer_0'}
# 🚀 Neuron 113 in layer_0 activated!
# 🕒 Neuron 114 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 114 received message: {'layer': 'layer_0'}
# 🚀 Neuron 114 in layer_0 activated!
# 🕒 Neuron 115 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 115 received message: {'layer': 'layer-0'}
# ✅ Neuron 115 received message: {'layer': 'layer_0'}
# 🚀 Neuron 115 in layer_0 activated!
# 🕒 Neuron 116 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 116 received message: {'layer': 'layer-0'}
# ✅ Neuron 116 received message: {'layer': 'layer_0'}
# 🚀 Neuron 116 in layer_0 activated!
# 🕒 Neuron 117 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 117 received message: {'layer': 'layer_0'}
# 🚀 Neuron 117 in layer_0 activated!
# 🕒 Neuron 118 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 118 received message: {'layer': 'layer-0'}
# ✅ Neuron 118 received message: {'layer': 'layer_0'}
# 🚀 Neuron 118 in layer_0 activated!
# 🕒 Neuron 119 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 119 received message: {'layer': 'layer_0'}
# 🚀 Neuron 119 in layer_0 activated!
# 🕒 Neuron 120 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 120 received message: {'layer': 'layer_0'}
# 🚀 Neuron 120 in layer_0 activated!
# 🕒 Neuron 121 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 121 received message: {'layer': 'layer-0'}
# ✅ Neuron 121 received message: {'layer': 'layer_0'}
# 🚀 Neuron 121 in layer_0 activated!
# 🕒 Neuron 122 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 122 received message: {'layer': 'layer-0'}
# ✅ Neuron 122 received message: {'layer': 'layer-0'}
# ✅ Neuron 122 received message: {'layer': 'layer_0'}
# 🚀 Neuron 122 in layer_0 activated!
# 🕒 Neuron 123 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 123 received message: {'layer': 'layer_0'}
# 🚀 Neuron 123 in layer_0 activated!
# 🕒 Neuron 124 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 124 received message: {'layer': 'layer-0'}
# ✅ Neuron 124 received message: {'layer': 'layer-0'}
# ✅ Neuron 124 received message: {'layer': 'layer_0'}
# 🚀 Neuron 124 in layer_0 activated!
# 🕒 Neuron 125 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 125 received message: {'layer': 'layer-0'}
# ✅ Neuron 125 received message: {'layer': 'layer-0'}
# ✅ Neuron 125 received message: {'layer': 'layer_0'}
# 🚀 Neuron 125 in layer_0 activated!
# 🕒 Neuron 126 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 126 received message: {'layer': 'layer-0'}
# ✅ Neuron 126 received message: {'layer': 'layer-0'}
# ...
# ✅ Neuron 56 received message: {'layer': 'layer_0'}
# 🚀 Neuron 56 in layer_0 activated!
# 🕒 Neuron 57 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 57 received message: {'layer': 'layer-0'}
# ✅ Neuron 57 received message: {'layer': 'layer_0'}
# 🚀 Neuron 57 in layer_0 activated!
# 🕒 Neuron 58 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 58 received message: {'layer': 'layer-0'}
# ✅ Neuron 58 received message: {'layer': 'layer-0'}
# ✅ Neuron 58 received message: {'layer': 'layer-0'}
# ✅ Neuron 58 received message: {'layer': 'layer_0'}
# 🚀 Neuron 58 in layer_0 activated!
# 🕒 Neuron 59 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 59 received message: {'layer': 'layer-0'}
# ✅ Neuron 59 received message: {'layer': 'layer-0'}
# ✅ Neuron 59 received message: {'layer': 'layer_0'}
# 🚀 Neuron 59 in layer_0 activated!
# 🕒 Neuron 60 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 60 received message: {'layer': 'layer-0'}
# ✅ Neuron 60 received message: {'layer': 'layer_0'}
# 🚀 Neuron 60 in layer_0 activated!
# 🕒 Neuron 61 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 61 received message: {'layer': 'layer_0'}
# 🚀 Neuron 61 in layer_0 activated!
# 🕒 Neuron 62 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 62 received message: {'layer': 'layer-0'}
# ✅ Neuron 62 received message: {'layer': 'layer_0'}
# 🚀 Neuron 62 in layer_0 activated!
# 🕒 Neuron 63 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 63 received message: {'layer': 'layer_0'}
# 🚀 Neuron 63 in layer_0 activated!
# 🕒 Neuron 64 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 64 received message: {'layer': 'layer_0'}
# 🚀 Neuron 64 in layer_0 activated!
# 🕒 Neuron 65 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 65 received message: {'layer': 'layer_0'}
# 🚀 Neuron 65 in layer_0 activated!
# 🕒 Neuron 66 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 66 received message: {'layer': 'layer-0'}
# ✅ Neuron 66 received message: {'layer': 'layer-0'}
# ✅ Neuron 66 received message: {'layer': 'layer_0'}
# 🚀 Neuron 66 in layer_0 activated!
# 🕒 Neuron 67 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 67 received message: {'layer': 'layer_0'}
# 🚀 Neuron 67 in layer_0 activated!
# 🕒 Neuron 68 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 68 received message: {'layer': 'layer-0'}
# ✅ Neuron 68 received message: {'layer': 'layer_0'}
# 🚀 Neuron 68 in layer_0 activated!
# 🕒 Neuron 69 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 69 received message: {'layer': 'layer-0'}
# ✅ Neuron 69 received message: {'layer': 'layer-0'}
# ✅ Neuron 69 received message: {'layer': 'layer-0'}
# ✅ Neuron 69 received message: {'layer': 'layer_0'}
# 🚀 Neuron 69 in layer_0 activated!
# 🕒 Neuron 70 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 70 received message: {'layer': 'layer-0'}
# ✅ Neuron 70 received message: {'layer': 'layer-0'}
# ✅ Neuron 70 received message: {'layer': 'layer_0'}
# 🚀 Neuron 70 in layer_0 activated!
# 🕒 Neuron 71 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 71 received message: {'layer': 'layer_0'}
# 🚀 Neuron 71 in layer_0 activated!
# 🕒 Neuron 72 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 72 received message: {'layer': 'layer-0'}
# ✅ Neuron 72 received message: {'layer': 'layer-0'}
# ✅ Neuron 72 received message: {'layer': 'layer-0'}
# ✅ Neuron 72 received message: {'layer': 'layer_0'}
# 🚀 Neuron 72 in layer_0 activated!
# 🕒 Neuron 73 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 73 received message: {'layer': 'layer-0'}
# ✅ Neuron 73 received message: {'layer': 'layer-0'}
# ✅ Neuron 73 received message: {'layer': 'layer-0'}
# ✅ Neuron 73 received message: {'layer': 'layer-0'}
# ✅ Neuron 73 received message: {'layer': 'layer_0'}
# 🚀 Neuron 73 in layer_0 activated!
# 🕒 Neuron 74 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 74 received message: {'layer': 'layer_0'}
# 🚀 Neuron 74 in layer_0 activated!
# 🕒 Neuron 75 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 75 received message: {'layer': 'layer_0'}
# 🚀 Neuron 75 in layer_0 activated!
# 🕒 Neuron 76 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 76 received message: {'layer': 'layer_0'}
# 🚀 Neuron 76 in layer_0 activated!
# 🕒 Neuron 77 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 77 received message: {'layer': 'layer-0'}
# ✅ Neuron 77 received message: {'layer': 'layer_0'}
# 🚀 Neuron 77 in layer_0 activated!
# 🕒 Neuron 78 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 78 received message: {'layer': 'layer_0'}
# 🚀 Neuron 78 in layer_0 activated!
# 🕒 Neuron 79 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 79 received message: {'layer': 'layer-0'}
# ✅ Neuron 79 received message: {'layer': 'layer-0'}
# ✅ Neuron 79 received message: {'layer': 'layer_0'}
# 🚀 Neuron 79 in layer_0 activated!
# 🕒 Neuron 80 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 80 received message: {'layer': 'layer-0'}
# ✅ Neuron 80 received message: {'layer': 'layer_0'}
# 🚀 Neuron 80 in layer_0 activated!
# 🕒 Neuron 81 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 81 received message: {'layer': 'layer_0'}
# 🚀 Neuron 81 in layer_0 activated!
# 🕒 Neuron 82 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 82 received message: {'layer': 'layer-0'}
# ✅ Neuron 82 received message: {'layer': 'layer_0'}
# 🚀 Neuron 82 in layer_0 activated!
# 🕒 Neuron 83 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 83 received message: {'layer': 'layer-0'}
# ✅ Neuron 83 received message: {'layer': 'layer-0'}
# ✅ Neuron 83 received message: {'layer': 'layer_0'}
# 🚀 Neuron 83 in layer_0 activated!
# 🕒 Neuron 84 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 84 received message: {'layer': 'layer-0'}
# ✅ Neuron 84 received message: {'layer': 'layer_0'}
# 🚀 Neuron 84 in layer_0 activated!
# 🕒 Neuron 85 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 85 received message: {'layer': 'layer-0'}
# ✅ Neuron 85 received message: {'layer': 'layer_0'}
# 🚀 Neuron 85 in layer_0 activated!
# 🕒 Neuron 86 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 86 received message: {'layer': 'layer_0'}
# 🚀 Neuron 86 in layer_0 activated!
# 🕒 Neuron 87 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 87 received message: {'layer': 'layer_0'}
# 🚀 Neuron 87 in layer_0 activated!
# 🕒 Neuron 88 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 88 received message: {'layer': 'layer_0'}
# 🚀 Neuron 88 in layer_0 activated!
# 🕒 Neuron 89 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 89 received message: {'layer': 'layer-0'}
# ✅ Neuron 89 received message: {'layer': 'layer_0'}
# 🚀 Neuron 89 in layer_0 activated!
# 🕒 Neuron 90 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 90 received message: {'layer': 'layer_0'}
# 🚀 Neuron 90 in layer_0 activated!
# 🕒 Neuron 91 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 91 received message: {'layer': 'layer_0'}
# 🚀 Neuron 91 in layer_0 activated!
# 🕒 Neuron 92 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 92 received message: {'layer': 'layer-0'}
# ✅ Neuron 92 received message: {'layer': 'layer-0'}
# ✅ Neuron 92 received message: {'layer': 'layer_0'}
# 🚀 Neuron 92 in layer_0 activated!
# 🕒 Neuron 93 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 93 received message: {'layer': 'layer-0'}
# ✅ Neuron 93 received message: {'layer': 'layer_0'}
# 🚀 Neuron 93 in layer_0 activated!
# 🕒 Neuron 94 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 94 received message: {'layer': 'layer-0'}
# ✅ Neuron 94 received message: {'layer': 'layer_0'}
# 🚀 Neuron 94 in layer_0 activated!
# 🕒 Neuron 95 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 95 received message: {'layer': 'layer-0'}
# ✅ Neuron 95 received message: {'layer': 'layer_0'}
# 🚀 Neuron 95 in layer_0 activated!
# 🕒 Neuron 96 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 96 received message: {'layer': 'layer_0'}
# 🚀 Neuron 96 in layer_0 activated!
# 🕒 Neuron 97 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 97 received message: {'layer': 'layer_0'}
# 🚀 Neuron 97 in layer_0 activated!
# 🕒 Neuron 98 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 98 received message: {'layer': 'layer-0'}
# ✅ Neuron 98 received message: {'layer': 'layer_0'}
# 🚀 Neuron 98 in layer_0 activated!
# 🕒 Neuron 99 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 99 received message: {'layer': 'layer_0'}
# 🚀 Neuron 99 in layer_0 activated!
# 🕒 Neuron 100 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 100 received message: {'layer': 'layer-0'}
# ✅ Neuron 100 received message: {'layer': 'layer_0'}
# 🚀 Neuron 100 in layer_0 activated!
# 🕒 Neuron 101 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 101 received message: {'layer': 'layer-0'}
# ✅ Neuron 101 received message: {'layer': 'layer-0'}
# ✅ Neuron 101 received message: {'layer': 'layer-0'}
# ✅ Neuron 101 received message: {'layer': 'layer_0'}
# 🚀 Neuron 101 in layer_0 activated!
# 🕒 Neuron 102 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 102 received message: {'layer': 'layer_0'}
# 🚀 Neuron 102 in layer_0 activated!
# 🕒 Neuron 103 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 103 received message: {'layer': 'layer-0'}
# ✅ Neuron 103 received message: {'layer': 'layer-0'}
# ✅ Neuron 103 received message: {'layer': 'layer_0'}
# 🚀 Neuron 103 in layer_0 activated!
# 🕒 Neuron 104 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 104 received message: {'layer': 'layer-0'}
# ✅ Neuron 104 received message: {'layer': 'layer_0'}
# 🚀 Neuron 104 in layer_0 activated!
# 🕒 Neuron 105 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 105 received message: {'layer': 'layer-0'}
# ✅ Neuron 105 received message: {'layer': 'layer-0'}
# ✅ Neuron 105 received message: {'layer': 'layer-0'}
# ✅ Neuron 105 received message: {'layer': 'layer-0'}
# ✅ Neuron 105 received message: {'layer': 'layer_0'}
# 🚀 Neuron 105 in layer_0 activated!
# 🕒 Neuron 106 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 106 received message: {'layer': 'layer-0'}
# ✅ Neuron 106 received message: {'layer': 'layer-0'}
# ✅ Neuron 106 received message: {'layer': 'layer_0'}
# 🚀 Neuron 106 in layer_0 activated!
# 🕒 Neuron 107 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 107 received message: {'layer': 'layer_0'}
# 🚀 Neuron 107 in layer_0 activated!
# 🕒 Neuron 108 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 108 received message: {'layer': 'layer-0'}
# ✅ Neuron 108 received message: {'layer': 'layer_0'}
# 🚀 Neuron 108 in layer_0 activated!
# 🕒 Neuron 109 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 109 received message: {'layer': 'layer_0'}
# 🚀 Neuron 109 in layer_0 activated!
# 🕒 Neuron 110 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 110 received message: {'layer': 'layer-0'}
# ✅ Neuron 110 received message: {'layer': 'layer_0'}
# 🚀 Neuron 110 in layer_0 activated!
# 🕒 Neuron 111 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 111 received message: {'layer': 'layer-0'}
# ✅ Neuron 111 received message: {'layer': 'layer-0'}
# ✅ Neuron 111 received message: {'layer': 'layer_0'}
# 🚀 Neuron 111 in layer_0 activated!
# 🕒 Neuron 112 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 112 received message: {'layer': 'layer_0'}
# 🚀 Neuron 112 in layer_0 activated!
# 🕒 Neuron 113 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 113 received message: {'layer': 'layer_0'}
# 🚀 Neuron 113 in layer_0 activated!
# 🕒 Neuron 114 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 114 received message: {'layer': 'layer-0'}
# ✅ Neuron 114 received message: {'layer': 'layer_0'}
# 🚀 Neuron 114 in layer_0 activated!
# 🕒 Neuron 115 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 115 received message: {'layer': 'layer-0'}
# ✅ Neuron 115 received message: {'layer': 'layer_0'}
# 🚀 Neuron 115 in layer_0 activated!
# 🕒 Neuron 116 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 116 received message: {'layer': 'layer_0'}
# 🚀 Neuron 116 in layer_0 activated!
# 🕒 Neuron 117 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 117 received message: {'layer': 'layer-0'}
# ✅ Neuron 117 received message: {'layer': 'layer_0'}
# 🚀 Neuron 117 in layer_0 activated!
# 🕒 Neuron 118 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 118 received message: {'layer': 'layer_0'}
# 🚀 Neuron 118 in layer_0 activated!
# 🕒 Neuron 119 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 119 received message: {'layer': 'layer-0'}
# ✅ Neuron 119 received message: {'layer': 'layer-0'}
# ✅ Neuron 119 received message: {'layer': 'layer-0'}
# ✅ Neuron 119 received message: {'layer': 'layer_0'}
# 🚀 Neuron 119 in layer_0 activated!
# 🕒 Neuron 120 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 120 received message: {'layer': 'layer_0'}
# 🚀 Neuron 120 in layer_0 activated!
# 🕒 Neuron 121 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 121 received message: {'layer': 'layer_0'}
# 🚀 Neuron 121 in layer_0 activated!
# 🕒 Neuron 122 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 122 received message: {'layer': 'layer-0'}
# ✅ Neuron 122 received message: {'layer': 'layer_0'}
# 🚀 Neuron 122 in layer_0 activated!
# 🕒 Neuron 123 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 123 received message: {'layer': 'layer-0'}
# ✅ Neuron 123 received message: {'layer': 'layer-0'}
# ✅ Neuron 123 received message: {'layer': 'layer-0'}
# ✅ Neuron 123 received message: {'layer': 'layer-0'}
# ✅ Neuron 123 received message: {'layer': 'layer_0'}
# 🚀 Neuron 123 in layer_0 activated!
# 🕒 Neuron 124 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 124 received message: {'layer': 'layer_0'}
# 🚀 Neuron 124 in layer_0 activated!
# 🕒 Neuron 125 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 125 received message: {'layer': 'layer_0'}
# 🚀 Neuron 125 in layer_0 activated!
# 🕒 Neuron 126 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 126 received message: {'layer': 'layer_0'}
# 🚀 Neuron 126 in layer_0 activated!
# 🕒 Neuron 127 in layer_0 waiting for activation on topic layer-0...
# ✅ Neuron 127 received message: {'layer': 'layer_0'}
# 🚀 Neuron 127 in layer_0 activated!
# 📤 Layer layer_1 sending activation message to topic layer-1...
# ✅ Kafka message sent to layer-1
# 🕒 Neuron 0 in layer_1 waiting for activation on topic layer-1...
# ✅ Neuron 0 received message: {'layer': 'layer_1'}
# 🚀 Neuron 0 in layer_1 activated!
# 🕒 Neuron 1 in layer_1 waiting for activation on topic layer-1...
# ✅ Neuron 1 received message: {'layer': 'layer_1'}
# 🚀 Neuron 1 in layer_1 activated!
# 🕒 Neuron 2 in layer_1 waiting for activation on topic layer-1...
# ✅ Neuron 2 received message: {'layer': 'layer_1'}
# 🚀 Neuron 2 in layer_1 activated!
# 🕒 Neuron 3 in layer_1 waiting for activation on topic layer-1...
# ✅ Neuron 3 received message: {'layer': 'layer_1'}
# 🚀 Neuron 3 in layer_1 activated!
# 🕒 Neuron 4 in layer_1 waiting for activation on topic layer-1...
# ✅ Neuron 4 received message: {'layer': 'layer_1'}
# 🚀 Neuron 4 in layer_1 activated!
# 🕒 Neuron 5 in layer_1 waiting for activation on topic layer-1...
# ✅ Neuron 5 received message: {'layer': 'layer_1'}
# 🚀 Neuron 5 in layer_1 activated!
# 🕒 Neuron 6 in layer_1 waiting for activation on topic layer-1...
# ✅ Neuron 6 received message: {'layer': 'layer_1'}
# 🚀 Neuron 6 in layer_1 activated!
# 🕒 Neuron 7 in layer_1 waiting for activation on topic layer-1...
# ✅ Neuron 7 received message: {'layer': 'layer_1'}
# 🚀 Neuron 7 in layer_1 activated!
# 🕒 Neuron 8 in layer_1 waiting for activation on topic layer-1...
# ✅ Neuron 8 received message: {'layer': 'layer_1'}
# 🚀 Neuron 8 in layer_1 activated!
# 🕒 Neuron 9 in layer_1 waiting for activation on topic layer-1...
# ✅ Neuron 9 received message: {'layer': 'layer_1'}
# 🚀 Neuron 9 in layer_1 activated!
# Image 9 Prediction: 9, Label: 9
# Test Accuracy: 90.00%
