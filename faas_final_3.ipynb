# %%
import redis 

client = redis.Redis('host.docker.internal', 6379, 0)

client.flushdb()
# Out:
# True

# %%
import json
import numpy as np
import threading
import time
#import pandas as pd
from concurrent.futures import ThreadPoolExecutor
from pcomp_utils.kafka_producer_utils import KafkaProducerHandler
from pcomp_utils.kafka_consumer_utils import KafkaConsumerHandler
from pcomp_utils.activation_functions import ACTIVATIONS, relu, softmax
from pcomp_utils.redis_utils import RedisHandler

# Kafka Configuration
KAFKA_BROKER = 'kafka:9092'

class Neuron(threading.Thread):
    def __init__(self, layer_id, neuron_id, weights, bias, activation, is_final_layer):
        threading.Thread.__init__(self)
        self.layer_id = layer_id
        self.layer_id_num = int(self.layer_id.replace("layer_", ""))
        self.neuron_id = neuron_id
        self.weights = np.array(weights)
        self.bias = np.array(bias)
        self.activation_func = ACTIVATIONS.get(activation, relu)
        self.is_final_layer = is_final_layer
        self.consumer = KafkaConsumerHandler(f'layer-{self.layer_id_num}', KAFKA_BROKER, partition=self.neuron_id)
        self.producer = KafkaProducerHandler(KAFKA_BROKER)
        self.redis_handler = RedisHandler('host.docker.internal', 6379, 0)
        self.executor = ThreadPoolExecutor(max_workers=4)

    def fetch_input(self, image_id):
        key = f"initial_data:{image_id}" if self.layer_id == 'layer_0' else f"layer_{int(self.layer_id[-1]) - 1}_{image_id}"
        data = self.redis_handler.get(key)
        while True:
            data = self.redis_handler.get(key)
            if data is not None:
                return data
            print(f"⏳ Neuron {self.neuron_id} waiting for input data for key: {key}")

    def process_data(self, inputs):
        z = np.dot(inputs, self.weights) + self.bias
        return z if self.is_final_layer else self.activation_func(z)

    def process_and_send(self, image_id, input_data):
        # thread pool.
        output = self.process_data(input_data)
        msg = {
            'neuron_id': self.neuron_id,
            'image_id': image_id,
            'output': output.astype(np.float64).tobytes().hex()
        }
        self.producer.send(f'layer-{self.layer_id_num}-complete', msg, self.layer_id_num)

    def run(self):
        last_msg_time = time.time()
        while True:
            got_message = False
            for message in self.consumer.consume():
                got_message = True
                last_msg_time = time.time()
                if message.value.get('layer') == self.layer_id:
                    image_id = message.value.get('image_id')
                    redis_key = f"{self.layer_id}:neuron_{self.neuron_id}:{image_id}"
    
                    input_data = self.fetch_input(image_id)
                    if input_data is not None:
                        self.executor.submit(self.process_and_send, image_id, input_data)
            if not got_message:
                if time.time() - last_msg_time > 10:
                    print(f"No messages for 10 seconds in Neuron {self.neuron_id}; stopping thread.")
                    self.consumer.close()
                    self.producer.close()
                    break
            time.sleep(0.1)


class LayerCoordinator(threading.Thread):
    def __init__(self, layer_id, neuron_count, is_final_layer=False):
        threading.Thread.__init__(self)
        self.layer_id = layer_id
        self.layer_id_num = int(self.layer_id.replace("layer_", ""))
        self.neuron_count = neuron_count
        self.is_final_layer = is_final_layer
        self.completed_neurons = {}  # TODO: make a dictionary with image_id as the keys
        self.outputs = {}
        self.consumer = KafkaConsumerHandler(f'layer-{self.layer_id_num}-complete', KAFKA_BROKER, self.layer_id_num)
        self.producer = KafkaProducerHandler(KAFKA_BROKER)
        self.redis_handler = RedisHandler('host.docker.internal', 6379, 0)
        self.executor = ThreadPoolExecutor(max_workers=4)

    def run(self):
        last_msg_time = time.time()
        while True:
            got_message = False
            for message in self.consumer.consume():
                got_message = True
                last_msg_time = time.time()
                image_id = message.value.get('image_id')
                neuron_id = message.value.get('neuron_id')
                output_hex = message.value.get('output')
                output = np.frombuffer(bytes.fromhex(output_hex), dtype=np.float64)[0]
                print(f"🔍 Received output for Neuron {neuron_id} and image {image_id}: {output}")
                if image_id not in self.completed_neurons:
                    self.completed_neurons[image_id] = set()
                    self.outputs[image_id] = {}
                self.completed_neurons[image_id].add(neuron_id)
                self.outputs[image_id][neuron_id] = output

                if len(self.completed_neurons[image_id]) == self.neuron_count:
                    print(f"🟢 Aggregating outputs for image {image_id} on layer {self.layer_id}")
                    local_outputs = self.outputs[image_id].copy()
                    self.executor.submit(self.aggregate_neuron_outputs, image_id, local_outputs)
                    del self.completed_neurons[image_id]
                    del self.outputs[image_id]
                #self.consumer.commit(message.topic, message.partition, message.offset + 1)
            if not got_message:
                if time.time() - last_msg_time > 10:
                    print(f"No messages for 10 seconds in Neuron {self.neuron_id}; stopping thread.")
                    self.consumer.close()
                    self.producer.close()
                    break
            time.sleep(0.1)

    def aggregate_neuron_outputs(self, image_id, local_outputs):
        if not self.is_final_layer:
            self.activate_next_layer(image_id)
        outputs = np.array([local_outputs.get(neuron_id) for neuron_id in range(self.neuron_count)])
        #print(f"✅ Aggregated outputs for image {image_id}: {outputs}")
    
        # Store the aggregated result in Redis
        self.redis_handler.set(f"{self.layer_id}_{image_id}", outputs)
    
        if self.is_final_layer:
            prediction = int(np.argmax(outputs))
            self.redis_handler.hset('predictions', image_id, prediction)
            self.redis_handler.delete(f"initial_data:{image_id}")
            print(f"🎯 Final Prediction for image {image_id}: {prediction}")
    
    def activate_next_layer(self, image_id):
        next_layer = f'layer_{self.layer_id_num + 1}'
        self.producer.send('activate-layer', {'layer': next_layer, 'image_id': image_id}, self.layer_id_num + 1)
        print(f"🚀 Activating next layer: {next_layer} for image {image_id}")
            

class Layer(threading.Thread):
    def __init__(self, layer_id, neuron_count):
        threading.Thread.__init__(self)
        self.layer_id = layer_id
        self.neuron_count = neuron_count
        self.producer = KafkaProducerHandler(KAFKA_BROKER)
        self.layer_id_num = int(self.layer_id.replace("layer_", ""))
        self.consumer = KafkaConsumerHandler('activate-layer', KAFKA_BROKER, self.layer_id_num)
        self.executor = ThreadPoolExecutor(max_workers=8)

    def activate_neurons(self, image_id):
        # Offload each send to the executor.
        for neuron_id in range(self.neuron_count):
            self.executor.submit(self.send_activation, neuron_id, image_id)

    def send_activation(self, neuron_id, image_id):
        self.producer.send(f'layer-{self.layer_id_num}', {'layer': self.layer_id, 'image_id': image_id}, neuron_id)
        print(f"✅ Activated Neuron {neuron_id} in {self.layer_id} for image {image_id}")

    def run(self):
        last_msg_time = time.time()
        while True:
            got_message = False
            for message in self.consumer.consume():
                got_message = True
                last_msg_time = time.time()
                if message.value.get('layer') == self.layer_id:
                    image_id = message.value.get('image_id')
                    self.activate_neurons(image_id)
            if not got_message:
                if time.time() - last_msg_time > 10:
                    print(f"No messages for 10 seconds in Layer {self.layer}; stopping thread.")
                    self.consumer.close()
                    self.producer.close()
                    break
            time.sleep(0.1)

def store_initial_input_data(image_np, image_id):
    redis_handler = RedisHandler('host.docker.internal', 6379, 0)
    key = f"initial_data:{image_id}"
    redis_handler.set(key, image_np)
    print(f"📥 Initial input data stored in Redis.")

def activate_network(image_id):
    producer = KafkaProducerHandler(KAFKA_BROKER)
    producer.send('activate-layer', {'layer': 'layer_0', 'image_id': image_id}, 0)
    print(f"🚀 Initial activation sent to activate-layer for layer_0 and image {image_id}")
    producer.close()

# Load network and dataset
data = json.load(open("node_based_model.json"))
#df = pd.read_csv('data/mnist.csv').head(10)

neurons = []
layers = []
coordinators = []

for layer_name, layer_info in data.items():
    neurons += [Neuron(layer_id=layer_name, neuron_id=i, weights=node['weights'], bias=node['biases'], activation=node['activation'], is_final_layer=(layer_name == list(data.keys())[-1])) for i, node in enumerate(layer_info['nodes'])]
    layers.append(Layer(layer_id=layer_name, neuron_count=len(layer_info['nodes'])))
    coordinators.append(LayerCoordinator(layer_id=layer_name, neuron_count=len(layer_info['nodes']), is_final_layer=(layer_name == list(data.keys())[-1])))

# Start all threads
for thread in neurons + layers + coordinators:
    thread.start()
# Out:
# ✅ Activated Neuron 1 in layer_0 for image 2
# ✅ Activated Neuron 7 in layer_0 for image 2
# ✅ Activated Neuron 0 in layer_0 for image 2
# ✅ Activated Neuron 2 in layer_0 for image 2
# ✅ Activated Neuron 3 in layer_0 for image 2
# ✅ Activated Neuron 5 in layer_0 for image 2
# ✅ Activated Neuron 4 in layer_0 for image 2
# ✅ Activated Neuron 6 in layer_0 for image 2
# ✅ Activated Neuron 8 in layer_0 for image 2
# ✅ Activated Neuron 15 in layer_0 for image 2
# ✅ Activated Neuron 10 in layer_0 for image 2
# ✅ Activated Neuron 12 in layer_0 for image 2
# ✅ Activated Neuron 14 in layer_0 for image 2
# ✅ Activated Neuron 11 in layer_0 for image 2
# ✅ Activated Neuron 9 in layer_0 for image 2
# ✅ Activated Neuron 13 in layer_0 for image 2
# 🔍 Received output for Neuron 5 and image 2: 0.0
# 🔍 Received output for Neuron 3 and image 2: 4.391325292455447
# 🔍 Received output for Neuron 4 and image 2: 0.0
# 🔍 Received output for Neuron 1 and image 2: 0.031371611418220535
# ✅ Activated Neuron 22 in layer_0 for image 2
# ✅ Activated Neuron 23 in layer_0 for image 2
# ✅ Activated Neuron 18 in layer_0 for image 2
# ✅ Activated Neuron 19 in layer_0 for image 2
# ✅ Activated Neuron 17 in layer_0 for image 2
# ✅ Activated Neuron 20 in layer_0 for image 2
# ✅ Activated Neuron 21 in layer_0 for image 2
# ✅ Activated Neuron 16 in layer_0 for image 2
# 🔍 Received output for Neuron 6 and image 2: 0.0
# 🔍 Received output for Neuron 7 and image 2: 0.0
# ✅ Activated Neuron 29 in layer_0 for image 2
# ✅ Activated Neuron 24 in layer_0 for image 2
# ✅ Activated Neuron 30 in layer_0 for image 2
# ✅ Activated Neuron 31 in layer_0 for image 2
# ✅ Activated Neuron 26 in layer_0 for image 2
# ✅ Activated Neuron 25 in layer_0 for image 2
# 🔍 Received output for Neuron 14 and image 2: 0.0
# 🔍 Received output for Neuron 2 and image 2: 2.1769534512291875
# 🔍 Received output for Neuron 9 and image 2: 0.0
# 🔍 Received output for Neuron 15 and image 2: 3.7491586261972074
# 🔍 Received output for Neuron 10 and image 2: 0.0
# 🔍 Received output for Neuron 11 and image 2: 0.0
# 🔍 Received output for Neuron 13 and image 2: 0.0
# 🔍 Received output for Neuron 0 and image 2: 0.2647896860341992
# 🔍 Received output for Neuron 8 and image 2: 3.197959659910226
# 🔍 Received output for Neuron 12 and image 2: 0.0
# ✅ Activated Neuron 27 in layer_0 for image 2
# ✅ Activated Neuron 35 in layer_0 for image 2
# ✅ Activated Neuron 28 in layer_0 for image 2
# ✅ Activated Neuron 32 in layer_0 for image 2
# ✅ Activated Neuron 34 in layer_0 for image 2
# ✅ Activated Neuron 37 in layer_0 for image 2
# ✅ Activated Neuron 36 in layer_0 for image 2
# ✅ Activated Neuron 33 in layer_0 for image 2
# 🔍 Received output for Neuron 17 and image 2: 3.926425711040047
# 🔍 Received output for Neuron 23 and image 2: 0.0
# 🔍 Received output for Neuron 18 and image 2: 0.0
# 🔍 Received output for Neuron 19 and image 2: 0.0
# ✅ Activated Neuron 43 in layer_0 for image 2
# ✅ Activated Neuron 45 in layer_0 for image 2
# ✅ Activated Neuron 39 in layer_0 for image 2
# ✅ Activated Neuron 40 in layer_0 for image 2
# ✅ Activated Neuron 41 in layer_0 for image 2
# ✅ Activated Neuron 42 in layer_0 for image 2
# ✅ Activated Neuron 38 in layer_0 for image 2
# ✅ Activated Neuron 44 in layer_0 for image 2
# 🔍 Received output for Neuron 22 and image 2: 0.7489851799098646
# 🔍 Received output for Neuron 29 and image 2: 0.0
# 🔍 Received output for Neuron 16 and image 2: 0.0
# 🔍 Received output for Neuron 20 and image 2: 0.5496832691983783
# 🔍 Received output for Neuron 21 and image 2: 0.0
# 🔍 Received output for Neuron 31 and image 2: 0.0
# 🔍 Received output for Neuron 28 and image 2: 6.976513229572072
# ✅ Activated Neuron 47 in layer_0 for image 2
# ✅ Activated Neuron 48 in layer_0 for image 2
# ✅ Activated Neuron 50 in layer_0 for image 2
# ✅ Activated Neuron 51 in layer_0 for image 2
# ✅ Activated Neuron 53 in layer_0 for image 2
# ✅ Activated Neuron 49 in layer_0 for image 2
# ✅ Activated Neuron 46 in layer_0 for image 2
# ✅ Activated Neuron 52 in layer_0 for image 2
# 🔍 Received output for Neuron 26 and image 2: 0.0
# 🔍 Received output for Neuron 25 and image 2: 0.0
# 🔍 Received output for Neuron 24 and image 2: 4.094255046415741
# 🔍 Received output for Neuron 30 and image 2: 0.049688762820784216
# 🔍 Received output for Neuron 37 and image 2: 0.0
# 🔍 Received output for Neuron 27 and image 2: 0.0
# 🔍 Received output for Neuron 36 and image 2: 0.0
# ✅ Activated Neuron 55 in layer_0 for image 2
# ✅ Activated Neuron 57 in layer_0 for image 2
# ✅ Activated Neuron 58 in layer_0 for image 2
# ✅ Activated Neuron 59 in layer_0 for image 2
# ✅ Activated Neuron 54 in layer_0 for image 2
# ✅ Activated Neuron 56 in layer_0 for image 2
# ✅ Activated Neuron 60 in layer_0 for image 2
# ✅ Activated Neuron 61 in layer_0 for image 2
# 🔍 Received output for Neuron 42 and image 2: 6.916702342629901
# 🔍 Received output for Neuron 45 and image 2: 0.0
# 🔍 Received output for Neuron 39 and image 2: 0.0
# 🔍 Received output for Neuron 38 and image 2: 0.0
# 🔍 Received output for Neuron 44 and image 2: 0.0
# 🔍 Received output for Neuron 41 and image 2: 0.0
# 🔍 Received output for Neuron 40 and image 2: 0.0
# 🔍 Received output for Neuron 43 and image 2: 0.0
# ✅ Activated Neuron 69 in layer_0 for image 2
# ✅ Activated Neuron 64 in layer_0 for image 2
# ✅ Activated Neuron 65 in layer_0 for image 2
# ✅ Activated Neuron 66 in layer_0 for image 2
# ✅ Activated Neuron 67 in layer_0 for image 2
# ✅ Activated Neuron 62 in layer_0 for image 2
# ✅ Activated Neuron 68 in layer_0 for image 2
# ✅ Activated Neuron 63 in layer_0 for image 2
# 🔍 Received output for Neuron 35 and image 2: 2.5367952087823307
# 🔍 Received output for Neuron 33 and image 2: 0.0
# 🔍 Received output for Neuron 34 and image 2: 0.0
# 🔍 Received output for Neuron 32 and image 2: 0.0
# 🔍 Received output for Neuron 49 and image 2: 0.0
# ✅ Activated Neuron 70 in layer_0 for image 2
# ✅ Activated Neuron 74 in layer_0 for image 2
# ✅ Activated Neuron 72 in layer_0 for image 2
# ✅ Activated Neuron 71 in layer_0 for image 2
# ✅ Activated Neuron 73 in layer_0 for image 2
# ✅ Activated Neuron 77 in layer_0 for image 2
# ✅ Activated Neuron 75 in layer_0 for image 2
# ✅ Activated Neuron 76 in layer_0 for image 2
# 🔍 Received output for Neuron 48 and image 2: 2.5293580758646907
# 🔍 Received output for Neuron 53 and image 2: 0.0
# 🔍 Received output for Neuron 51 and image 2: 0.0
# 🔍 Received output for Neuron 50 and image 2: 0.0
# 🔍 Received output for Neuron 47 and image 2: 0.0
# ✅ Activated Neuron 78 in layer_0 for image 2
# ✅ Activated Neuron 83 in layer_0 for image 2
# ✅ Activated Neuron 84 in layer_0 for image 2
# ✅ Activated Neuron 81 in layer_0 for image 2
# ✅ Activated Neuron 85 in layer_0 for image 2
# ✅ Activated Neuron 79 in layer_0 for image 2
# ✅ Activated Neuron 80 in layer_0 for image 2
# ✅ Activated Neuron 82 in layer_0 for image 2
# 🔍 Received output for Neuron 57 and image 2: 0.0
# 🔍 Received output for Neuron 55 and image 2: 2.1214264480101637
# 🔍 Received output for Neuron 61 and image 2: 0.394399648058929
# 🔍 Received output for Neuron 58 and image 2: 5.590005948945845
# ✅ Activated Neuron 90 in layer_0 for image 2
# ✅ Activated Neuron 87 in layer_0 for image 2
# ✅ Activated Neuron 93 in layer_0 for image 2
# ✅ Activated Neuron 88 in layer_0 for image 2
# ✅ Activated Neuron 89 in layer_0 for image 2
# ✅ Activated Neuron 86 in layer_0 for image 2
# ✅ Activated Neuron 92 in layer_0 for image 2
# ✅ Activated Neuron 91 in layer_0 for image 2
# 🔍 Received output for Neuron 54 and image 2: 0.748275181713743
# 🔍 Received output for Neuron 60 and image 2: 2.2131844366300335
# 🔍 Received output for Neuron 56 and image 2: 0.0
# 🔍 Received output for Neuron 52 and image 2: 0.0
# 🔍 Received output for Neuron 62 and image 2: 0.0
# 🔍 Received output for Neuron 59 and image 2: 1.6319348277254424
# 🔍 Received output for Neuron 46 and image 2: 0.0
# ✅ Activated Neuron 94 in layer_0 for image 2
# ✅ Activated Neuron 95 in layer_0 for image 2
# ✅ Activated Neuron 96 in layer_0 for image 2
# ✅ Activated Neuron 98 in layer_0 for image 2
# ✅ Activated Neuron 97 in layer_0 for image 2
# ✅ Activated Neuron 99 in layer_0 for image 2
# ✅ Activated Neuron 100 in layer_0 for image 2
# ✅ Activated Neuron 101 in layer_0 for image 2
# 🔍 Received output for Neuron 66 and image 2: 0.0
# 🔍 Received output for Neuron 65 and image 2: 3.817662720266078
# 🔍 Received output for Neuron 63 and image 2: 0.0
# 🔍 Received output for Neuron 67 and image 2: 0.0
# ✅ Activated Neuron 102 in layer_0 for image 2
# ✅ Activated Neuron 103 in layer_0 for image 2
# ✅ Activated Neuron 105 in layer_0 for image 2
# ✅ Activated Neuron 106 in layer_0 for image 2
# ✅ Activated Neuron 107 in layer_0 for image 2
# ✅ Activated Neuron 108 in layer_0 for image 2
# ✅ Activated Neuron 109 in layer_0 for image 2
# ✅ Activated Neuron 104 in layer_0 for image 2
# 🔍 Received output for Neuron 77 and image 2: 4.6791564466918185
# 🔍 Received output for Neuron 70 and image 2: 0.0
# 🔍 Received output for Neuron 75 and image 2: 0.0
# 🔍 Received output for Neuron 74 and image 2: 0.0
# 🔍 Received output for Neuron 64 and image 2: 0.0
# 🔍 Received output for Neuron 76 and image 2: 0.0
# 🔍 Received output for Neuron 72 and image 2: 0.0
# ✅ Activated Neuron 110 in layer_0 for image 2
# ✅ Activated Neuron 113 in layer_0 for image 2
# ✅ Activated Neuron 115 in layer_0 for image 2
# ✅ Activated Neuron 116 in layer_0 for image 2
# ✅ Activated Neuron 112 in layer_0 for image 2
# ✅ Activated Neuron 111 in layer_0 for image 2
# ✅ Activated Neuron 114 in layer_0 for image 2
# ✅ Activated Neuron 117 in layer_0 for image 2
# 🔍 Received output for Neuron 73 and image 2: 0.0
# 🔍 Received output for Neuron 78 and image 2: 7.201951008054515
# 🔍 Received output for Neuron 71 and image 2: 0.0
# 🔍 Received output for Neuron 84 and image 2: 0.0
# 🔍 Received output for Neuron 83 and image 2: 0.9928437019856649
# 🔍 Received output for Neuron 81 and image 2: 0.0
# 🔍 Received output for Neuron 79 and image 2: 1.5446053819606809
# 🔍 Received output for Neuron 82 and image 2: 0.0
# ✅ Activated Neuron 119 in layer_0 for image 2
# ✅ Activated Neuron 120 in layer_0 for image 2
# ✅ Activated Neuron 122 in layer_0 for image 2
# ✅ Activated Neuron 123 in layer_0 for image 2
# ✅ Activated Neuron 124 in layer_0 for image 2
# ✅ Activated Neuron 125 in layer_0 for image 2
# ✅ Activated Neuron 118 in layer_0 for image 2
# ✅ Activated Neuron 121 in layer_0 for image 2
# 🔍 Received output for Neuron 93 and image 2: 0.0
# 🔍 Received output for Neuron 87 and image 2: 0.0
# 🔍 Received output for Neuron 89 and image 2: 0.0
# 🔍 Received output for Neuron 85 and image 2: 0.0
# 🔍 Received output for Neuron 80 and image 2: 0.0
# 🔍 Received output for Neuron 68 and image 2: 0.09232164487610062
# 🔍 Received output for Neuron 69 and image 2: 0.0
# 🔍 Received output for Neuron 86 and image 2: 0.0
# 🔍 Received output for Neuron 92 and image 2: 0.0
# 🔍 Received output for Neuron 94 and image 2: 2.020697122735246
# ✅ Activated Neuron 127 in layer_0 for image 2
# ✅ Activated Neuron 126 in layer_0 for image 2
# ✅ Activated Neuron 0 in layer_0 for image 1
# ✅ Activated Neuron 4 in layer_0 for image 1
# ✅ Activated Neuron 1 in layer_0 for image 1
# ✅ Activated Neuron 3 in layer_0 for image 1
# ✅ Activated Neuron 2 in layer_0 for image 1
# 🔍 Received output for Neuron 95 and image 2: 0.0
# ✅ Activated Neuron 5 in layer_0 for image 1
# 🔍 Received output for Neuron 98 and image 2: 0.0
# 🔍 Received output for Neuron 96 and image 2: 0.0
# 🔍 Received output for Neuron 101 and image 2: 0.005829127567029024
# 🔍 Received output for Neuron 108 and image 2: 0.0
# 🔍 Received output for Neuron 114 and image 2: 9.095843829423664
# ✅ Activated Neuron 7 in layer_0 for image 1
# ✅ Activated Neuron 8 in layer_0 for image 1
# ✅ Activated Neuron 9 in layer_0 for image 1
# ✅ Activated Neuron 10 in layer_0 for image 1
# ✅ Activated Neuron 11 in layer_0 for image 1
# ✅ Activated Neuron 12 in layer_0 for image 1
# ✅ Activated Neuron 6 in layer_0 for image 1
# ✅ Activated Neuron 13 in layer_0 for image 1
# 🔍 Received output for Neuron 97 and image 2: 0.0
# 🔍 Received output for Neuron 116 and image 2: 3.501806495508082
# 🔍 Received output for Neuron 113 and image 2: 0.0
# 🔍 Received output for Neuron 107 and image 2: 0.0
# ✅ Activated Neuron 14 in layer_0 for image 1
# ✅ Activated Neuron 15 in layer_0 for image 1
# ✅ Activated Neuron 21 in layer_0 for image 1
# ✅ Activated Neuron 16 in layer_0 for image 1
# ✅ Activated Neuron 20 in layer_0 for image 1
# ✅ Activated Neuron 18 in layer_0 for image 1
# ✅ Activated Neuron 17 in layer_0 for image 1
# ✅ Activated Neuron 19 in layer_0 for image 1
# 🔍 Received output for Neuron 111 and image 2: 4.590815113286977
# 🔍 Received output for Neuron 104 and image 2: 4.93043268034805
# 🔍 Received output for Neuron 99 and image 2: 0.0
# 🔍 Received output for Neuron 102 and image 2: 0.0
# 🔍 Received output for Neuron 103 and image 2: 4.875721908451294
# ✅ Activated Neuron 23 in layer_0 for image 1
# ✅ Activated Neuron 26 in layer_0 for image 1
# ✅ Activated Neuron 22 in layer_0 for image 1
# ✅ Activated Neuron 25 in layer_0 for image 1
# ✅ Activated Neuron 24 in layer_0 for image 1
# ✅ Activated Neuron 27 in layer_0 for image 1
# ✅ Activated Neuron 28 in layer_0 for image 1
# ✅ Activated Neuron 29 in layer_0 for image 1
# 🔍 Received output for Neuron 112 and image 2: 0.0
# 🔍 Received output for Neuron 109 and image 2: 0.0
# 🔍 Received output for Neuron 106 and image 2: 1.6400491641384263
# 🔍 Received output for Neuron 117 and image 2: 4.067854293719213
# 🔍 Received output for Neuron 110 and image 2: 0.6165651760542142
# ✅ Activated Neuron 30 in layer_0 for image 1
# ✅ Activated Neuron 36 in layer_0 for image 1
# ✅ Activated Neuron 37 in layer_0 for image 1
# ✅ Activated Neuron 31 in layer_0 for image 1
# ✅ Activated Neuron 32 in layer_0 for image 1
# ✅ Activated Neuron 33 in layer_0 for image 1
# ✅ Activated Neuron 34 in layer_0 for image 1
# 🔍 Received output for Neuron 100 and image 2: 0.0
# ✅ Activated Neuron 35 in layer_0 for image 1
# 🔍 Received output for Neuron 115 and image 2: 0.0
# 🔍 Received output for Neuron 105 and image 2: 0.0
# 🔍 Received output for Neuron 88 and image 2: 0.0
# 🔍 Received output for Neuron 90 and image 2: 0.8742084621584063
# 🔍 Received output for Neuron 0 and image 1: 1.8688847743489465
# ✅ Activated Neuron 38 in layer_0 for image 1
# ✅ Activated Neuron 39 in layer_0 for image 1
# ✅ Activated Neuron 40 in layer_0 for image 1
# ✅ Activated Neuron 41 in layer_0 for image 1
# ✅ Activated Neuron 44 in layer_0 for image 1
# ✅ Activated Neuron 42 in layer_0 for image 1
# ✅ Activated Neuron 43 in layer_0 for image 1
# 🔍 Received output for Neuron 91 and image 2: 0.0
# ✅ Activated Neuron 45 in layer_0 for image 1
# 🔍 Received output for Neuron 5 and image 1: 0.0
# 🔍 Received output for Neuron 3 and image 1: 0.0
# 🔍 Received output for Neuron 4 and image 1: 0.0
# 🔍 Received output for Neuron 122 and image 2: 0.0
# 🔍 Received output for Neuron 2 and image 1: 0.18511520004251847
# 🔍 Received output for Neuron 119 and image 2: 0.0
# 🔍 Received output for Neuron 126 and image 2: 0.0
# 🔍 Received output for Neuron 123 and image 2: 0.0
# 🔍 Received output for Neuron 1 and image 1: 0.0
# 🔍 Received output for Neuron 121 and image 2: 0.0
# 🔍 Received output for Neuron 127 and image 2: 0.0
# 🔍 Received output for Neuron 10 and image 1: 0.0
# 🔍 Received output for Neuron 11 and image 1: 0.0
# 🔍 Received output for Neuron 6 and image 1: 1.5490288624878272
# 🔍 Received output for Neuron 9 and image 1: 0.0
# 🔍 Received output for Neuron 13 and image 1: 0.0
# 🔍 Received output for Neuron 8 and image 1: 0.07973160386456324
# 🔍 Received output for Neuron 12 and image 1: 0.0
# 🔍 Received output for Neuron 7 and image 1: 0.0
# 🔍 Received output for Neuron 20 and image 1: 6.385523378747793
# ✅ Activated Neuron 53 in layer_0 for image 1
# ✅ Activated Neuron 48 in layer_0 for image 1
# ✅ Activated Neuron 49 in layer_0 for image 1
# ✅ Activated Neuron 50 in layer_0 for image 1
# ✅ Activated Neuron 46 in layer_0 for image 1
# ✅ Activated Neuron 47 in layer_0 for image 1
# ✅ Activated Neuron 52 in layer_0 for image 1
# ✅ Activated Neuron 51 in layer_0 for image 1
# 🔍 Received output for Neuron 21 and image 1: 0.0
# 🔍 Received output for Neuron 19 and image 1: 0.0
# 🔍 Received output for Neuron 18 and image 1: 0.0
# 🔍 Received output for Neuron 17 and image 1: 8.550638000545185
# 🔍 Received output for Neuron 14 and image 1: 0.0
# 🔍 Received output for Neuron 15 and image 1: 0.0
# 🔍 Received output for Neuron 16 and image 1: 0.0
# 🔍 Received output for Neuron 24 and image 1: 0.0
# 🔍 Received output for Neuron 22 and image 1: 8.994970717836344
# 🔍 Received output for Neuron 26 and image 1: 0.0
# 🔍 Received output for Neuron 27 and image 1: 0.0
# ✅ Activated Neuron 55 in layer_0 for image 1
# ✅ Activated Neuron 57 in layer_0 for image 1
# ✅ Activated Neuron 58 in layer_0 for image 1
# ✅ Activated Neuron 54 in layer_0 for image 1
# ✅ Activated Neuron 59 in layer_0 for image 1
# ✅ Activated Neuron 60 in layer_0 for image 1
# ✅ Activated Neuron 61 in layer_0 for image 1
# ✅ Activated Neuron 56 in layer_0 for image 1
# 🔍 Received output for Neuron 23 and image 1: 5.121950911728728
# 🔍 Received output for Neuron 28 and image 1: 4.44740902703968
# 🔍 Received output for Neuron 29 and image 1: 0.0
# 🔍 Received output for Neuron 25 and image 1: 0.0
# 🔍 Received output for Neuron 31 and image 1: 0.0
# 🔍 Received output for Neuron 33 and image 1: 0.0
# 🔍 Received output for Neuron 35 and image 1: 0.0
# 🔍 Received output for Neuron 30 and image 1: 0.0
# 🔍 Received output for Neuron 36 and image 1: 0.0
# 🔍 Received output for Neuron 124 and image 2: 0.0
# 🔍 Received output for Neuron 32 and image 1: 1.5386311261586698
# ✅ Activated Neuron 62 in layer_0 for image 1
# ✅ Activated Neuron 64 in layer_0 for image 1
# ✅ Activated Neuron 65 in layer_0 for image 1
# ✅ Activated Neuron 66 in layer_0 for image 1
# ✅ Activated Neuron 67 in layer_0 for image 1
# ✅ Activated Neuron 68 in layer_0 for image 1
# ✅ Activated Neuron 69 in layer_0 for image 1
# ✅ Activated Neuron 63 in layer_0 for image 1
# 🔍 Received output for Neuron 125 and image 2: 0.0
# 🔍 Received output for Neuron 118 and image 2: 0.0
# 🔍 Received output for Neuron 44 and image 1: 0.0
# 🔍 Received output for Neuron 120 and image 2: 3.9255170098256125
# 🟢 Aggregating outputs for image 2 on layer layer_0
# ✅ Activated Neuron 75 in layer_0 for image 1
# ✅ Activated Neuron 74 in layer_0 for image 1
# ✅ Activated Neuron 77 in layer_0 for image 1
# ✅ Activated Neuron 71 in layer_0 for image 1
# ✅ Activated Neuron 72 in layer_0 for image 1
# ✅ Activated Neuron 73 in layer_0 for image 1
# ✅ Activated Neuron 76 in layer_0 for image 1
# ✅ Activated Neuron 70 in layer_0 for image 1
# 🔍 Received output for Neuron 34 and image 1: 0.0
# 🔍 Received output for Neuron 45 and image 1: 0.0
# 🔍 Received output for Neuron 42 and image 1: 9.140240474475233
# 🔍 Received output for Neuron 40 and image 1: 0.0
# 🔍 Received output for Neuron 41 and image 1: 2.2881523634669847
# 🔍 Received output for Neuron 39 and image 1: 0.0
# 🔍 Received output for Neuron 47 and image 1: 0.0
# 🔍 Received output for Neuron 43 and image 1: 0.0
# 🔍 Received output for Neuron 38 and image 1: 0.0
# 🔍 Received output for Neuron 49 and image 1: 0.0
# 🔍 Received output for Neuron 52 and image 1: 0.0
# 🔍 Received output for Neuron 53 and image 1: 0.0
# 🔍 Received output for Neuron 48 and image 1: 6.833550390385879
# 🔍 Received output for Neuron 50 and image 1: 0.0
# 🔍 Received output for Neuron 51 and image 1: 5.031456394289796
# 🔍 Received output for Neuron 46 and image 1: 0.0
# 🔍 Received output for Neuron 59 and image 1: 0.0
# 🔍 Received output for Neuron 56 and image 1: 0.0
# 🔍 Received output for Neuron 54 and image 1: 5.835899212955684
# 🔍 Received output for Neuron 60 and image 1: 0.0
# 🔍 Received output for Neuron 55 and image 1: 4.687214475758783
# 🔍 Received output for Neuron 57 and image 1: 0.0
# 🔍 Received output for Neuron 61 and image 1: 1.814893781253189
# 🔍 Received output for Neuron 58 and image 1: 1.8702709853095802
# 🔍 Received output for Neuron 63 and image 1: 0.0
# 🔍 Received output for Neuron 37 and image 1: 0.0
# 🔍 Received output for Neuron 66 and image 1: 0.0
# 🔍 Received output for Neuron 69 and image 1: 0.0
# 🔍 Received output for Neuron 68 and image 1: 0.0
# 🚀 Activating next layer: layer_1 for image 2
# 🔍 Received output for Neuron 62 and image 1: 0.0
# 🔍 Received output for Neuron 64 and image 1: 0.0
# 🔍 Received output for Neuron 67 and image 1: 4.293497453909125
# 🔍 Received output for Neuron 72 and image 1: 0.0
# 🔍 Received output for Neuron 65 and image 1: 0.0
# 🔍 Received output for Neuron 71 and image 1: 0.0
# ✅ Activated Neuron 81 in layer_0 for image 1
# ✅ Activated Neuron 83 in layer_0 for image 1
# ✅ Activated Neuron 84 in layer_0 for image 1
# 🔍 Received output for Neuron 76 and image 1: 0.0
# 🔍 Received output for Neuron 74 and image 1: 0.0
# ✅ Activated Neuron 85 in layer_0 for image 1
# ✅ Activated Neuron 79 in layer_0 for image 1
# ✅ Activated Neuron 80 in layer_0 for image 1
# ✅ Activated Neuron 78 in layer_0 for image 1
# ✅ Activated Neuron 82 in layer_0 for image 1
# 🔍 Received output for Neuron 75 and image 1: 0.0
# 🔍 Received output for Neuron 73 and image 1: 0.0
# 🔍 Received output for Neuron 70 and image 1: 0.0
# 🔍 Received output for Neuron 77 and image 1: 14.206964991464677
# 🔍 Received output for Neuron 80 and image 1: 0.0
# ✅ Activated Neuron 4 in layer_1 for image 2
# ✅ Activated Neuron 2 in layer_1 for image 2
# ✅ Activated Neuron 6 in layer_1 for image 2
# ✅ Activated Neuron 3 in layer_1 for image 2
# ✅ Activated Neuron 5 in layer_1 for image 2
# ✅ Activated Neuron 7 in layer_1 for image 2
# ✅ Activated Neuron 1 in layer_1 for image 2
# ✅ Activated Neuron 0 in layer_1 for image 2
# 🔍 Received output for Neuron 82 and image 1: 1.2150718441174053
# 🔍 Received output for Neuron 79 and image 1: 1.8109701447921709
# ✅ Activated Neuron 87 in layer_0 for image 1
# ✅ Activated Neuron 89 in layer_0 for image 1
# ✅ Activated Neuron 92 in layer_0 for image 1
# ✅ Activated Neuron 86 in layer_0 for image 1
# ✅ Activated Neuron 91 in layer_0 for image 1
# ✅ Activated Neuron 90 in layer_0 for image 1
# ✅ Activated Neuron 93 in layer_0 for image 1
# ✅ Activated Neuron 88 in layer_0 for image 1
# 🔍 Received output for Neuron 85 and image 1: 0.0
# 🔍 Received output for Neuron 84 and image 1: 0.0
# 🔍 Received output for Neuron 83 and image 1: 0.0
# ✅ Activated Neuron 9 in layer_1 for image 2
# ✅ Activated Neuron 8 in layer_1 for image 2
# 🔍 Received output for Neuron 81 and image 1: 0.0
# 🔍 Received output for Neuron 88 and image 1: 0.0
# 🔍 Received output for Neuron 78 and image 1: 0.0
# ✅ Activated Neuron 94 in layer_0 for image 1
# ✅ Activated Neuron 99 in layer_0 for image 1
# ✅ Activated Neuron 100 in layer_0 for image 1
# ✅ Activated Neuron 101 in layer_0 for image 1
# ✅ Activated Neuron 95 in layer_0 for image 1
# ✅ Activated Neuron 96 in layer_0 for image 1
# ✅ Activated Neuron 97 in layer_0 for image 1
# ✅ Activated Neuron 98 in layer_0 for image 1
# 🔍 Received output for Neuron 87 and image 1: 5.243300790715361
# 🔍 Received output for Neuron 91 and image 1: 0.0
# 🔍 Received output for Neuron 89 and image 1: 0.0
# 🔍 Received output for Neuron 7 and image 2: -0.0015783463739884596
# 🔍 Received output for Neuron 92 and image 1: 0.0
# 🔍 Received output for Neuron 90 and image 1: 0.19557434822592057
# 🔍 Received output for Neuron 86 and image 1: 0.0
# ✅ Activated Neuron 102 in layer_0 for image 1
# ✅ Activated Neuron 103 in layer_0 for image 1
# ✅ Activated Neuron 104 in layer_0 for image 1
# ✅ Activated Neuron 105 in layer_0 for image 1
# ✅ Activated Neuron 106 in layer_0 for image 1
# ✅ Activated Neuron 107 in layer_0 for image 1
# ✅ Activated Neuron 108 in layer_0 for image 1
# ✅ Activated Neuron 109 in layer_0 for image 1
# 🔍 Received output for Neuron 0 and image 2: -7.946612480963191
# 🔍 Received output for Neuron 93 and image 1: 0.0
# 🔍 Received output for Neuron 2 and image 2: -1.8329778696321806
# 🔍 Received output for Neuron 6 and image 2: -2.7462809191666566
# 🔍 Received output for Neuron 9 and image 2: -6.002163032324886
# 🔍 Received output for Neuron 3 and image 2: -4.6039716658664895
# 🔍 Received output for Neuron 99 and image 1: 0.0
# ✅ Activated Neuron 112 in layer_0 for image 1
# ✅ Activated Neuron 111 in layer_0 for image 1
# ✅ Activated Neuron 113 in layer_0 for image 1
# ✅ Activated Neuron 114 in layer_0 for image 1
# ✅ Activated Neuron 115 in layer_0 for image 1
# ✅ Activated Neuron 116 in layer_0 for image 1
# ✅ Activated Neuron 110 in layer_0 for image 1
# 🔍 Received output for Neuron 5 and image 2: -4.015411606677464
# 🔍 Received output for Neuron 96 and image 1: 0.0
# 🔍 Received output for Neuron 1 and image 2: 3.8651437957351784
# 🔍 Received output for Neuron 98 and image 1: 0.0
# 🔍 Received output for Neuron 4 and image 2: -3.1335432391886666
# 🔍 Received output for Neuron 94 and image 1: 4.999135166536048
# 🔍 Received output for Neuron 101 and image 1: 0.0
# 🔍 Received output for Neuron 97 and image 1: 0.0
# 🔍 Received output for Neuron 8 and image 2: -0.2995561323425415
# 🟢 Aggregating outputs for image 2 on layer layer_1
# 🔍 Received output for Neuron 102 and image 1: 0.0
# 🔍 Received output for Neuron 103 and image 1: 0.0
# 🔍 Received output for Neuron 106 and image 1: 4.807984956311325
# 🔍 Received output for Neuron 95 and image 1: 0.0
# 🔍 Received output for Neuron 105 and image 1: 2.217096148314303
# ✅ Activated Neuron 124 in layer_0 for image 1
# ✅ Activated Neuron 118 in layer_0 for image 1
# ✅ Activated Neuron 120 in layer_0 for image 1
# ✅ Activated Neuron 121 in layer_0 for image 1
# 🔍 Received output for Neuron 104 and image 1: 0.0
# 🔍 Received output for Neuron 107 and image 1: 0.0
# 🔍 Received output for Neuron 100 and image 1: 0.0
# ✅ Activated Neuron 117 in layer_0 for image 1
# ✅ Activated Neuron 119 in layer_0 for image 1
# ✅ Activated Neuron 123 in layer_0 for image 1
# ✅ Activated Neuron 122 in layer_0 for image 1
# 🔍 Received output for Neuron 109 and image 1: 0.0
# 🔍 Received output for Neuron 108 and image 1: 0.0
# 🔍 Received output for Neuron 111 and image 1: 0.0
# 🔍 Received output for Neuron 113 and image 1: 5.592418360255667
# 🔍 Received output for Neuron 110 and image 1: 7.972506326184247
# 🔍 Received output for Neuron 117 and image 1: 0.0
# 🔍 Received output for Neuron 112 and image 1: 0.0
# 🔍 Received output for Neuron 114 and image 1: 9.986496783927617
# 🔍 Received output for Neuron 115 and image 1: 0.0
# 🔍 Received output for Neuron 123 and image 1: 0.0
# 🔍 Received output for Neuron 121 and image 1: 0.0
# 🎯 Final Prediction for image 2: 1
# ✅ Activated Neuron 4 in layer_0 for image 0
# ✅ Activated Neuron 127 in layer_0 for image 1
# ✅ Activated Neuron 0 in layer_0 for image 0
# ✅ Activated Neuron 1 in layer_0 for image 0
# ✅ Activated Neuron 125 in layer_0 for image 1
# ✅ Activated Neuron 2 in layer_0 for image 0
# ✅ Activated Neuron 3 in layer_0 for image 0
# ✅ Activated Neuron 126 in layer_0 for image 1
# 🔍 Received output for Neuron 120 and image 1: 5.87764257973972
# 🔍 Received output for Neuron 119 and image 1: 0.0
# 🔍 Received output for Neuron 116 and image 1: 7.3342666949390445
# 🔍 Received output for Neuron 124 and image 1: 3.941282662610277
# 🔍 Received output for Neuron 118 and image 1: 0.0
# 🔍 Received output for Neuron 122 and image 1: 0.0
# 🔍 Received output for Neuron 126 and image 1: 0.0
# 🔍 Received output for Neuron 125 and image 1: 0.0
# 🔍 Received output for Neuron 0 and image 0: 0.0
# 🔍 Received output for Neuron 3 and image 0: 0.0
# 🔍 Received output for Neuron 4 and image 0: 3.5262670475389415
# ✅ Activated Neuron 5 in layer_0 for image 0
# ✅ Activated Neuron 6 in layer_0 for image 0
# ✅ Activated Neuron 8 in layer_0 for image 0
# ✅ Activated Neuron 9 in layer_0 for image 0
# ✅ Activated Neuron 10 in layer_0 for image 0
# ✅ Activated Neuron 11 in layer_0 for image 0
# ✅ Activated Neuron 12 in layer_0 for image 0
# 🔍 Received output for Neuron 2 and image 0: 2.2311119535381727
# 🔍 Received output for Neuron 1 and image 0: 1.0285565756125576
# ✅ Activated Neuron 7 in layer_0 for image 0
# 🔍 Received output for Neuron 127 and image 1: 0.0
# 🟢 Aggregating outputs for image 1 on layer layer_0
# 🔍 Received output for Neuron 5 and image 0: 0.0
# 🔍 Received output for Neuron 10 and image 0: 0.0
# 🔍 Received output for Neuron 9 and image 0: 0.0
# 🔍 Received output for Neuron 6 and image 0: 3.7727046527839527
# 🔍 Received output for Neuron 7 and image 0: 0.0
# 🔍 Received output for Neuron 12 and image 0: 3.2751154340261444
# 🚀 Activating next layer: layer_1 for image 1
# 🔍 Received output for Neuron 8 and image 0: 4.321642683619148
# 🔍 Received output for Neuron 11 and image 0: 0.0
# ✅ Activated Neuron 0 in layer_1 for image 1
# ✅ Activated Neuron 1 in layer_1 for image 1
# ✅ Activated Neuron 15 in layer_0 for image 0
# ✅ Activated Neuron 17 in layer_0 for image 0
# ✅ Activated Neuron 18 in layer_0 for image 0
# ✅ Activated Neuron 19 in layer_0 for image 0
# ✅ Activated Neuron 20 in layer_0 for image 0
# ✅ Activated Neuron 14 in layer_0 for image 0
# ✅ Activated Neuron 13 in layer_0 for image 0
# ✅ Activated Neuron 6 in layer_1 for image 1
# ✅ Activated Neuron 2 in layer_1 for image 1
# ✅ Activated Neuron 16 in layer_0 for image 0
# 🔍 Received output for Neuron 18 and image 0: 7.414502214991407🔍 Received output for Neuron 5 and image 1: -2.97403239670082
#
# 🔍 Received output for Neuron 17 and image 0: 0.0
# 🔍 Received output for Neuron 15 and image 0: 7.071286191568182
# 🔍 Received output for Neuron 14 and image 0: 0.0
# 🔍 Received output for Neuron 16 and image 0: 0.0
# 🔍 Received output for Neuron 8 and image 1: -0.6595345915203961
# 🔍 Received output for Neuron 0 and image 1: -0.85861474887442
# 🔍 Received output for Neuron 6 and image 1: -0.7163351298627791
# 🔍 Received output for Neuron 4 and image 1: -13.354509610138908
# 🔍 Received output for Neuron 2 and image 1: 10.39621737730393
# 🔍 Received output for Neuron 1 and image 1: 1.3325118118382608
# 🔍 Received output for Neuron 3 and image 1: 0.9121538665714213
# 🔍 Received output for Neuron 19 and image 0: 0.0
# ✅ Activated Neuron 28 in layer_0 for image 0
# ✅ Activated Neuron 23 in layer_0 for image 0
# ✅ Activated Neuron 26 in layer_0 for image 0
# ✅ Activated Neuron 25 in layer_0 for image 0
# ✅ Activated Neuron 21 in layer_0 for image 0
# ✅ Activated Neuron 27 in layer_0 for image 0
# ✅ Activated Neuron 22 in layer_0 for image 0
# ✅ Activated Neuron 24 in layer_0 for image 0
# 🔍 Received output for Neuron 9 and image 1: -16.28722297237999
# 🔍 Received output for Neuron 7 and image 1: -8.262975222068205
# 🟢 Aggregating outputs for image 1 on layer layer_1
# 🔍 Received output for Neuron 13 and image 0: 0.0
# ✅ Activated Neuron 5 in layer_1 for image 1
# ✅ Activated Neuron 7 in layer_1 for image 1
# ✅ Activated Neuron 3 in layer_1 for image 1
# ✅ Activated Neuron 4 in layer_1 for image 1
# ✅ Activated Neuron 8 in layer_1 for image 1
# ✅ Activated Neuron 9 in layer_1 for image 1
# 🔍 Received output for Neuron 20 and image 0: 1.9019663169299645
# 🔍 Received output for Neuron 28 and image 0: 0.0
# 🔍 Received output for Neuron 21 and image 0: 0.0
# 🔍 Received output for Neuron 24 and image 0: 2.8720249810655085
# 🔍 Received output for Neuron 23 and image 0: 0.0
# 🔍 Received output for Neuron 25 and image 0: 0.0
# 🎯 Final Prediction for image 1: 2
# 🔍 Received output for Neuron 26 and image 0: 2.131010086261625
# 🔍 Received output for Neuron 22 and image 0: 6.62872909093244
# 🔍 Received output for Neuron 27 and image 0: 0.0
# ✅ Activated Neuron 29 in layer_0 for image 0
# ✅ Activated Neuron 30 in layer_0 for image 0
# ✅ Activated Neuron 32 in layer_0 for image 0
# ✅ Activated Neuron 33 in layer_0 for image 0
# ✅ Activated Neuron 34 in layer_0 for image 0
# ✅ Activated Neuron 35 in layer_0 for image 0
# ✅ Activated Neuron 36 in layer_0 for image 0
# ✅ Activated Neuron 31 in layer_0 for image 0
# 🔍 Received output for Neuron 36 and image 0: 0.0
# 🔍 Received output for Neuron 35 and image 0: 0.0
# 🔍 Received output for Neuron 33 and image 0: 0.0
# 🔍 Received output for Neuron 29 and image 0: 0.0
# 🔍 Received output for Neuron 31 and image 0: 0.0
# 🔍 Received output for Neuron 34 and image 0: 0.0
# 🔍 Received output for Neuron 32 and image 0: 4.786088693407803
# 🔍 Received output for Neuron 30 and image 0: 7.153803209011044
# ✅ Activated Neuron 38 in layer_0 for image 0
# ✅ Activated Neuron 40 in layer_0 for image 0
# ✅ Activated Neuron 41 in layer_0 for image 0
# ✅ Activated Neuron 42 in layer_0 for image 0
# ✅ Activated Neuron 43 in layer_0 for image 0
# ✅ Activated Neuron 44 in layer_0 for image 0
# ✅ Activated Neuron 37 in layer_0 for image 0
# ✅ Activated Neuron 39 in layer_0 for image 0
# 🔍 Received output for Neuron 38 and image 0: 0.0
# 🔍 Received output for Neuron 43 and image 0: 0.0
# 🔍 Received output for Neuron 42 and image 0: 0.0
# 🔍 Received output for Neuron 41 and image 0: 4.420482435587142
# 🔍 Received output for Neuron 37 and image 0: 0.0
# 🔍 Received output for Neuron 44 and image 0: 0.0
# 🔍 Received output for Neuron 40 and image 0: 0.0
# 🔍 Received output for Neuron 39 and image 0: 2.4277216552330785
# ✅ Activated Neuron 49 in layer_0 for image 0
# ✅ Activated Neuron 48 in layer_0 for image 0
# ✅ Activated Neuron 50 in layer_0 for image 0
# ✅ Activated Neuron 52 in layer_0 for image 0
# ✅ Activated Neuron 51 in layer_0 for image 0
# ✅ Activated Neuron 46 in layer_0 for image 0
# ✅ Activated Neuron 45 in layer_0 for image 0
# ✅ Activated Neuron 47 in layer_0 for image 0
# 🔍 Received output for Neuron 50 and image 0: 6.462321041498492
# 🔍 Received output for Neuron 47 and image 0: 0.0
# 🔍 Received output for Neuron 48 and image 0: 0.0
# 🔍 Received output for Neuron 46 and image 0: 0.028291041741794615
# 🔍 Received output for Neuron 49 and image 0: 0.0
# 🔍 Received output for Neuron 45 and image 0: 0.0
# 🔍 Received output for Neuron 51 and image 0: 0.0
# 🔍 Received output for Neuron 52 and image 0: 0.0
# ✅ Activated Neuron 54 in layer_0 for image 0
# ✅ Activated Neuron 56 in layer_0 for image 0
# ✅ Activated Neuron 58 in layer_0 for image 0
# ✅ Activated Neuron 59 in layer_0 for image 0
# ✅ Activated Neuron 60 in layer_0 for image 0
# ✅ Activated Neuron 55 in layer_0 for image 0
# ✅ Activated Neuron 53 in layer_0 for image 0
# ✅ Activated Neuron 57 in layer_0 for image 0
# 🔍 Received output for Neuron 58 and image 0: 0.0
# ✅ Activated Neuron 68 in layer_0 for image 0
# ✅ Activated Neuron 64 in layer_0 for image 0
# ✅ Activated Neuron 63 in layer_0 for image 0
# ✅ Activated Neuron 66 in layer_0 for image 0
# ✅ Activated Neuron 65 in layer_0 for image 0
# ✅ Activated Neuron 61 in layer_0 for image 0
# ✅ Activated Neuron 67 in layer_0 for image 0
# ✅ Activated Neuron 62 in layer_0 for image 0
# 🔍 Received output for Neuron 55 and image 0: 1.9162726751934027
# 🔍 Received output for Neuron 59 and image 0: 5.675490357646747
# 🔍 Received output for Neuron 57 and image 0: 0.0
# 🔍 Received output for Neuron 54 and image 0: 0.0
# 🔍 Received output for Neuron 60 and image 0: 4.047010903924251
# 🔍 Received output for Neuron 56 and image 0: 0.0
# 🔍 Received output for Neuron 53 and image 0: 0.0
# 🔍 Received output for Neuron 63 and image 0: 3.8851744022399095
# 🔍 Received output for Neuron 62 and image 0: 3.0157681172587507
# 🔍 Received output for Neuron 64 and image 0: 10.017956033178933
# 🔍 Received output for Neuron 67 and image 0: 0.0
# 🔍 Received output for Neuron 61 and image 0: 0.0
# 🔍 Received output for Neuron 68 and image 0: 0.0
# 🔍 Received output for Neuron 65 and image 0: 4.618611006897984
# 🔍 Received output for Neuron 66 and image 0: 0.0
# ✅ Activated Neuron 70 in layer_0 for image 0
# ✅ Activated Neuron 74 in layer_0 for image 0
# ✅ Activated Neuron 69 in layer_0 for image 0
# ✅ Activated Neuron 72 in layer_0 for image 0
# ✅ Activated Neuron 71 in layer_0 for image 0
# ✅ Activated Neuron 75 in layer_0 for image 0
# ✅ Activated Neuron 76 in layer_0 for image 0
# ✅ Activated Neuron 73 in layer_0 for image 0
# 🔍 Received output for Neuron 75 and image 0: 0.0
# ✅ Activated Neuron 78 in layer_0 for image 0
# ✅ Activated Neuron 79 in layer_0 for image 0
# ✅ Activated Neuron 81 in layer_0 for image 0
# ✅ Activated Neuron 80 in layer_0 for image 0
# ✅ Activated Neuron 77 in layer_0 for image 0
# 🔍 Received output for Neuron 73 and image 0: 0.0
# 🔍 Received output for Neuron 72 and image 0: 0.0
# 🔍 Received output for Neuron 71 and image 0: 0.0
# 🔍 Received output for Neuron 76 and image 0: 0.0
# 🔍 Received output for Neuron 70 and image 0: 0.0
# ✅ Activated Neuron 89 in layer_0 for image 0
# ✅ Activated Neuron 83 in layer_0 for image 0
# ✅ Activated Neuron 86 in layer_0 for image 0
# ✅ Activated Neuron 87 in layer_0 for image 0
# ✅ Activated Neuron 88 in layer_0 for image 0
# ✅ Activated Neuron 82 in layer_0 for image 0
# ✅ Activated Neuron 84 in layer_0 for image 0
# ✅ Activated Neuron 85 in layer_0 for image 0
# 🔍 Received output for Neuron 74 and image 0: 0.0
# 🔍 Received output for Neuron 69 and image 0: 0.0
# 🔍 Received output for Neuron 81 and image 0: 2.9931974754403967
# 🔍 Received output for Neuron 77 and image 0: 0.0
# 🔍 Received output for Neuron 83 and image 0: 0.033003394030188815
# 🔍 Received output for Neuron 79 and image 0: 4.165464971020841
# 🔍 Received output for Neuron 84 and image 0: 0.0
# 🔍 Received output for Neuron 78 and image 0: 10.199375718215862
# 🔍 Received output for Neuron 82 and image 0: 0.0
# 🔍 Received output for Neuron 80 and image 0: 0.08924061469024352
# 🔍 Received output for Neuron 87 and image 0: 0.0
# 🔍 Received output for Neuron 89 and image 0: 0.0
# 🔍 Received output for Neuron 88 and image 0: 0.0
# 🔍 Received output for Neuron 86 and image 0: 0.0
# ✅ Activated Neuron 93 in layer_0 for image 0
# ✅ Activated Neuron 92 in layer_0 for image 0
# ✅ Activated Neuron 94 in layer_0 for image 0
# ✅ Activated Neuron 95 in layer_0 for image 0
# ✅ Activated Neuron 96 in layer_0 for image 0
# 🔍 Received output for Neuron 85 and image 0: 0.0
# ✅ Activated Neuron 90 in layer_0 for image 0
# ✅ Activated Neuron 97 in layer_0 for image 0
# ✅ Activated Neuron 91 in layer_0 for image 0
# 🔍 Received output for Neuron 94 and image 0: 0.0
# 🔍 Received output for Neuron 96 and image 0: 0.0
# 🔍 Received output for Neuron 95 and image 0: 0.0
# 🔍 Received output for Neuron 91 and image 0: 0.0
# 🔍 Received output for Neuron 90 and image 0: 4.16997889971063
# 🔍 Received output for Neuron 93 and image 0: 0.0
# 🔍 Received output for Neuron 97 and image 0: 0.0
# 🔍 Received output for Neuron 92 and image 0: 0.0
# ✅ Activated Neuron 100 in layer_0 for image 0
# ✅ Activated Neuron 102 in layer_0 for image 0
# ✅ Activated Neuron 103 in layer_0 for image 0
# ✅ Activated Neuron 101 in layer_0 for image 0
# ✅ Activated Neuron 105 in layer_0 for image 0
# ✅ Activated Neuron 104 in layer_0 for image 0
# ✅ Activated Neuron 98 in layer_0 for image 0
# ✅ Activated Neuron 99 in layer_0 for image 0
# 🔍 Received output for Neuron 100 and image 0: 0.0
# 🔍 Received output for Neuron 101 and image 0: 5.286582705603713
# 🔍 Received output for Neuron 105 and image 0: 0.0
# 🔍 Received output for Neuron 102 and image 0: 0.0
# 🔍 Received output for Neuron 98 and image 0: 0.0
# 🔍 Received output for Neuron 99 and image 0: 0.0
# 🔍 Received output for Neuron 104 and image 0: 0.0
# ✅ Activated Neuron 113 in layer_0 for image 0
# ✅ Activated Neuron 112 in layer_0 for image 0
# ✅ Activated Neuron 109 in layer_0 for image 0
# ✅ Activated Neuron 107 in layer_0 for image 0
# 🔍 Received output for Neuron 103 and image 0: 0.0
# ✅ Activated Neuron 108 in layer_0 for image 0
# ✅ Activated Neuron 111 in layer_0 for image 0
# ✅ Activated Neuron 110 in layer_0 for image 0
# ✅ Activated Neuron 106 in layer_0 for image 0
# 🔍 Received output for Neuron 110 and image 0: 0.40866483687021915
# 🔍 Received output for Neuron 109 and image 0: 0.0
# 🔍 Received output for Neuron 107 and image 0: 0.0
# ✅ Activated Neuron 120 in layer_0 for image 0
# ✅ Activated Neuron 116 in layer_0 for image 0
# ✅ Activated Neuron 119 in layer_0 for image 0
# ✅ Activated Neuron 117 in layer_0 for image 0
# ✅ Activated Neuron 121 in layer_0 for image 0
# ✅ Activated Neuron 114 in layer_0 for image 0
# ✅ Activated Neuron 115 in layer_0 for image 0
# ✅ Activated Neuron 118 in layer_0 for image 0
# 🔍 Received output for Neuron 115 and image 0: 0.0
# 🔍 Received output for Neuron 111 and image 0: 3.9578771193286806
# 🔍 Received output for Neuron 106 and image 0: 1.7691193724110863
# 🔍 Received output for Neuron 108 and image 0: 0.0
# ✅ Activated Neuron 126 in layer_0 for image 0
# ✅ Activated Neuron 127 in layer_0 for image 0
# ✅ Activated Neuron 122 in layer_0 for image 0
# ✅ Activated Neuron 1 in layer_0 for image 3
# ✅ Activated Neuron 0 in layer_0 for image 3
# ✅ Activated Neuron 124 in layer_0 for image 0
# ✅ Activated Neuron 125 in layer_0 for image 0
# ✅ Activated Neuron 123 in layer_0 for image 0
# 🔍 Received output for Neuron 113 and image 0: 0.0
# 🔍 Received output for Neuron 112 and image 0: 3.9527472866578655
# 🔍 Received output for Neuron 114 and image 0: 2.8119947811262787
# 🔍 Received output for Neuron 117 and image 0: 0.0
# 🔍 Received output for Neuron 121 and image 0: 0.0
# 🔍 Received output for Neuron 119 and image 0: 5.796542986923228
# ✅ Activated Neuron 6 in layer_0 for image 3
# ✅ Activated Neuron 8 in layer_0 for image 3
# ✅ Activated Neuron 5 in layer_0 for image 3
# ✅ Activated Neuron 4 in layer_0 for image 3
# ✅ Activated Neuron 9 in layer_0 for image 3
# ✅ Activated Neuron 3 in layer_0 for image 3
# ✅ Activated Neuron 2 in layer_0 for image 3
# ✅ Activated Neuron 7 in layer_0 for image 3
# 🔍 Received output for Neuron 120 and image 0: 0.0
# 🔍 Received output for Neuron 116 and image 0: 2.3189490103518513
# 🔍 Received output for Neuron 125 and image 0: 0.0
# 🔍 Received output for Neuron 122 and image 0: 0.0
# 🔍 Received output for Neuron 118 and image 0: 0.0
# 🔍 Received output for Neuron 124 and image 0: 4.588778625321133
# 🔍 Received output for Neuron 5 and image 3: 0.0
# 🔍 Received output for Neuron 1 and image 3: 0.0
# ✅ Activated Neuron 11 in layer_0 for image 3
# 🔍 Received output for Neuron 3 and image 3: 0.0
# 🔍 Received output for Neuron 123 and image 0: 0.0
# 🔍 Received output for Neuron 8 and image 3: 0.0
# 🔍 Received output for Neuron 126 and image 0: 0.0
# 🔍 Received output for Neuron 4 and image 3: 0.0
# 🔍 Received output for Neuron 127 and image 0: 0.0
# 🟢 Aggregating outputs for image 0 on layer layer_0
# ✅ Activated Neuron 10 in layer_0 for image 3
# 🔍 Received output for Neuron 2 and image 3: 2.7594002163159255
# 🔍 Received output for Neuron 7 and image 3: 0.0
# 🚀 Activating next layer: layer_1 for image 0
# 🔍 Received output for Neuron 0 and image 3: 0.0
# 🔍 Received output for Neuron 6 and image 3: 8.269017094215393
# 🔍 Received output for Neuron 12 and image 3: 9.307276194545379
# 🔍 Received output for Neuron 9 and image 3: 0.0
# 🔍 Received output for Neuron 10 and image 3: 0.0
# 🔍 Received output for Neuron 15 and image 3: 0.0
# ✅ Activated Neuron 14 in layer_0 for image 3
# ✅ Activated Neuron 19 in layer_0 for image 3
# ✅ Activated Neuron 16 in layer_0 for image 3
# ✅ Activated Neuron 17 in layer_0 for image 3
# ✅ Activated Neuron 12 in layer_0 for image 3
# ✅ Activated Neuron 13 in layer_0 for image 3
# ✅ Activated Neuron 18 in layer_0 for image 3
# ✅ Activated Neuron 1 in layer_1 for image 0
# 🔍 Received output for Neuron 14 and image 3: 7.490746095700806
# 🔍 Received output for Neuron 13 and image 3: 0.0
# 🔍 Received output for Neuron 11 and image 3: 0.0
# 🔍 Received output for Neuron 16 and image 3: 0.0
# ✅ Activated Neuron 0 in layer_1 for image 0
# ✅ Activated Neuron 15 in layer_0 for image 3
# 🔍 Received output for Neuron 17 and image 3: 0.0
# 🔍 Received output for Neuron 1 and image 0: -11.243634546058475
# ✅ Activated Neuron 2 in layer_1 for image 0
# ✅ Activated Neuron 5 in layer_1 for image 0
# ✅ Activated Neuron 6 in layer_1 for image 0
# ✅ Activated Neuron 7 in layer_1 for image 0
# ✅ Activated Neuron 8 in layer_1 for image 0
# ✅ Activated Neuron 3 in layer_1 for image 0
# ✅ Activated Neuron 9 in layer_1 for image 0
# ✅ Activated Neuron 4 in layer_1 for image 0
# 🔍 Received output for Neuron 0 and image 0: -6.867582317209552
# 🔍 Received output for Neuron 18 and image 3: 1.0014264267826718
# 🔍 Received output for Neuron 6 and image 0: -12.853611297532014
# 🔍 Received output for Neuron 3 and image 0: 2.5094254824845152
# 🔍 Received output for Neuron 4 and image 0: -10.954757109879182
# 🔍 Received output for Neuron 2 and image 0: -2.542845800594375
# 🔍 Received output for Neuron 5 and image 0: -4.378832594745012
# 🔍 Received output for Neuron 9 and image 0: -4.09878555404558
# 🔍 Received output for Neuron 7 and image 0: 11.062075426343023🔍 Received output for Neuron 19 and image 3: 0.0
# ✅ Activated Neuron 20 in layer_0 for image 3
# ✅ Activated Neuron 27 in layer_0 for image 3
# ✅ Activated Neuron 22 in layer_0 for image 3
# ✅ Activated Neuron 23 in layer_0 for image 3
# ✅ Activated Neuron 24 in layer_0 for image 3
# ✅ Activated Neuron 25 in layer_0 for image 3
# ✅ Activated Neuron 26 in layer_0 for image 3
#
# ✅ Activated Neuron 21 in layer_0 for image 3
# 🔍 Received output for Neuron 8 and image 0: -3.2350892974173417
# 🟢 Aggregating outputs for image 0 on layer layer_1
# 🔍 Received output for Neuron 24 and image 3: 0.0
# 🔍 Received output for Neuron 20 and image 3: 0.0
# 🎯 Final Prediction for image 0: 7
# 🔍 Received output for Neuron 27 and image 3: 0.0
# ✅ Activated Neuron 32 in layer_0 for image 3
# ✅ Activated Neuron 34 in layer_0 for image 3
# ✅ Activated Neuron 35 in layer_0 for image 3
# ✅ Activated Neuron 31 in layer_0 for image 3
# ✅ Activated Neuron 29 in layer_0 for image 3
# ✅ Activated Neuron 30 in layer_0 for image 3
# ✅ Activated Neuron 28 in layer_0 for image 3
# 🔍 Received output for Neuron 22 and image 3: 9.975624297244192
# 🔍 Received output for Neuron 26 and image 3: 0.0
# 🔍 Received output for Neuron 23 and image 3: 0.0
# ✅ Activated Neuron 33 in layer_0 for image 3
# 🔍 Received output for Neuron 21 and image 3: 0.0
# 🔍 Received output for Neuron 34 and image 3: 0.0
# 🔍 Received output for Neuron 25 and image 3: 0.0
# 🔍 Received output for Neuron 30 and image 3: 2.7270604684261763
# 🔍 Received output for Neuron 28 and image 3: 0.0
# 🔍 Received output for Neuron 33 and image 3: 0.0
# 🔍 Received output for Neuron 35 and image 3: 0.0
# 🔍 Received output for Neuron 29 and image 3: 0.0
# 🔍 Received output for Neuron 32 and image 3: 10.019114380022366
# 🔍 Received output for Neuron 31 and image 3: 0.0
# ✅ Activated Neuron 37 in layer_0 for image 3
# ✅ Activated Neuron 38 in layer_0 for image 3
# ✅ Activated Neuron 40 in layer_0 for image 3
# ✅ Activated Neuron 41 in layer_0 for image 3
# ✅ Activated Neuron 42 in layer_0 for image 3
# ✅ Activated Neuron 43 in layer_0 for image 3
# ✅ Activated Neuron 36 in layer_0 for image 3
# ✅ Activated Neuron 39 in layer_0 for image 3
# 🔍 Received output for Neuron 38 and image 3: 0.0
# 🔍 Received output for Neuron 37 and image 3: 1.1179554817086654
# 🔍 Received output for Neuron 42 and image 3: 0.0
# 🔍 Received output for Neuron 41 and image 3: 14.182674687243011
# 🔍 Received output for Neuron 36 and image 3: 0.0
# 🔍 Received output for Neuron 43 and image 3: 0.0
# 🔍 Received output for Neuron 40 and image 3: 0.0
# 🔍 Received output for Neuron 39 and image 3: 7.59207121416132
# ✅ Activated Neuron 45 in layer_0 for image 3
# ✅ Activated Neuron 47 in layer_0 for image 3
# ✅ Activated Neuron 48 in layer_0 for image 3
# ✅ Activated Neuron 49 in layer_0 for image 3
# ✅ Activated Neuron 50 in layer_0 for image 3
# ✅ Activated Neuron 44 in layer_0 for image 3
# ✅ Activated Neuron 51 in layer_0 for image 3
# ✅ Activated Neuron 46 in layer_0 for image 3
# 🔍 Received output for Neuron 51 and image 3: 0.0
# 🔍 Received output for Neuron 45 and image 3: 0.0
# 🔍 Received output for Neuron 48 and image 3: 0.0
# 🔍 Received output for Neuron 44 and image 3: 0.0
# 🔍 Received output for Neuron 49 and image 3: 0.0
# 🔍 Received output for Neuron 46 and image 3: 0.5575656237474135
# 🔍 Received output for Neuron 47 and image 3: 0.0
# 🔍 Received output for Neuron 50 and image 3: 0.0
# ✅ Activated Neuron 54 in layer_0 for image 3
# ✅ Activated Neuron 58 in layer_0 for image 3
# ✅ Activated Neuron 55 in layer_0 for image 3
# ✅ Activated Neuron 57 in layer_0 for image 3
# ✅ Activated Neuron 56 in layer_0 for image 3
# ✅ Activated Neuron 53 in layer_0 for image 3
# ✅ Activated Neuron 59 in layer_0 for image 3
# ✅ Activated Neuron 52 in layer_0 for image 3
# ✅ Activated Neuron 60 in layer_0 for image 3
# ✅ Activated Neuron 63 in layer_0 for image 3
# ✅ Activated Neuron 64 in layer_0 for image 3
# ✅ Activated Neuron 65 in layer_0 for image 3
# ✅ Activated Neuron 66 in layer_0 for image 3
# ✅ Activated Neuron 67 in layer_0 for image 3
# ✅ Activated Neuron 61 in layer_0 for image 3
# ✅ Activated Neuron 62 in layer_0 for image 3
# 🔍 Received output for Neuron 59 and image 3: 0.0
# 🔍 Received output for Neuron 64 and image 3: 0.0
# 🔍 Received output for Neuron 60 and image 3: 0.0
# 🔍 Received output for Neuron 52 and image 3: 0.0
# 🔍 Received output for Neuron 56 and image 3: 0.0
# 🔍 Received output for Neuron 58 and image 3: 0.4499537995720461
# 🔍 Received output for Neuron 54 and image 3: 2.15244281251792
# 🔍 Received output for Neuron 61 and image 3: 0.0
# 🔍 Received output for Neuron 53 and image 3: 0.0
# 🔍 Received output for Neuron 55 and image 3: 0.0
# 🔍 Received output for Neuron 57 and image 3: 0.0
# 🔍 Received output for Neuron 65 and image 3: 0.0
# ...
# 🔍 Received output for Neuron 116 and image 8: 2.2248823894087244
# 🔍 Received output for Neuron 113 and image 8: 0.0
# ✅ Activated Neuron 121 in layer_0 for image 8
# ✅ Activated Neuron 0 in layer_0 for image 9
# ✅ Activated Neuron 123 in layer_0 for image 8
# ✅ Activated Neuron 124 in layer_0 for image 8
# ✅ Activated Neuron 125 in layer_0 for image 8
# ✅ Activated Neuron 126 in layer_0 for image 8
# ✅ Activated Neuron 127 in layer_0 for image 8
# ✅ Activated Neuron 122 in layer_0 for image 8
# 🔍 Received output for Neuron 126 and image 8: 0.0
# 🔍 Received output for Neuron 124 and image 8: 0.0
# 🔍 Received output for Neuron 123 and image 8: 0.0
# 🔍 Received output for Neuron 127 and image 8: 0.0
# 🔍 Received output for Neuron 0 and image 9: 0.0
# 🔍 Received output for Neuron 122 and image 8: 0.0
# 🔍 Received output for Neuron 125 and image 8: 0.0
# 🔍 Received output for Neuron 121 and image 8: 0.0
# 🟢 Aggregating outputs for image 8 on layer layer_0
# ✅ Activated Neuron 4 in layer_0 for image 9
# ✅ Activated Neuron 6 in layer_0 for image 9
# ✅ Activated Neuron 7 in layer_0 for image 9
# ✅ Activated Neuron 8 in layer_0 for image 9
# ✅ Activated Neuron 1 in layer_0 for image 9
# ✅ Activated Neuron 3 in layer_0 for image 9
# ✅ Activated Neuron 2 in layer_0 for image 9
# ✅ Activated Neuron 5 in layer_0 for image 9
# 🚀 Activating next layer: layer_1 for image 8
# 🔍 Received output for Neuron 1 and image 9: 3.033168414980758
# 🔍 Received output for Neuron 7 and image 9: 0.0
# 🔍 Received output for Neuron 6 and image 9: 3.4555911155457077
# 🔍 Received output for Neuron 5 and image 9: 0.0
# 🔍 Received output for Neuron 3 and image 9: 5.612173442890181
# 🔍 Received output for Neuron 2 and image 9: 3.42563902890515
# 🔍 Received output for Neuron 4 and image 9: 0.0
# 🔍 Received output for Neuron 8 and image 9: 0.0
# 🔍 Received output for Neuron 0 and image 8: -1.3589984094335383
# ✅ Activated Neuron 0 in layer_1 for image 8
# 🔍 Received output for Neuron 1 and image 8: -9.578443421442945
# 🔍 Received output for Neuron 3 and image 8: -8.753485578963398
# 🔍 Received output for Neuron 7 and image 8: -6.448590035366386
# 🔍 Received output for Neuron 2 and image 8: -2.1353454096291826
# ✅ Activated Neuron 11 in layer_0 for image 9
# ✅ Activated Neuron 13 in layer_0 for image 9
# ✅ Activated Neuron 14 in layer_0 for image 9
# ✅ Activated Neuron 15 in layer_0 for image 9
# ✅ Activated Neuron 16 in layer_0 for image 9
# ✅ Activated Neuron 9 in layer_0 for image 9
# ✅ Activated Neuron 10 in layer_0 for image 9
# 🔍 Received output for Neuron 4 and image 8: -0.3128416900909792
# 🔍 Received output for Neuron 6 and image 8: 3.8167926240720935
# 🔍 Received output for Neuron 5 and image 8: 2.9236888099036613
# 🔍 Received output for Neuron 16 and image 9: 0.0
# ✅ Activated Neuron 1 in layer_1 for image 8
# ✅ Activated Neuron 2 in layer_1 for image 8
# ✅ Activated Neuron 5 in layer_1 for image 8
# ✅ Activated Neuron 3 in layer_1 for image 8
# ✅ Activated Neuron 6 in layer_1 for image 8
# ✅ Activated Neuron 4 in layer_1 for image 8
# ✅ Activated Neuron 12 in layer_0 for image 9
# 🔍 Received output for Neuron 9 and image 9: 0.0
# 🔍 Received output for Neuron 14 and image 9: 1.0788371444079692
# 🔍 Received output for Neuron 11 and image 9: 0.0
# ✅ Activated Neuron 7 in layer_1 for image 8
# ✅ Activated Neuron 9 in layer_1 for image 8
# ✅ Activated Neuron 8 in layer_1 for image 8
# 🔍 Received output for Neuron 12 and image 9: 9.375982201177072
# 🔍 Received output for Neuron 13 and image 9: 0.0
# 🔍 Received output for Neuron 10 and image 9: 0.0
# 🔍 Received output for Neuron 8 and image 8: -2.8661299013056594
# 🔍 Received output for Neuron 15 and image 9: 12.03649497578194
# ✅ Activated Neuron 18 in layer_0 for image 9
# ✅ Activated Neuron 21 in layer_0 for image 9
# ✅ Activated Neuron 22 in layer_0 for image 9
# ✅ Activated Neuron 23 in layer_0 for image 9
# ✅ Activated Neuron 17 in layer_0 for image 9
# ✅ Activated Neuron 19 in layer_0 for image 9
# 🔍 Received output for Neuron 9 and image 8: -2.8360979261505257
# 🟢 Aggregating outputs for image 8 on layer layer_1
# ✅ Activated Neuron 24 in layer_0 for image 9
# ✅ Activated Neuron 20 in layer_0 for image 9
# 🔍 Received output for Neuron 22 and image 9: 0.0
# 🔍 Received output for Neuron 18 and image 9: 2.002526151957487
# 🔍 Received output for Neuron 23 and image 9: 0.0
# 🎯 Final Prediction for image 8: 6
# 🔍 Received output for Neuron 19 and image 9: 0.0
# 🔍 Received output for Neuron 21 and image 9: 0.0
# 🔍 Received output for Neuron 24 and image 9: 0.0
# 🔍 Received output for Neuron 17 and image 9: 1.6804297302072897
# 🔍 Received output for Neuron 20 and image 9: 0.0
# ✅ Activated Neuron 25 in layer_0 for image 9
# ✅ Activated Neuron 30 in layer_0 for image 9
# ✅ Activated Neuron 32 in layer_0 for image 9
# ✅ Activated Neuron 31 in layer_0 for image 9
# ✅ Activated Neuron 27 in layer_0 for image 9
# ✅ Activated Neuron 28 in layer_0 for image 9
# ✅ Activated Neuron 29 in layer_0 for image 9
# ✅ Activated Neuron 26 in layer_0 for image 9
# 🔍 Received output for Neuron 32 and image 9: 4.010165557423677
# 🔍 Received output for Neuron 28 and image 9: 0.0
# 🔍 Received output for Neuron 29 and image 9: 0.0
# 🔍 Received output for Neuron 31 and image 9: 0.0
# 🔍 Received output for Neuron 30 and image 9: 10.905140590815417
# 🔍 Received output for Neuron 25 and image 9: 0.0
# 🔍 Received output for Neuron 26 and image 9: 7.683210632705636
# 🔍 Received output for Neuron 27 and image 9: 0.4330541488255719
# ✅ Activated Neuron 35 in layer_0 for image 9
# ✅ Activated Neuron 37 in layer_0 for image 9
# ✅ Activated Neuron 38 in layer_0 for image 9
# ✅ Activated Neuron 39 in layer_0 for image 9
# ✅ Activated Neuron 40 in layer_0 for image 9
# ✅ Activated Neuron 33 in layer_0 for image 9
# ✅ Activated Neuron 36 in layer_0 for image 9
# ✅ Activated Neuron 34 in layer_0 for image 9
# 🔍 Received output for Neuron 39 and image 9: 0.0
# 🔍 Received output for Neuron 37 and image 9: 0.0
# 🔍 Received output for Neuron 38 and image 9: 0.0
# 🔍 Received output for Neuron 36 and image 9: 0.0
# 🔍 Received output for Neuron 35 and image 9: 0.8951815440673286
# 🔍 Received output for Neuron 40 and image 9: 1.1831009788502689
# 🔍 Received output for Neuron 34 and image 9: 0.0
# 🔍 Received output for Neuron 33 and image 9: 0.0
# ✅ Activated Neuron 48 in layer_0 for image 9
# ✅ Activated Neuron 43 in layer_0 for image 9
# ✅ Activated Neuron 44 in layer_0 for image 9
# ✅ Activated Neuron 45 in layer_0 for image 9
# ✅ Activated Neuron 46 in layer_0 for image 9
# ✅ Activated Neuron 47 in layer_0 for image 9
# ✅ Activated Neuron 42 in layer_0 for image 9
# ✅ Activated Neuron 41 in layer_0 for image 9
# 🔍 Received output for Neuron 46 and image 9: 0.0
# 🔍 Received output for Neuron 45 and image 9: 0.0
# 🔍 Received output for Neuron 41 and image 9: 9.37562281283205
# 🔍 Received output for Neuron 42 and image 9: 0.0
# 🔍 Received output for Neuron 48 and image 9: 0.0
# 🔍 Received output for Neuron 43 and image 9: 0.0
# 🔍 Received output for Neuron 44 and image 9: 0.0
# ✅ Activated Neuron 49 in layer_0 for image 9
# ✅ Activated Neuron 51 in layer_0 for image 9
# ✅ Activated Neuron 52 in layer_0 for image 9
# ✅ Activated Neuron 53 in layer_0 for image 9
# ✅ Activated Neuron 56 in layer_0 for image 9
# ✅ Activated Neuron 50 in layer_0 for image 9
# ✅ Activated Neuron 55 in layer_0 for image 9
# 🔍 Received output for Neuron 47 and image 9: 0.0
# ✅ Activated Neuron 54 in layer_0 for image 9
# ✅ Activated Neuron 58 in layer_0 for image 9
# ✅ Activated Neuron 59 in layer_0 for image 9
# ✅ Activated Neuron 60 in layer_0 for image 9
# ✅ Activated Neuron 57 in layer_0 for image 9
# 🔍 Received output for Neuron 54 and image 9: 0.0
# ✅ Activated Neuron 61 in layer_0 for image 9
# ✅ Activated Neuron 64 in layer_0 for image 9
# ✅ Activated Neuron 62 in layer_0 for image 9
# ✅ Activated Neuron 66 in layer_0 for image 9
# ✅ Activated Neuron 67 in layer_0 for image 9
# ✅ Activated Neuron 68 in layer_0 for image 9
# ✅ Activated Neuron 63 in layer_0 for image 9
# ✅ Activated Neuron 65 in layer_0 for image 9
# ✅ Activated Neuron 69 in layer_0 for image 9
# ✅ Activated Neuron 71 in layer_0 for image 9
# ✅ Activated Neuron 70 in layer_0 for image 9
# ✅ Activated Neuron 72 in layer_0 for image 9
# ✅ Activated Neuron 73 in layer_0 for image 9
# ✅ Activated Neuron 74 in layer_0 for image 9
# ✅ Activated Neuron 75 in layer_0 for image 9
# 🔍 Received output for Neuron 49 and image 9: 0.0
# 🔍 Received output for Neuron 51 and image 9: 0.0
# 🔍 Received output for Neuron 50 and image 9: 7.589039308380836
# 🔍 Received output for Neuron 55 and image 9: 3.1765946440952346
# 🔍 Received output for Neuron 62 and image 9: 0.6931969138117069
# 🔍 Received output for Neuron 61 and image 9: 0.0
# 🔍 Received output for Neuron 53 and image 9: 0.0
# 🔍 Received output for Neuron 60 and image 9: 5.398083044451015
# 🔍 Received output for Neuron 52 and image 9: 0.0
# 🔍 Received output for Neuron 59 and image 9: 11.438930060244164
# 🔍 Received output for Neuron 57 and image 9: 0.0
# ✅ Activated Neuron 80 in layer_0 for image 9
# ✅ Activated Neuron 77 in layer_0 for image 9
# ✅ Activated Neuron 82 in layer_0 for image 9
# ✅ Activated Neuron 83 in layer_0 for image 9
# ✅ Activated Neuron 78 in layer_0 for image 9
# 🔍 Received output for Neuron 64 and image 9: 7.860500233413312
# ✅ Activated Neuron 79 in layer_0 for image 9
# ✅ Activated Neuron 81 in layer_0 for image 9
# ✅ Activated Neuron 76 in layer_0 for image 9
# 🔍 Received output for Neuron 56 and image 9: 0.0
# 🔍 Received output for Neuron 58 and image 9: 1.4732277861666145
# 🔍 Received output for Neuron 75 and image 9: 0.0
# 🔍 Received output for Neuron 71 and image 9: 0.0
# 🔍 Received output for Neuron 68 and image 9: 6.707068601232144
# 🔍 Received output for Neuron 69 and image 9: 0.0
# 🔍 Received output for Neuron 73 and image 9: 0.0
# 🔍 Received output for Neuron 74 and image 9: 0.0
# 🔍 Received output for Neuron 72 and image 9: 0.0
# 🔍 Received output for Neuron 65 and image 9: 5.351711041247956
# 🔍 Received output for Neuron 63 and image 9: 9.932265574855716
# 🔍 Received output for Neuron 76 and image 9: 0.0
# 🔍 Received output for Neuron 81 and image 9: 5.508156733111244
# 🔍 Received output for Neuron 67 and image 9: 2.434116754842616
# 🔍 Received output for Neuron 70 and image 9: 0.0
# 🔍 Received output for Neuron 77 and image 9: 3.6856129852599975
# ✅ Activated Neuron 91 in layer_0 for image 9
# ✅ Activated Neuron 85 in layer_0 for image 9
# ✅ Activated Neuron 87 in layer_0 for image 9
# ✅ Activated Neuron 88 in layer_0 for image 9
# ✅ Activated Neuron 89 in layer_0 for image 9
# ✅ Activated Neuron 90 in layer_0 for image 9
# ✅ Activated Neuron 84 in layer_0 for image 9
# ✅ Activated Neuron 86 in layer_0 for image 9
# 🔍 Received output for Neuron 66 and image 9: 0.0
# 🔍 Received output for Neuron 79 and image 9: 2.6228173777494836
# 🔍 Received output for Neuron 83 and image 9: 6.386588172843824
# 🔍 Received output for Neuron 82 and image 9: 0.0
# 🔍 Received output for Neuron 78 and image 9: 9.7716641361936
# 🔍 Received output for Neuron 80 and image 9: 0.0
# 🔍 Received output for Neuron 88 and image 9: 0.0
# 🔍 Received output for Neuron 89 and image 9: 0.0
# 🔍 Received output for Neuron 84 and image 9: 0.0
# 🔍 Received output for Neuron 86 and image 9: 0.0
# 🔍 Received output for Neuron 85 and image 9: 0.0
# 🔍 Received output for Neuron 91 and image 9: 0.0
# 🔍 Received output for Neuron 87 and image 9: 1.9435537017873037
# 🔍 Received output for Neuron 90 and image 9: 5.110902492403158
# ✅ Activated Neuron 92 in layer_0 for image 9
# ✅ Activated Neuron 94 in layer_0 for image 9
# ✅ Activated Neuron 95 in layer_0 for image 9
# ✅ Activated Neuron 96 in layer_0 for image 9
# ✅ Activated Neuron 99 in layer_0 for image 9
# ✅ Activated Neuron 98 in layer_0 for image 9
# ✅ Activated Neuron 97 in layer_0 for image 9
# ✅ Activated Neuron 93 in layer_0 for image 9
# 🔍 Received output for Neuron 94 and image 9: 1.900232603810472
# 🔍 Received output for Neuron 92 and image 9: 0.0
# 🔍 Received output for Neuron 98 and image 9: 0.0
# 🔍 Received output for Neuron 96 and image 9: 0.0
# 🔍 Received output for Neuron 97 and image 9: 0.0
# 🔍 Received output for Neuron 99 and image 9: 0.0
# 🔍 Received output for Neuron 95 and image 9: 0.0
# 🔍 Received output for Neuron 93 and image 9: 0.0
# ✅ Activated Neuron 100 in layer_0 for image 9
# ✅ Activated Neuron 101 in layer_0 for image 9
# ✅ Activated Neuron 102 in layer_0 for image 9
# ✅ Activated Neuron 103 in layer_0 for image 9
# ✅ Activated Neuron 104 in layer_0 for image 9
# ✅ Activated Neuron 105 in layer_0 for image 9
# ✅ Activated Neuron 106 in layer_0 for image 9
# ✅ Activated Neuron 107 in layer_0 for image 9
# 🔍 Received output for Neuron 105 and image 9: 0.0
# 🔍 Received output for Neuron 103 and image 9: 0.0
# 🔍 Received output for Neuron 101 and image 9: 8.091172373328
# 🔍 Received output for Neuron 102 and image 9: 0.0
# 🔍 Received output for Neuron 104 and image 9: 7.169111388260195
# 🔍 Received output for Neuron 107 and image 9: 0.0
# 🔍 Received output for Neuron 100 and image 9: 0.0
# 🔍 Received output for Neuron 106 and image 9: 1.4755923678346812
# ✅ Activated Neuron 110 in layer_0 for image 9
# ✅ Activated Neuron 111 in layer_0 for image 9
# ✅ Activated Neuron 113 in layer_0 for image 9
# ✅ Activated Neuron 114 in layer_0 for image 9
# ✅ Activated Neuron 112 in layer_0 for image 9
# ✅ Activated Neuron 108 in layer_0 for image 9
# ✅ Activated Neuron 109 in layer_0 for image 9
# ✅ Activated Neuron 115 in layer_0 for image 9
# 🔍 Received output for Neuron 113 and image 9: 0.0
# 🔍 Received output for Neuron 115 and image 9: 0.0
# 🔍 Received output for Neuron 112 and image 9: 0.0
# 🔍 Received output for Neuron 108 and image 9: 0.0
# 🔍 Received output for Neuron 114 and image 9: 2.639702687172382
# 🔍 Received output for Neuron 111 and image 9: 4.372145894652366
# 🔍 Received output for Neuron 110 and image 9: 0.0
# 🔍 Received output for Neuron 109 and image 9: 0.0
# ✅ Activated Neuron 116 in layer_0 for image 9
# ✅ Activated Neuron 122 in layer_0 for image 9
# ✅ Activated Neuron 123 in layer_0 for image 9
# ✅ Activated Neuron 117 in layer_0 for image 9
# ✅ Activated Neuron 118 in layer_0 for image 9
# ✅ Activated Neuron 119 in layer_0 for image 9
# ✅ Activated Neuron 120 in layer_0 for image 9
# ✅ Activated Neuron 121 in layer_0 for image 9
# 🔍 Received output for Neuron 121 and image 9: 0.0
# 🔍 Received output for Neuron 116 and image 9: 0.0
# 🔍 Received output for Neuron 120 and image 9: 0.0
# 🔍 Received output for Neuron 117 and image 9: 3.269977778913032
# 🔍 Received output for Neuron 119 and image 9: 0.4969649083294101
# 🔍 Received output for Neuron 123 and image 9: 0.0
# ✅ Activated Neuron 124 in layer_0 for image 9
# ✅ Activated Neuron 125 in layer_0 for image 9
# ✅ Activated Neuron 126 in layer_0 for image 9
# ✅ Activated Neuron 127 in layer_0 for image 9
# 🔍 Received output for Neuron 118 and image 9: 0.0
# 🔍 Received output for Neuron 122 and image 9: 0.0
# 🔍 Received output for Neuron 126 and image 9: 0.0
# 🔍 Received output for Neuron 125 and image 9: 0.0
# 🔍 Received output for Neuron 124 and image 9: 0.0
# 🔍 Received output for Neuron 127 and image 9: 0.0
# 🟢 Aggregating outputs for image 9 on layer layer_0
# 🚀 Activating next layer: layer_1 for image 9
# ✅ Activated Neuron 0 in layer_1 for image 9
# ✅ Activated Neuron 5 in layer_1 for image 9
# ✅ Activated Neuron 6 in layer_1 for image 9
# ✅ Activated Neuron 7 in layer_1 for image 9
# ✅ Activated Neuron 3 in layer_1 for image 9
# ✅ Activated Neuron 1 in layer_1 for image 9
# ✅ Activated Neuron 2 in layer_1 for image 9
# 🔍 Received output for Neuron 2 and image 9: -9.390017834496225
# ✅ Activated Neuron 4 in layer_1 for image 9
# 🔍 Received output for Neuron 1 and image 9: -16.788759595942942
# 🔍 Received output for Neuron 0 and image 9: -11.935084164856937
# ✅ Activated Neuron 8 in layer_1 for image 9
# ✅ Activated Neuron 9 in layer_1 for image 9
# 🔍 Received output for Neuron 3 and image 9: -5.381783376115491
# 🔍 Received output for Neuron 5 and image 9: -6.124749915604316
# 🔍 Received output for Neuron 4 and image 9: 0.906443257234733
# 🔍 Received output for Neuron 6 and image 9: -15.212989041793895
# 🔍 Received output for Neuron 7 and image 9: 2.4675733487772664
# 🔍 Received output for Neuron 8 and image 9: 2.29320358402897
# 🔍 Received output for Neuron 9 and image 9: 7.06329725320386
# 🟢 Aggregating outputs for image 9 on layer layer_1
# 🎯 Final Prediction for image 9: 9

# %%
for thread in neurons + layers + coordinators:
    thread.join()
# Out:
# Exception in thread Thread-260:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/tmp/ipykernel_1698/2416226026.py", line 175, in run
# AttributeError: 'Layer' object has no attribute 'neuron_id'
# No messages for 10 seconds in Neuron 0; stopping thread.
# No messages for 10 seconds in Neuron 1; stopping thread.
# No messages for 10 seconds in Neuron 7; stopping thread.
# No messages for 10 seconds in Neuron 6; stopping thread.
# No messages for 10 seconds in Neuron 5; stopping thread.
# No messages for 10 seconds in Neuron 3; stopping thread.
# No messages for 10 seconds in Neuron 4; stopping thread.
# No messages for 10 seconds in Neuron 2; stopping thread.
# No messages for 10 seconds in Neuron 8; stopping thread.
# No messages for 10 seconds in Neuron 14; stopping thread.
# No messages for 10 seconds in Neuron 10; stopping thread.
# No messages for 10 seconds in Neuron 16; stopping thread.
# No messages for 10 seconds in Neuron 12; stopping thread.
# No messages for 10 seconds in Neuron 9; stopping thread.
# No messages for 10 seconds in Neuron 11; stopping thread.
# No messages for 10 seconds in Neuron 13; stopping thread.
# No messages for 10 seconds in Neuron 15; stopping thread.
# No messages for 10 seconds in Neuron 17; stopping thread.
# No messages for 10 seconds in Neuron 18; stopping thread.
# No messages for 10 seconds in Neuron 22; stopping thread.
# No messages for 10 seconds in Neuron 21; stopping thread.
# No messages for 10 seconds in Neuron 24; stopping thread.
# No messages for 10 seconds in Neuron 19; stopping thread.
# No messages for 10 seconds in Neuron 23; stopping thread.
# No messages for 10 seconds in Neuron 20; stopping thread.
# No messages for 10 seconds in Neuron 32; stopping thread.
# No messages for 10 seconds in Neuron 28; stopping thread.
# No messages for 10 seconds in Neuron 29; stopping thread.
# No messages for 10 seconds in Neuron 30; stopping thread.
# No messages for 10 seconds in Neuron 26; stopping thread.
# No messages for 10 seconds in Neuron 31; stopping thread.
# No messages for 10 seconds in Neuron 25; stopping thread.
# No messages for 10 seconds in Neuron 27; stopping thread.
# No messages for 10 seconds in Neuron 39; stopping thread.
# No messages for 10 seconds in Neuron 38; stopping thread.
# No messages for 10 seconds in Neuron 37; stopping thread.
# No messages for 10 seconds in Neuron 35; stopping thread.
# No messages for 10 seconds in Neuron 36; stopping thread.
# No messages for 10 seconds in Neuron 33; stopping thread.
# No messages for 10 seconds in Neuron 34; stopping thread.
# No messages for 10 seconds in Neuron 40; stopping thread.
# No messages for 10 seconds in Neuron 42; stopping thread.
# No messages for 10 seconds in Neuron 46; stopping thread.
# No messages for 10 seconds in Neuron 45; stopping thread.
# No messages for 10 seconds in Neuron 47; stopping thread.
# No messages for 10 seconds in Neuron 41; stopping thread.
# No messages for 10 seconds in Neuron 43; stopping thread.
# No messages for 10 seconds in Neuron 48; stopping thread.
# No messages for 10 seconds in Neuron 44; stopping thread.
# No messages for 10 seconds in Neuron 54; stopping thread.
# No messages for 10 seconds in Neuron 49; stopping thread.
# No messages for 10 seconds in Neuron 50; stopping thread.
# No messages for 10 seconds in Neuron 55; stopping thread.
# No messages for 10 seconds in Neuron 62; stopping thread.
# No messages for 10 seconds in Neuron 51; stopping thread.
# No messages for 10 seconds in Neuron 53; stopping thread.
# No messages for 10 seconds in Neuron 52; stopping thread.
# No messages for 10 seconds in Neuron 60; stopping thread.
# No messages for 10 seconds in Neuron 59; stopping thread.
# No messages for 10 seconds in Neuron 56; stopping thread.No messages for 10 seconds in Neuron 61; stopping thread.
#
# No messages for 10 seconds in Neuron 64; stopping thread.
# No messages for 10 seconds in Neuron 57; stopping thread.
# No messages for 10 seconds in Neuron 65; stopping thread.
# No messages for 10 seconds in Neuron 58; stopping thread.
# No messages for 10 seconds in Neuron 71; stopping thread.
# No messages for 10 seconds in Neuron 68; stopping thread.
# No messages for 10 seconds in Neuron 73; stopping thread.
# No messages for 10 seconds in Neuron 75; stopping thread.
# No messages for 10 seconds in Neuron 69; stopping thread.
# No messages for 10 seconds in Neuron 66; stopping thread.
# No messages for 10 seconds in Neuron 63; stopping thread.
# No messages for 10 seconds in Neuron 74; stopping thread.
# No messages for 10 seconds in Neuron 67; stopping thread.
# No messages for 10 seconds in Neuron 70; stopping thread.
# No messages for 10 seconds in Neuron 72; stopping thread.
# No messages for 10 seconds in Neuron 81; stopping thread.
# No messages for 10 seconds in Neuron 76; stopping thread.
# No messages for 10 seconds in Neuron 77; stopping thread.
# No messages for 10 seconds in Neuron 83; stopping thread.
# No messages for 10 seconds in Neuron 82; stopping thread.
# No messages for 10 seconds in Neuron 79; stopping thread.
# No messages for 10 seconds in Neuron 80; stopping thread.
# No messages for 10 seconds in Neuron 78; stopping thread.
# No messages for 10 seconds in Neuron 86; stopping thread.
# No messages for 10 seconds in Neuron 88; stopping thread.
# No messages for 10 seconds in Neuron 85; stopping thread.
# No messages for 10 seconds in Neuron 84; stopping thread.
# No messages for 10 seconds in Neuron 89; stopping thread.
# No messages for 10 seconds in Neuron 90; stopping thread.
# No messages for 10 seconds in Neuron 91; stopping thread.
# No messages for 10 seconds in Neuron 87; stopping thread.
# No messages for 10 seconds in Neuron 92; stopping thread.
# No messages for 10 seconds in Neuron 94; stopping thread.
# Exception in thread Thread-262:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/tmp/ipykernel_1698/2416226026.py", line 117, in run
# AttributeError: 'LayerCoordinator' object has no attribute 'neuron_id'
# No messages for 10 seconds in Neuron 96; stopping thread.
# No messages for 10 seconds in Neuron 93; stopping thread.
# No messages for 10 seconds in Neuron 97; stopping thread.
# No messages for 10 seconds in Neuron 98; stopping thread.
# No messages for 10 seconds in Neuron 99; stopping thread.
# No messages for 10 seconds in Neuron 95; stopping thread.
# No messages for 10 seconds in Neuron 104; stopping thread.
# No messages for 10 seconds in Neuron 105; stopping thread.
# No messages for 10 seconds in Neuron 103; stopping thread.
# No messages for 10 seconds in Neuron 101; stopping thread.
# No messages for 10 seconds in Neuron 107; stopping thread.
# No messages for 10 seconds in Neuron 106; stopping thread.
# No messages for 10 seconds in Neuron 102; stopping thread.
# No messages for 10 seconds in Neuron 100; stopping thread.
# No messages for 10 seconds in Neuron 112; stopping thread.
# No messages for 10 seconds in Neuron 113; stopping thread.
# No messages for 10 seconds in Neuron 108; stopping thread.
# No messages for 10 seconds in Neuron 111; stopping thread.
# No messages for 10 seconds in Neuron 115; stopping thread.
# No messages for 10 seconds in Neuron 114; stopping thread.
# No messages for 10 seconds in Neuron 109; stopping thread.
# No messages for 10 seconds in Neuron 110; stopping thread.
# No messages for 10 seconds in Neuron 121; stopping thread.
# No messages for 10 seconds in Neuron 116; stopping thread.
# No messages for 10 seconds in Neuron 123; stopping thread.
# No messages for 10 seconds in Neuron 120; stopping thread.
# No messages for 10 seconds in Neuron 119; stopping thread.
# No messages for 10 seconds in Neuron 117; stopping thread.
# No messages for 10 seconds in Neuron 118; stopping thread.
# No messages for 10 seconds in Neuron 122; stopping thread.
# No messages for 10 seconds in Neuron 124; stopping thread.
# No messages for 10 seconds in Neuron 125; stopping thread.
# No messages for 10 seconds in Neuron 127; stopping thread.
# No messages for 10 seconds in Neuron 126; stopping thread.
# Exception in thread Thread-284:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/tmp/ipykernel_1698/2416226026.py", line 175, in run
# AttributeError: 'Layer' object has no attribute 'neuron_id'
# Exception in thread Thread-286:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/tmp/ipykernel_1698/2416226026.py", line 117, in run
# AttributeError: 'LayerCoordinator' object has no attribute 'neuron_id'
# No messages for 10 seconds in Neuron 0; stopping thread.
# No messages for 10 seconds in Neuron 2; stopping thread.
# No messages for 10 seconds in Neuron 3; stopping thread.
# No messages for 10 seconds in Neuron 1; stopping thread.
# No messages for 10 seconds in Neuron 4; stopping thread.
# No messages for 10 seconds in Neuron 5; stopping thread.
# No messages for 10 seconds in Neuron 6; stopping thread.
# No messages for 10 seconds in Neuron 7; stopping thread.
# No messages for 10 seconds in Neuron 8; stopping thread.
# No messages for 10 seconds in Neuron 9; stopping thread.

# %%
# Send images one by one
for idx, row in df.iterrows():
    image_np = row.iloc[:-1].values.astype(np.float64)
    store_initial_input_data(image_np, idx)
    activate_network(idx)

# Wait for all threads to complete
for thread in neurons + layers + coordinators:
    thread.join()
# Out:
# 📥 Initial input data stored in Redis.
# 🚀 Initial activation sent to activate-layer for layer_0 and image 0
# ✅ Activated Neuron 1 in layer_0 for image 0
# ✅ Activated Neuron 3 in layer_0 for image 0
# ✅ Activated Neuron 0 in layer_0 for image 0
# ✅ Activated Neuron 2 in layer_0 for image 0
# 📥 Initial input data stored in Redis.
# ✅ Activated Neuron 7 in layer_0 for image 0
# ✅ Activated Neuron 5 in layer_0 for image 0
# ✅ Activated Neuron 10 in layer_0 for image 0
# ✅ Activated Neuron 11 in layer_0 for image 0
# ✅ Activated Neuron 6 in layer_0 for image 0
# ✅ Activated Neuron 4 in layer_0 for image 0
# ✅ Activated Neuron 8 in layer_0 for image 0
# ✅ Activated Neuron 9 in layer_0 for image 0
# 🔍 Received output for Neuron 3 and image 0: 0.0
# 🔍 Received output for Neuron 2 and image 0: 2.2311119535381727
# ✅ Activated Neuron 13 in layer_0 for image 0
# ✅ Activated Neuron 15 in layer_0 for image 0
# ✅ Activated Neuron 16 in layer_0 for image 0
# ✅ Activated Neuron 17 in layer_0 for image 0
# ✅ Activated Neuron 18 in layer_0 for image 0
# ✅ Activated Neuron 19 in layer_0 for image 0
# ✅ Activated Neuron 14 in layer_0 for image 0
# ✅ Activated Neuron 12 in layer_0 for image 0
# 🔍 Received output for Neuron 1 and image 0: 1.0285565756125576
# 🔍 Received output for Neuron 6 and image 0: 3.7727046527839527
# 🔍 Received output for Neuron 10 and image 0: 0.0
# 🔍 Received output for Neuron 8 and image 0: 4.321642683619148
# 🔍 Received output for Neuron 0 and image 0: 0.0
# 🔍 Received output for Neuron 7 and image 0: 0.0
# ✅ Activated Neuron 27 in layer_0 for image 0
# ✅ Activated Neuron 25 in layer_0 for image 0
# ✅ Activated Neuron 26 in layer_0 for image 0
# ✅ Activated Neuron 22 in layer_0 for image 0
# ✅ Activated Neuron 23 in layer_0 for image 0
# ✅ Activated Neuron 24 in layer_0 for image 0
# ✅ Activated Neuron 21 in layer_0 for image 0
# ✅ Activated Neuron 20 in layer_0 for image 0
# ✅ Activated Neuron 33 in layer_0 for image 0
# ✅ Activated Neuron 29 in layer_0 for image 0
# ✅ Activated Neuron 35 in layer_0 for image 0
# ✅ Activated Neuron 30 in layer_0 for image 0
# ✅ Activated Neuron 28 in layer_0 for image 0
# ✅ Activated Neuron 31 in layer_0 for image 0
# ✅ Activated Neuron 34 in layer_0 for image 0
# 🔍 Received output for Neuron 11 and image 0: 0.0
# ✅ Activated Neuron 32 in layer_0 for image 0
# 🔍 Received output for Neuron 4 and image 0: 3.5262670475389415
# 🔍 Received output for Neuron 5 and image 0: 0.0
# 🔍 Received output for Neuron 19 and image 0: 0.0
# 🔍 Received output for Neuron 9 and image 0: 0.0
# 🔍 Received output for Neuron 18 and image 0: 7.414502214991407
# 🔍 Received output for Neuron 14 and image 0: 0.0
# 🔍 Received output for Neuron 15 and image 0: 7.071286191568182
# 🚀 Initial activation sent to activate-layer for layer_0 and image 1
# 🔍 Received output for Neuron 12 and image 0: 3.2751154340261444
# 🔍 Received output for Neuron 16 and image 0: 0.0
# 🔍 Received output for Neuron 13 and image 0: 0.0
# 🔍 Received output for Neuron 24 and image 0: 2.8720249810655085
# ✅ Activated Neuron 37 in layer_0 for image 0
# ✅ Activated Neuron 38 in layer_0 for image 0
# ✅ Activated Neuron 39 in layer_0 for image 0
# ✅ Activated Neuron 41 in layer_0 for image 0
# ✅ Activated Neuron 42 in layer_0 for image 0
# ✅ Activated Neuron 40 in layer_0 for image 0
# ✅ Activated Neuron 43 in layer_0 for image 0
# ✅ Activated Neuron 36 in layer_0 for image 0
# 🔍 Received output for Neuron 17 and image 0: 0.0
# 🔍 Received output for Neuron 23 and image 0: 0.0
# 🔍 Received output for Neuron 26 and image 0: 2.131010086261625
# ✅ Activated Neuron 48 in layer_0 for image 0
# ✅ Activated Neuron 45 in layer_0 for image 0
# ✅ Activated Neuron 51 in layer_0 for image 0
# ✅ Activated Neuron 46 in layer_0 for image 0
# ✅ Activated Neuron 47 in layer_0 for image 0
# ✅ Activated Neuron 44 in layer_0 for image 0
# ✅ Activated Neuron 49 in layer_0 for image 0
# ✅ Activated Neuron 50 in layer_0 for image 0
# 📥 Initial input data stored in Redis.
# 🔍 Received output for Neuron 25 and image 0: 0.0
# 🔍 Received output for Neuron 21 and image 0: 0.0
# 🔍 Received output for Neuron 22 and image 0: 6.62872909093244
# 🔍 Received output for Neuron 33 and image 0: 0.0
# 🔍 Received output for Neuron 20 and image 0: 1.9019663169299645
# 🔍 Received output for Neuron 27 and image 0: 0.0
# 🔍 Received output for Neuron 34 and image 0: 0.0
# 🔍 Received output for Neuron 28 and image 0: 0.0
# 🔍 Received output for Neuron 35 and image 0: 0.0
# 🔍 Received output for Neuron 31 and image 0: 0.0
# ✅ Activated Neuron 52 in layer_0 for image 0
# ✅ Activated Neuron 54 in layer_0 for image 0
# ✅ Activated Neuron 55 in layer_0 for image 0
# ✅ Activated Neuron 56 in layer_0 for image 0
# ✅ Activated Neuron 59 in layer_0 for image 0
# ✅ Activated Neuron 57 in layer_0 for image 0
# ✅ Activated Neuron 58 in layer_0 for image 0
# ✅ Activated Neuron 53 in layer_0 for image 0
# 🔍 Received output for Neuron 32 and image 0: 4.786088693407803
# 🔍 Received output for Neuron 29 and image 0: 0.0
# 🔍 Received output for Neuron 37 and image 0: 0.0
# 🔍 Received output for Neuron 36 and image 0: 0.0
# 🔍 Received output for Neuron 39 and image 0: 2.4277216552330785
# 🔍 Received output for Neuron 38 and image 0: 0.0
# 🔍 Received output for Neuron 42 and image 0: 0.0
# 🔍 Received output for Neuron 41 and image 0: 4.420482435587142
# ✅ Activated Neuron 61 in layer_0 for image 0
# ✅ Activated Neuron 63 in layer_0 for image 0
# ✅ Activated Neuron 64 in layer_0 for image 0
# ✅ Activated Neuron 65 in layer_0 for image 0
# ✅ Activated Neuron 66 in layer_0 for image 0
# ✅ Activated Neuron 67 in layer_0 for image 0
# ✅ Activated Neuron 60 in layer_0 for image 0
# ✅ Activated Neuron 62 in layer_0 for image 0
# 🔍 Received output for Neuron 50 and image 0: 6.462321041498492
# 🔍 Received output for Neuron 51 and image 0: 0.0
# 🔍 Received output for Neuron 49 and image 0: 0.0
# 🔍 Received output for Neuron 45 and image 0: 0.0
# 🔍 Received output for Neuron 44 and image 0: 0.0
# 🚀 Initial activation sent to activate-layer for layer_0 and image 2
# ✅ Activated Neuron 69 in layer_0 for image 0
# ✅ Activated Neuron 70 in layer_0 for image 0
# ✅ Activated Neuron 72 in layer_0 for image 0
# ✅ Activated Neuron 73 in layer_0 for image 0
# ✅ Activated Neuron 74 in layer_0 for image 0
# ✅ Activated Neuron 75 in layer_0 for image 0
# ✅ Activated Neuron 68 in layer_0 for image 0
# ✅ Activated Neuron 71 in layer_0 for image 0
# 🔍 Received output for Neuron 48 and image 0: 0.0
# 🔍 Received output for Neuron 46 and image 0: 0.028291041741794615
# 🔍 Received output for Neuron 43 and image 0: 0.0
# 🔍 Received output for Neuron 30 and image 0: 7.153803209011044
# 🔍 Received output for Neuron 47 and image 0: 0.0
# 🔍 Received output for Neuron 40 and image 0: 0.0
# 🔍 Received output for Neuron 55 and image 0: 1.9162726751934027
# 🔍 Received output for Neuron 58 and image 0: 0.0
# 📥 Initial input data stored in Redis.
# ✅ Activated Neuron 76 in layer_0 for image 0
# ✅ Activated Neuron 83 in layer_0 for image 0
# ✅ Activated Neuron 77 in layer_0 for image 0
# ✅ Activated Neuron 79 in layer_0 for image 0
# ✅ Activated Neuron 78 in layer_0 for image 0
# ✅ Activated Neuron 81 in layer_0 for image 0
# ✅ Activated Neuron 80 in layer_0 for image 0
# ✅ Activated Neuron 82 in layer_0 for image 0
# 🔍 Received output for Neuron 52 and image 0: 0.0
# 🔍 Received output for Neuron 54 and image 0: 0.0
# 🔍 Received output for Neuron 53 and image 0: 0.0
# 🔍 Received output for Neuron 57 and image 0: 0.0
# 🔍 Received output for Neuron 66 and image 0: 0.0
# 🔍 Received output for Neuron 61 and image 0: 0.0
# 🔍 Received output for Neuron 63 and image 0: 3.8851744022399095
# ✅ Activated Neuron 84 in layer_0 for image 0
# ✅ Activated Neuron 86 in layer_0 for image 0
# 🔍 Received output for Neuron 65 and image 0: 4.618611006897984
# ✅ Activated Neuron 85 in layer_0 for image 0
# ✅ Activated Neuron 91 in layer_0 for image 0
# ✅ Activated Neuron 87 in layer_0 for image 0
# ✅ Activated Neuron 89 in layer_0 for image 0
# ✅ Activated Neuron 90 in layer_0 for image 0
# ✅ Activated Neuron 88 in layer_0 for image 0
# 🔍 Received output for Neuron 62 and image 0: 3.0157681172587507
# 🔍 Received output for Neuron 64 and image 0: 10.017956033178933
# 🔍 Received output for Neuron 67 and image 0: 0.0
# 🔍 Received output for Neuron 59 and image 0: 5.675490357646747
# 🔍 Received output for Neuron 60 and image 0: 4.047010903924251
# 🔍 Received output for Neuron 56 and image 0: 0.0
# 🔍 Received output for Neuron 71 and image 0: 0.0
# ✅ Activated Neuron 92 in layer_0 for image 0
# ✅ Activated Neuron 94 in layer_0 for image 0
# ✅ Activated Neuron 95 in layer_0 for image 0
# ✅ Activated Neuron 96 in layer_0 for image 0
# ✅ Activated Neuron 97 in layer_0 for image 0
# ✅ Activated Neuron 98 in layer_0 for image 0
# 🔍 Received output for Neuron 74 and image 0: 0.0
# ✅ Activated Neuron 99 in layer_0 for image 0
# ✅ Activated Neuron 93 in layer_0 for image 0
# 🚀 Initial activation sent to activate-layer for layer_0 and image 3
# 🔍 Received output for Neuron 75 and image 0: 0.0
# 🔍 Received output for Neuron 69 and image 0: 0.0
# 🔍 Received output for Neuron 72 and image 0: 0.0
# 🔍 Received output for Neuron 70 and image 0: 0.0
# 🔍 Received output for Neuron 78 and image 0: 10.199375718215862
# 🔍 Received output for Neuron 73 and image 0: 0.0
# 🔍 Received output for Neuron 68 and image 0: 0.0
# 🔍 Received output for Neuron 81 and image 0: 2.9931974754403967
# ✅ Activated Neuron 106 in layer_0 for image 0
# ✅ Activated Neuron 101 in layer_0 for image 0
# ✅ Activated Neuron 107 in layer_0 for image 0
# ✅ Activated Neuron 102 in layer_0 for image 0
# ✅ Activated Neuron 103 in layer_0 for image 0
# ✅ Activated Neuron 104 in layer_0 for image 0
# ✅ Activated Neuron 105 in layer_0 for image 0
# 📥 Initial input data stored in Redis.
# 🔍 Received output for Neuron 76 and image 0: 0.0
# ✅ Activated Neuron 100 in layer_0 for image 0
# 🔍 Received output for Neuron 79 and image 0: 4.165464971020841
# 🔍 Received output for Neuron 82 and image 0: 0.0
# 🔍 Received output for Neuron 77 and image 0: 0.0
# ✅ Activated Neuron 109 in layer_0 for image 0
# 🔍 Received output for Neuron 80 and image 0: 0.08924061469024352
# ✅ Activated Neuron 110 in layer_0 for image 0
# ✅ Activated Neuron 115 in layer_0 for image 0
# ✅ Activated Neuron 114 in layer_0 for image 0
# ✅ Activated Neuron 108 in layer_0 for image 0
# ✅ Activated Neuron 111 in layer_0 for image 0
# ✅ Activated Neuron 112 in layer_0 for image 0
# ✅ Activated Neuron 113 in layer_0 for image 0
# 🔍 Received output for Neuron 83 and image 0: 0.033003394030188815
# 🔍 Received output for Neuron 84 and image 0: 0.0
# ✅ Activated Neuron 123 in layer_0 for image 0
# ✅ Activated Neuron 118 in layer_0 for image 0
# ✅ Activated Neuron 119 in layer_0 for image 0
# ✅ Activated Neuron 120 in layer_0 for image 0
# ✅ Activated Neuron 122 in layer_0 for image 0
# ✅ Activated Neuron 116 in layer_0 for image 0
# ✅ Activated Neuron 121 in layer_0 for image 0
# 🔍 Received output for Neuron 88 and image 0: 0.0
# ✅ Activated Neuron 117 in layer_0 for image 0
# 🔍 Received output for Neuron 87 and image 0: 0.0
# 🔍 Received output for Neuron 90 and image 0: 4.16997889971063
# 🔍 Received output for Neuron 86 and image 0: 0.0
# 🔍 Received output for Neuron 89 and image 0: 0.0
# 🔍 Received output for Neuron 91 and image 0: 0.0
# ✅ Activated Neuron 3 in layer_0 for image 1
# ✅ Activated Neuron 125 in layer_0 for image 0
# ✅ Activated Neuron 126 in layer_0 for image 0
# ✅ Activated Neuron 127 in layer_0 for image 0
# ✅ Activated Neuron 0 in layer_0 for image 1
# ✅ Activated Neuron 1 in layer_0 for image 1
# ✅ Activated Neuron 2 in layer_0 for image 1
# ✅ Activated Neuron 124 in layer_0 for image 0
# 🔍 Received output for Neuron 99 and image 0: 0.0
# 🔍 Received output for Neuron 97 and image 0: 0.0
# 🔍 Received output for Neuron 92 and image 0: 0.0
# 🔍 Received output for Neuron 93 and image 0: 0.0
# ✅ Activated Neuron 4 in layer_0 for image 1
# ✅ Activated Neuron 6 in layer_0 for image 1
# ✅ Activated Neuron 7 in layer_0 for image 1
# ✅ Activated Neuron 8 in layer_0 for image 1
# ✅ Activated Neuron 9 in layer_0 for image 1
# ✅ Activated Neuron 5 in layer_0 for image 1
# 🔍 Received output for Neuron 94 and image 0: 0.0
# 🔍 Received output for Neuron 95 and image 0: 0.0
# 🚀 Initial activation sent to activate-layer for layer_0 and image 4
# 🔍 Received output for Neuron 98 and image 0: 0.0
# 🔍 Received output for Neuron 96 and image 0: 0.0
# 🔍 Received output for Neuron 104 and image 0: 0.0
# 🔍 Received output for Neuron 103 and image 0: 0.0
# 🔍 Received output for Neuron 100 and image 0: 0.0
# 🔍 Received output for Neuron 106 and image 0: 1.7691193724110863
# 🔍 Received output for Neuron 102 and image 0: 0.0
# 🔍 Received output for Neuron 101 and image 0: 5.286582705603713
# 📥 Initial input data stored in Redis.
# 🔍 Received output for Neuron 85 and image 0: 0.0
# 🔍 Received output for Neuron 113 and image 0: 0.0
# 🔍 Received output for Neuron 107 and image 0: 0.0
# ✅ Activated Neuron 12 in layer_0 for image 1
# ✅ Activated Neuron 11 in layer_0 for image 1
# ✅ Activated Neuron 10 in layer_0 for image 1
# 🔍 Received output for Neuron 109 and image 0: 0.0
# 🔍 Received output for Neuron 114 and image 0: 2.8119947811262787
# 🔍 Received output for Neuron 115 and image 0: 0.0
# 🔍 Received output for Neuron 111 and image 0: 3.9578771193286806
# 🔍 Received output for Neuron 110 and image 0: 0.40866483687021915
# 🔍 Received output for Neuron 121 and image 0: 0.0
# 🔍 Received output for Neuron 112 and image 0: 3.9527472866578655
# 🔍 Received output for Neuron 118 and image 0: 0.0
# 🔍 Received output for Neuron 116 and image 0: 2.3189490103518513
# 🔍 Received output for Neuron 120 and image 0: 0.0
# 🔍 Received output for Neuron 123 and image 0: 0.0
# 🔍 Received output for Neuron 122 and image 0: 0.0
# 🔍 Received output for Neuron 0 and image 1: 1.8688847743489465
# 🔍 Received output for Neuron 2 and image 1: 0.18511520004251847
# 🔍 Received output for Neuron 3 and image 1: 0.0
# 🔍 Received output for Neuron 119 and image 0: 5.796542986923228
# 🔍 Received output for Neuron 1 and image 1: 0.0
# 🔍 Received output for Neuron 117 and image 0: 0.0
# 🔍 Received output for Neuron 124 and image 0: 4.588778625321133
# 🔍 Received output for Neuron 125 and image 0: 0.0
# 🔍 Received output for Neuron 5 and image 1: 0.0
# 🔍 Received output for Neuron 4 and image 1: 0.0
# 🔍 Received output for Neuron 126 and image 0: 0.0
# 🔍 Received output for Neuron 8 and image 1: 0.07973160386456324
# 🔍 Received output for Neuron 6 and image 1: 1.5490288624878272
# 🔍 Received output for Neuron 7 and image 1: 0.0
# 🔍 Received output for Neuron 127 and image 0: 0.0
# 🔍 Received output for Neuron 9 and image 1: 0.0
# 🔍 Received output for Neuron 105 and image 0: 0.0
# 🚀 Initial activation sent to activate-layer for layer_0 and image 5
# ✅ Activated Neuron 13 in layer_0 for image 1
# 🔍 Received output for Neuron 11 and image 1: 0.0
# 🔍 Received output for Neuron 12 and image 1: 0.0
# ✅ Activated Neuron 15 in layer_0 for image 1
# ✅ Activated Neuron 16 in layer_0 for image 1
# ✅ Activated Neuron 14 in layer_0 for image 1
# 🔍 Received output for Neuron 10 and image 1: 0.0
# 🔍 Received output for Neuron 108 and image 0: 0.0
# 🟢 Aggregating outputs for image 0 on layer layer_0
# ✅ Activated Neuron 17 in layer_0 for image 1
# 🔍 Received output for Neuron 13 and image 1: 0.0
# ✅ Activated Neuron 19 in layer_0 for image 1
# ✅ Activated Neuron 20 in layer_0 for image 1
# ✅ Activated Neuron 21 in layer_0 for image 1
# ✅ Activated Neuron 22 in layer_0 for image 1
# ✅ Activated Neuron 18 in layer_0 for image 1
# ✅ Activated Neuron 23 in layer_0 for image 1
# ✅ Activated Neuron 24 in layer_0 for image 1
# 🔍 Received output for Neuron 14 and image 1: 0.0
# 🔍 Received output for Neuron 18 and image 1: 0.0
# 📥 Initial input data stored in Redis.
# ✅ Activated Neuron 27 in layer_0 for image 1
# ✅ Activated Neuron 28 in layer_0 for image 1
# ✅ Activated Neuron 30 in layer_0 for image 1
# ✅ Activated Neuron 31 in layer_0 for image 1
# ✅ Activated Neuron 32 in layer_0 for image 1
# ✅ Activated Neuron 25 in layer_0 for image 1
# ✅ Activated Neuron 26 in layer_0 for image 1
# 🔍 Received output for Neuron 15 and image 1: 0.0
# ✅ Activated Neuron 29 in layer_0 for image 1
# 🔍 Received output for Neuron 21 and image 1: 0.0
# 🔍 Received output for Neuron 16 and image 1: 0.0
# 🔍 Received output for Neuron 23 and image 1: 5.121950911728728
# 🔍 Received output for Neuron 20 and image 1: 6.385523378747793
# 🔍 Received output for Neuron 17 and image 1: 8.550638000545185
# 🔍 Received output for Neuron 32 and image 1: 1.5386311261586698
# 🔍 Received output for Neuron 22 and image 1: 8.994970717836344
# 🔍 Received output for Neuron 19 and image 1: 0.0
# 🚀 Activating next layer: layer_1 for image 0
# 🔍 Received output for Neuron 25 and image 1: 0.0
# 🔍 Received output for Neuron 28 and image 1: 4.44740902703968
# 🔍 Received output for Neuron 30 and image 1: 0.0
# 🔍 Received output for Neuron 24 and image 1: 0.0
# ✅ Activated Neuron 0 in layer_1 for image 0
# ✅ Activated Neuron 3 in layer_1 for image 0
# ✅ Activated Neuron 5 in layer_1 for image 0
# ✅ Activated Neuron 6 in layer_1 for image 0
# ✅ Activated Neuron 7 in layer_1 for image 0
# ✅ Activated Neuron 2 in layer_1 for image 0
# ✅ Activated Neuron 1 in layer_1 for image 0
# ✅ Activated Neuron 40 in layer_0 for image 1
# ✅ Activated Neuron 35 in layer_0 for image 1
# ✅ Activated Neuron 36 in layer_0 for image 1
# ✅ Activated Neuron 39 in layer_0 for image 1
# ✅ Activated Neuron 33 in layer_0 for image 1
# ✅ Activated Neuron 4 in layer_1 for image 0
# ✅ Activated Neuron 34 in layer_0 for image 1
# ✅ Activated Neuron 37 in layer_0 for image 1
# ✅ Activated Neuron 38 in layer_0 for image 1
# 🔍 Received output for Neuron 26 and image 1: 0.0
# ✅ Activated Neuron 9 in layer_1 for image 0
# 🔍 Received output for Neuron 29 and image 1: 0.0
# 🔍 Received output for Neuron 31 and image 1: 0.0
# 🔍 Received output for Neuron 27 and image 1: 0.0
# ✅ Activated Neuron 8 in layer_1 for image 0
# 🔍 Received output for Neuron 33 and image 1: 0.0
# 🔍 Received output for Neuron 35 and image 1: 0.0
# 🔍 Received output for Neuron 37 and image 1: 0.0
# 🔍 Received output for Neuron 38 and image 1: 0.0
# 🔍 Received output for Neuron 2 and image 0: -2.542845800594375
# 🔍 Received output for Neuron 4 and image 0: -10.954757109879182
# ✅ Activated Neuron 41 in layer_0 for image 1
# ✅ Activated Neuron 43 in layer_0 for image 1
# ✅ Activated Neuron 44 in layer_0 for image 1
# ✅ Activated Neuron 46 in layer_0 for image 1
# ✅ Activated Neuron 45 in layer_0 for image 1
# ✅ Activated Neuron 47 in layer_0 for image 1
# ✅ Activated Neuron 48 in layer_0 for image 1
# ✅ Activated Neuron 42 in layer_0 for image 1
# 🔍 Received output for Neuron 40 and image 1: 0.0
# 🔍 Received output for Neuron 1 and image 0: -11.243634546058475
# 🔍 Received output for Neuron 36 and image 1: 0.0
# 🔍 Received output for Neuron 3 and image 0: 2.5094254824845152
# 🔍 Received output for Neuron 7 and image 0: 11.062075426343023
# 🔍 Received output for Neuron 39 and image 1: 0.0
# 🔍 Received output for Neuron 34 and image 1: 0.0
# 🔍 Received output for Neuron 5 and image 0: -4.378832594745012
# 🔍 Received output for Neuron 6 and image 0: -12.853611297532014
# ✅ Activated Neuron 49 in layer_0 for image 1
# ✅ Activated Neuron 51 in layer_0 for image 1
# ✅ Activated Neuron 50 in layer_0 for image 1
# ✅ Activated Neuron 53 in layer_0 for image 1
# ✅ Activated Neuron 54 in layer_0 for image 1
# ✅ Activated Neuron 52 in layer_0 for image 1
# ✅ Activated Neuron 56 in layer_0 for image 1
# ✅ Activated Neuron 55 in layer_0 for image 1
# 🔍 Received output for Neuron 0 and image 0: -6.867582317209552
# ✅ Activated Neuron 63 in layer_0 for image 1
# ✅ Activated Neuron 64 in layer_0 for image 1
# ✅ Activated Neuron 59 in layer_0 for image 1
# 🔍 Received output for Neuron 42 and image 1: 9.140240474475233
# ✅ Activated Neuron 60 in layer_0 for image 1
# ✅ Activated Neuron 61 in layer_0 for image 1
# ✅ Activated Neuron 62 in layer_0 for image 1
# ✅ Activated Neuron 58 in layer_0 for image 1
# ✅ Activated Neuron 57 in layer_0 for image 1
# 🔍 Received output for Neuron 47 and image 1: 0.0
# 🔍 Received output for Neuron 44 and image 1: 0.0
# 🔍 Received output for Neuron 45 and image 1: 0.0
# 🔍 Received output for Neuron 46 and image 1: 0.0
# 🔍 Received output for Neuron 48 and image 1: 6.833550390385879
# 🔍 Received output for Neuron 41 and image 1: 2.2881523634669847
# 🔍 Received output for Neuron 50 and image 1: 0.0
# 🔍 Received output for Neuron 43 and image 1: 0.0
# 🔍 Received output for Neuron 8 and image 0: -3.2350892974173417
# ✅ Activated Neuron 72 in layer_0 for image 1
# ✅ Activated Neuron 68 in layer_0 for image 1
# ✅ Activated Neuron 69 in layer_0 for image 1
# ✅ Activated Neuron 70 in layer_0 for image 1
# ✅ Activated Neuron 71 in layer_0 for image 1
# 🚀 Initial activation sent to activate-layer for layer_0 and image 6
# ✅ Activated Neuron 66 in layer_0 for image 1
# ✅ Activated Neuron 67 in layer_0 for image 1
# ✅ Activated Neuron 65 in layer_0 for image 1
# 🔍 Received output for Neuron 51 and image 1: 5.031456394289796
# 🔍 Received output for Neuron 52 and image 1: 0.0
# 🔍 Received output for Neuron 53 and image 1: 0.0
# 🔍 Received output for Neuron 56 and image 1: 0.0
# 🔍 Received output for Neuron 54 and image 1: 5.835899212955684
# 🔍 Received output for Neuron 64 and image 1: 0.0
# 🔍 Received output for Neuron 55 and image 1: 4.687214475758783
# 🔍 Received output for Neuron 58 and image 1: 1.8702709853095802
# 🔍 Received output for Neuron 49 and image 1: 0.0
# 🔍 Received output for Neuron 9 and image 0: -4.09878555404558
# 🟢 Aggregating outputs for image 0 on layer layer_1
# 🔍 Received output for Neuron 57 and image 1: 0.0
# 🔍 Received output for Neuron 60 and image 1: 0.0
# 🔍 Received output for Neuron 63 and image 1: 0.0
# 🔍 Received output for Neuron 61 and image 1: 1.814893781253189
# 📥 Initial input data stored in Redis.
# 🔍 Received output for Neuron 62 and image 1: 0.0
# 🔍 Received output for Neuron 59 and image 1: 0.0
# ✅ Activated Neuron 73 in layer_0 for image 1
# ✅ Activated Neuron 80 in layer_0 for image 1
# ✅ Activated Neuron 75 in layer_0 for image 1
# ✅ Activated Neuron 76 in layer_0 for image 1
# ✅ Activated Neuron 77 in layer_0 for image 1
# ✅ Activated Neuron 78 in layer_0 for image 1
# ✅ Activated Neuron 79 in layer_0 for image 1
# ✅ Activated Neuron 74 in layer_0 for image 1
# 🔍 Received output for Neuron 72 and image 1: 0.0
# 🔍 Received output for Neuron 69 and image 1: 0.0
# 🔍 Received output for Neuron 70 and image 1: 0.0
# 🔍 Received output for Neuron 67 and image 1: 4.293497453909125
# 🔍 Received output for Neuron 71 and image 1: 0.0
# 🔍 Received output for Neuron 66 and image 1: 0.0
# ✅ Activated Neuron 88 in layer_0 for image 1
# ✅ Activated Neuron 83 in layer_0 for image 1
# ✅ Activated Neuron 84 in layer_0 for image 1
# ✅ Activated Neuron 85 in layer_0 for image 1
# ✅ Activated Neuron 86 in layer_0 for image 1
# ✅ Activated Neuron 87 in layer_0 for image 1
# ✅ Activated Neuron 82 in layer_0 for image 1
# 🔍 Received output for Neuron 68 and image 1: 0.0
# 🔍 Received output for Neuron 78 and image 1: 0.0
# ✅ Activated Neuron 81 in layer_0 for image 1
# 🔍 Received output for Neuron 65 and image 1: 0.0
# 🎯 Final Prediction for image 0: 7
# 🔍 Received output for Neuron 73 and image 1: 0.0
# 🔍 Received output for Neuron 77 and image 1: 14.206964991464677
# 🔍 Received output for Neuron 74 and image 1: 0.0
# 🔍 Received output for Neuron 76 and image 1: 0.0
# 🔍 Received output for Neuron 80 and image 1: 0.0
# 🔍 Received output for Neuron 85 and image 1: 0.0
# ✅ Activated Neuron 90 in layer_0 for image 1
# ✅ Activated Neuron 92 in layer_0 for image 1
# ✅ Activated Neuron 93 in layer_0 for image 1
# ✅ Activated Neuron 94 in layer_0 for image 1
# ✅ Activated Neuron 95 in layer_0 for image 1
# ✅ Activated Neuron 96 in layer_0 for image 1
# ✅ Activated Neuron 89 in layer_0 for image 1
# ✅ Activated Neuron 91 in layer_0 for image 1
# 🔍 Received output for Neuron 88 and image 1: 0.0
# 🔍 Received output for Neuron 86 and image 1: 0.0
# 🔍 Received output for Neuron 79 and image 1: 1.8109701447921709
# 🔍 Received output for Neuron 87 and image 1: 5.243300790715361
# 🔍 Received output for Neuron 83 and image 1: 0.0
# 🔍 Received output for Neuron 75 and image 1: 0.0
# 🔍 Received output for Neuron 94 and image 1: 4.999135166536048
# 🔍 Received output for Neuron 81 and image 1: 0.0
# 🔍 Received output for Neuron 90 and image 1: 0.19557434822592057
# 🔍 Received output for Neuron 89 and image 1: 0.0
# 🔍 Received output for Neuron 93 and image 1: 0.0
# 🔍 Received output for Neuron 84 and image 1: 0.0
# 🔍 Received output for Neuron 95 and image 1: 0.0
# 🔍 Received output for Neuron 96 and image 1: 0.0
# 🔍 Received output for Neuron 91 and image 1: 0.0
# ✅ Activated Neuron 97 in layer_0 for image 1
# ✅ Activated Neuron 99 in layer_0 for image 1
# ✅ Activated Neuron 100 in layer_0 for image 1
# ✅ Activated Neuron 101 in layer_0 for image 1
# ✅ Activated Neuron 102 in layer_0 for image 1
# ✅ Activated Neuron 103 in layer_0 for image 1
# ✅ Activated Neuron 104 in layer_0 for image 1
# ✅ Activated Neuron 98 in layer_0 for image 1
# 🔍 Received output for Neuron 92 and image 1: 0.0
# 🔍 Received output for Neuron 82 and image 1: 1.2150718441174053
# 🔍 Received output for Neuron 98 and image 1: 0.0
# 🔍 Received output for Neuron 102 and image 1: 0.0
# 🔍 Received output for Neuron 99 and image 1: 0.0
# 🔍 Received output for Neuron 103 and image 1: 0.0
# 🔍 Received output for Neuron 100 and image 1: 0.0
# 🔍 Received output for Neuron 101 and image 1: 0.0
# 🚀 Initial activation sent to activate-layer for layer_0 and image 7
# 🔍 Received output for Neuron 97 and image 1: 0.0
# 🔍 Received output for Neuron 104 and image 1: 0.0
# ✅ Activated Neuron 107 in layer_0 for image 1
# ✅ Activated Neuron 109 in layer_0 for image 1
# ✅ Activated Neuron 110 in layer_0 for image 1
# ✅ Activated Neuron 111 in layer_0 for image 1
# ✅ Activated Neuron 108 in layer_0 for image 1
# ✅ Activated Neuron 105 in layer_0 for image 1
# ✅ Activated Neuron 112 in layer_0 for image 1
# ✅ Activated Neuron 106 in layer_0 for image 1
# 🔍 Received output for Neuron 111 and image 1: 0.0
# 🔍 Received output for Neuron 105 and image 1: 2.217096148314303
# 📥 Initial input data stored in Redis.
# 🔍 Received output for Neuron 110 and image 1: 7.972506326184247
# 🔍 Received output for Neuron 107 and image 1: 0.0
# 🔍 Received output for Neuron 108 and image 1: 0.0
# 🔍 Received output for Neuron 106 and image 1: 4.807984956311325
# 🔍 Received output for Neuron 109 and image 1: 0.0
# ✅ Activated Neuron 119 in layer_0 for image 1
# ✅ Activated Neuron 118 in layer_0 for image 1
# ✅ Activated Neuron 114 in layer_0 for image 1
# ✅ Activated Neuron 120 in layer_0 for image 1
# ✅ Activated Neuron 116 in layer_0 for image 1
# ✅ Activated Neuron 115 in layer_0 for image 1
# ✅ Activated Neuron 117 in layer_0 for image 1
# ✅ Activated Neuron 113 in layer_0 for image 1
# 🔍 Received output for Neuron 112 and image 1: 0.0
# 🔍 Received output for Neuron 117 and image 1: 0.0
# 🔍 Received output for Neuron 114 and image 1: 9.986496783927617
# 🔍 Received output for Neuron 118 and image 1: 0.0
# 🔍 Received output for Neuron 119 and image 1: 0.0
# 🔍 Received output for Neuron 113 and image 1: 5.592418360255667
# 🔍 Received output for Neuron 116 and image 1: 7.3342666949390445
# 🔍 Received output for Neuron 115 and image 1: 0.0
# 🔍 Received output for Neuron 120 and image 1: 5.87764257973972
# ✅ Activated Neuron 124 in layer_0 for image 1
# ✅ Activated Neuron 127 in layer_0 for image 1
# ✅ Activated Neuron 126 in layer_0 for image 1
# ✅ Activated Neuron 0 in layer_0 for image 2
# ✅ Activated Neuron 121 in layer_0 for image 1
# ✅ Activated Neuron 122 in layer_0 for image 1
# ✅ Activated Neuron 123 in layer_0 for image 1
# ✅ Activated Neuron 125 in layer_0 for image 1
# 🔍 Received output for Neuron 127 and image 1: 0.0
# 🔍 Received output for Neuron 0 and image 2: 0.2647896860341992
# 🔍 Received output for Neuron 121 and image 1: 0.0
# 🔍 Received output for Neuron 125 and image 1: 0.0
# 🔍 Received output for Neuron 123 and image 1: 0.0
# 🔍 Received output for Neuron 122 and image 1: 0.0
# 🔍 Received output for Neuron 126 and image 1: 0.0
# 🔍 Received output for Neuron 124 and image 1: 3.941282662610277
# 🟢 Aggregating outputs for image 1 on layer layer_0
# ✅ Activated Neuron 1 in layer_0 for image 2
# ✅ Activated Neuron 2 in layer_0 for image 2
# ✅ Activated Neuron 3 in layer_0 for image 2
# ✅ Activated Neuron 4 in layer_0 for image 2
# ✅ Activated Neuron 5 in layer_0 for image 2
# ✅ Activated Neuron 6 in layer_0 for image 2
# ✅ Activated Neuron 7 in layer_0 for image 2
# ✅ Activated Neuron 8 in layer_0 for image 2
# 🚀 Activating next layer: layer_1 for image 1
# 🔍 Received output for Neuron 3 and image 2: 4.391325292455447
# 🔍 Received output for Neuron 6 and image 2: 0.0
# ✅ Activated Neuron 0 in layer_1 for image 1
# ✅ Activated Neuron 1 in layer_1 for image 1
# ✅ Activated Neuron 2 in layer_1 for image 1
# 🔍 Received output for Neuron 4 and image 2: 0.0
# 🔍 Received output for Neuron 8 and image 2: 3.197959659910226
# 🔍 Received output for Neuron 1 and image 2: 0.031371611418220535
# 🔍 Received output for Neuron 2 and image 2: 2.1769534512291875
# ✅ Activated Neuron 10 in layer_0 for image 2
# ✅ Activated Neuron 13 in layer_0 for image 2
# ✅ Activated Neuron 14 in layer_0 for image 2
# ✅ Activated Neuron 15 in layer_0 for image 2
# ✅ Activated Neuron 16 in layer_0 for image 2
# ✅ Activated Neuron 12 in layer_0 for image 2
# ✅ Activated Neuron 11 in layer_0 for image 2
# 🔍 Received output for Neuron 1 and image 1: 1.3325118118382608
# ✅ Activated Neuron 9 in layer_0 for image 2
# 🔍 Received output for Neuron 7 and image 2: 0.0
# 🔍 Received output for Neuron 5 and image 2: 0.0
# 🔍 Received output for Neuron 0 and image 1: -0.85861474887442
# 🔍 Received output for Neuron 5 and image 1: -2.97403239670082
# 🔍 Received output for Neuron 9 and image 2: 0.0
# ✅ Activated Neuron 3 in layer_1 for image 1
# ✅ Activated Neuron 7 in layer_1 for image 1
# ✅ Activated Neuron 4 in layer_1 for image 1
# ✅ Activated Neuron 8 in layer_1 for image 1
# ✅ Activated Neuron 9 in layer_1 for image 1
# ✅ Activated Neuron 5 in layer_1 for image 1
# ✅ Activated Neuron 6 in layer_1 for image 1
# 🔍 Received output for Neuron 3 and image 1: 0.9121538665714213
# 🔍 Received output for Neuron 7 and image 1: -8.262975222068205
# 🔍 Received output for Neuron 2 and image 1: 10.39621737730393
# 🔍 Received output for Neuron 11 and image 2: 0.0
# 🔍 Received output for Neuron 14 and image 2: 0.0
# 🔍 Received output for Neuron 10 and image 2: 0.0
# 🔍 Received output for Neuron 16 and image 2: 0.0
# 🔍 Received output for Neuron 12 and image 2: 0.0
# 🔍 Received output for Neuron 15 and image 2: 3.7491586261972074
# 🔍 Received output for Neuron 13 and image 2: 0.0
# 🔍 Received output for Neuron 4 and image 1: -13.354509610138908
# ✅ Activated Neuron 24 in layer_0 for image 2
# ✅ Activated Neuron 19 in layer_0 for image 2
# ✅ Activated Neuron 20 in layer_0 for image 2
# ✅ Activated Neuron 21 in layer_0 for image 2
# ✅ Activated Neuron 22 in layer_0 for image 2
# ✅ Activated Neuron 23 in layer_0 for image 2
# ✅ Activated Neuron 18 in layer_0 for image 2
# ✅ Activated Neuron 17 in layer_0 for image 2
# 🔍 Received output for Neuron 6 and image 1: -0.7163351298627791
# 🔍 Received output for Neuron 9 and image 1: -16.28722297237999
# 🔍 Received output for Neuron 8 and image 1: -0.6595345915203961
# 🟢 Aggregating outputs for image 1 on layer layer_1
# 🚀 Initial activation sent to activate-layer for layer_0 and image 8
# 🔍 Received output for Neuron 24 and image 2: 4.094255046415741
# 🎯 Final Prediction for image 1: 2
# 🔍 Received output for Neuron 17 and image 2: 3.926425711040047
# 🔍 Received output for Neuron 21 and image 2: 0.0
# 🔍 Received output for Neuron 19 and image 2: 0.0
# 🔍 Received output for Neuron 23 and image 2: 0.0
# 🔍 Received output for Neuron 20 and image 2: 0.5496832691983783
# 🔍 Received output for Neuron 18 and image 2: 0.0
# ✅ Activated Neuron 25 in layer_0 for image 2
# ✅ Activated Neuron 26 in layer_0 for image 2
# ✅ Activated Neuron 27 in layer_0 for image 2
# ✅ Activated Neuron 28 in layer_0 for image 2
# ✅ Activated Neuron 29 in layer_0 for image 2
# ✅ Activated Neuron 30 in layer_0 for image 2
# ✅ Activated Neuron 31 in layer_0 for image 2
# ✅ Activated Neuron 32 in layer_0 for image 2
# 🔍 Received output for Neuron 22 and image 2: 0.7489851799098646
# 🔍 Received output for Neuron 27 and image 2: 0.0
# 📥 Initial input data stored in Redis.
# 🔍 Received output for Neuron 31 and image 2: 0.0
# 🔍 Received output for Neuron 25 and image 2: 0.0
# 🔍 Received output for Neuron 28 and image 2: 6.976513229572072
# 🔍 Received output for Neuron 29 and image 2: 0.0
# 🔍 Received output for Neuron 26 and image 2: 0.0
# 🔍 Received output for Neuron 32 and image 2: 0.0
# ✅ Activated Neuron 35 in layer_0 for image 2
# ✅ Activated Neuron 37 in layer_0 for image 2
# ✅ Activated Neuron 38 in layer_0 for image 2
# ✅ Activated Neuron 39 in layer_0 for image 2
# ✅ Activated Neuron 33 in layer_0 for image 2
# ✅ Activated Neuron 40 in layer_0 for image 2
# ✅ Activated Neuron 34 in layer_0 for image 2
# ✅ Activated Neuron 36 in layer_0 for image 2
# 🔍 Received output for Neuron 30 and image 2: 0.049688762820784216
# 🔍 Received output for Neuron 35 and image 2: 2.5367952087823307
# 🔍 Received output for Neuron 37 and image 2: 0.0
# 🔍 Received output for Neuron 34 and image 2: 0.0
# 🔍 Received output for Neuron 39 and image 2: 0.0
# 🔍 Received output for Neuron 40 and image 2: 0.0
# 🔍 Received output for Neuron 33 and image 2: 0.0
# 🔍 Received output for Neuron 38 and image 2: 0.0
# 🔍 Received output for Neuron 36 and image 2: 0.0
# ✅ Activated Neuron 42 in layer_0 for image 2
# ✅ Activated Neuron 44 in layer_0 for image 2
# ✅ Activated Neuron 45 in layer_0 for image 2
# ✅ Activated Neuron 46 in layer_0 for image 2
# ✅ Activated Neuron 47 in layer_0 for image 2
# ✅ Activated Neuron 48 in layer_0 for image 2
# ✅ Activated Neuron 41 in layer_0 for image 2
# ✅ Activated Neuron 43 in layer_0 for image 2
# 🔍 Received output for Neuron 45 and image 2: 0.0
# 🔍 Received output for Neuron 47 and image 2: 0.0
# 🔍 Received output for Neuron 46 and image 2: 0.0
# 🔍 Received output for Neuron 43 and image 2: 0.0
# 🔍 Received output for Neuron 41 and image 2: 0.0
# 🔍 Received output for Neuron 44 and image 2: 0.0
# 🔍 Received output for Neuron 42 and image 2: 6.916702342629901
# 🔍 Received output for Neuron 48 and image 2: 2.5293580758646907
# ✅ Activated Neuron 51 in layer_0 for image 2
# ✅ Activated Neuron 52 in layer_0 for image 2
# ✅ Activated Neuron 53 in layer_0 for image 2
# ✅ Activated Neuron 54 in layer_0 for image 2
# ✅ Activated Neuron 55 in layer_0 for image 2
# ✅ Activated Neuron 56 in layer_0 for image 2
# ✅ Activated Neuron 50 in layer_0 for image 2
# ✅ Activated Neuron 49 in layer_0 for image 2
# 🔍 Received output for Neuron 52 and image 2: 0.0
# 🔍 Received output for Neuron 51 and image 2: 0.0
# 🔍 Received output for Neuron 54 and image 2: 0.748275181713743
# 🔍 Received output for Neuron 49 and image 2: 0.0
# 🔍 Received output for Neuron 56 and image 2: 0.0
# 🔍 Received output for Neuron 53 and image 2: 0.0
# 🔍 Received output for Neuron 50 and image 2: 0.0
# 🔍 Received output for Neuron 55 and image 2: 2.1214264480101637
# ✅ Activated Neuron 58 in layer_0 for image 2
# ✅ Activated Neuron 59 in layer_0 for image 2
# ✅ Activated Neuron 61 in layer_0 for image 2
# ✅ Activated Neuron 62 in layer_0 for image 2
# ✅ Activated Neuron 63 in layer_0 for image 2
# ✅ Activated Neuron 64 in layer_0 for image 2
# ✅ Activated Neuron 57 in layer_0 for image 2
# ✅ Activated Neuron 60 in layer_0 for image 2
# 🔍 Received output for Neuron 57 and image 2: 0.0
# 🔍 Received output for Neuron 63 and image 2: 0.0
# 🔍 Received output for Neuron 64 and image 2: 0.0
# 🔍 Received output for Neuron 62 and image 2: 0.0
# 🔍 Received output for Neuron 60 and image 2: 2.2131844366300335
# 🔍 Received output for Neuron 58 and image 2: 5.590005948945845
# 🔍 Received output for Neuron 59 and image 2: 1.6319348277254424
# 🔍 Received output for Neuron 61 and image 2: 0.394399648058929
# 🚀 Initial activation sent to activate-layer for layer_0 and image 9
# ✅ Activated Neuron 65 in layer_0 for image 2
# ✅ Activated Neuron 68 in layer_0 for image 2
# ✅ Activated Neuron 69 in layer_0 for image 2
# ✅ Activated Neuron 70 in layer_0 for image 2
# ✅ Activated Neuron 71 in layer_0 for image 2
# ✅ Activated Neuron 72 in layer_0 for image 2
# ✅ Activated Neuron 66 in layer_0 for image 2
# ✅ Activated Neuron 67 in layer_0 for image 2
# 🔍 Received output for Neuron 71 and image 2: 0.0
# 🔍 Received output for Neuron 69 and image 2: 0.0
# 🔍 Received output for Neuron 70 and image 2: 0.0
# 🔍 Received output for Neuron 72 and image 2: 0.0
# 🔍 Received output for Neuron 66 and image 2: 0.0
# 🔍 Received output for Neuron 67 and image 2: 0.0
# 🔍 Received output for Neuron 65 and image 2: 3.817662720266078
# 🔍 Received output for Neuron 68 and image 2: 0.09232164487610062
# ✅ Activated Neuron 74 in layer_0 for image 2
# ✅ Activated Neuron 76 in layer_0 for image 2
# ✅ Activated Neuron 77 in layer_0 for image 2
# ✅ Activated Neuron 78 in layer_0 for image 2
# ✅ Activated Neuron 79 in layer_0 for image 2
# ✅ Activated Neuron 80 in layer_0 for image 2
# ✅ Activated Neuron 73 in layer_0 for image 2
# ✅ Activated Neuron 75 in layer_0 for image 2
# 🔍 Received output for Neuron 77 and image 2: 4.6791564466918185
# 🔍 Received output for Neuron 74 and image 2: 0.0
# 🔍 Received output for Neuron 80 and image 2: 0.0
# 🔍 Received output for Neuron 75 and image 2: 0.0
# 🔍 Received output for Neuron 73 and image 2: 0.0
# ✅ Activated Neuron 81 in layer_0 for image 2
# ✅ Activated Neuron 83 in layer_0 for image 2
# ✅ Activated Neuron 84 in layer_0 for image 2
# ✅ Activated Neuron 85 in layer_0 for image 2
# ✅ Activated Neuron 86 in layer_0 for image 2
# ✅ Activated Neuron 87 in layer_0 for image 2
# ✅ Activated Neuron 88 in layer_0 for image 2
# ✅ Activated Neuron 82 in layer_0 for image 2
# 🔍 Received output for Neuron 78 and image 2: 7.201951008054515
# 🔍 Received output for Neuron 79 and image 2: 1.5446053819606809
# 🔍 Received output for Neuron 76 and image 2: 0.0
# 🔍 Received output for Neuron 86 and image 2: 0.0
# 🔍 Received output for Neuron 87 and image 2: 0.0
# 🔍 Received output for Neuron 84 and image 2: 0.0
# 🔍 Received output for Neuron 81 and image 2: 0.0
# 🔍 Received output for Neuron 82 and image 2: 0.0
# 🔍 Received output for Neuron 88 and image 2: 0.0
# 🔍 Received output for Neuron 83 and image 2: 0.9928437019856649
# 🔍 Received output for Neuron 85 and image 2: 0.0
# ✅ Activated Neuron 96 in layer_0 for image 2
# ✅ Activated Neuron 91 in layer_0 for image 2
# ✅ Activated Neuron 93 in layer_0 for image 2
# ✅ Activated Neuron 92 in layer_0 for image 2
# ✅ Activated Neuron 94 in layer_0 for image 2
# ✅ Activated Neuron 95 in layer_0 for image 2
# ✅ Activated Neuron 89 in layer_0 for image 2
# ✅ Activated Neuron 90 in layer_0 for image 2
# 🔍 Received output for Neuron 96 and image 2: 0.0
# 🔍 Received output for Neuron 93 and image 2: 0.0
# 🔍 Received output for Neuron 89 and image 2: 0.0
# 🔍 Received output for Neuron 92 and image 2: 0.0
# 🔍 Received output for Neuron 94 and image 2: 2.020697122735246
# 🔍 Received output for Neuron 95 and image 2: 0.0
# 🔍 Received output for Neuron 91 and image 2: 0.0
# 🔍 Received output for Neuron 90 and image 2: 0.8742084621584063
# ✅ Activated Neuron 97 in layer_0 for image 2
# ✅ Activated Neuron 99 in layer_0 for image 2
# ✅ Activated Neuron 100 in layer_0 for image 2
# ✅ Activated Neuron 101 in layer_0 for image 2
# ✅ Activated Neuron 102 in layer_0 for image 2
# ✅ Activated Neuron 104 in layer_0 for image 2
# ✅ Activated Neuron 103 in layer_0 for image 2
# ✅ Activated Neuron 98 in layer_0 for image 2
# 🔍 Received output for Neuron 100 and image 2: 0.0
# 🔍 Received output for Neuron 97 and image 2: 0.0
# 🔍 Received output for Neuron 101 and image 2: 0.005829127567029024
# 🔍 Received output for Neuron 99 and image 2: 0.0
# 🔍 Received output for Neuron 104 and image 2: 4.93043268034805
# 🔍 Received output for Neuron 103 and image 2: 4.875721908451294
# 🔍 Received output for Neuron 98 and image 2: 0.0
# 🔍 Received output for Neuron 102 and image 2: 0.0
# ✅ Activated Neuron 105 in layer_0 for image 2
# ✅ Activated Neuron 106 in layer_0 for image 2
# ✅ Activated Neuron 108 in layer_0 for image 2
# ✅ Activated Neuron 109 in layer_0 for image 2
# ✅ Activated Neuron 111 in layer_0 for image 2
# ✅ Activated Neuron 112 in layer_0 for image 2
# ✅ Activated Neuron 110 in layer_0 for image 2
# ✅ Activated Neuron 107 in layer_0 for image 2
# 🔍 Received output for Neuron 109 and image 2: 0.0
# 🔍 Received output for Neuron 105 and image 2: 0.0
# 🔍 Received output for Neuron 108 and image 2: 0.0
# 🔍 Received output for Neuron 111 and image 2: 4.590815113286977
# 🔍 Received output for Neuron 112 and image 2: 0.0
# 🔍 Received output for Neuron 107 and image 2: 0.0
# 🔍 Received output for Neuron 106 and image 2: 1.6400491641384263
# 🔍 Received output for Neuron 110 and image 2: 0.6165651760542142
# ✅ Activated Neuron 116 in layer_0 for image 2
# ✅ Activated Neuron 118 in layer_0 for image 2
# ✅ Activated Neuron 119 in layer_0 for image 2
# ✅ Activated Neuron 120 in layer_0 for image 2
# ✅ Activated Neuron 114 in layer_0 for image 2
# ✅ Activated Neuron 115 in layer_0 for image 2
# ✅ Activated Neuron 117 in layer_0 for image 2
# ✅ Activated Neuron 113 in layer_0 for image 2
# 🔍 Received output for Neuron 119 and image 2: 0.0
# 🔍 Received output for Neuron 118 and image 2: 0.0
# 🔍 Received output for Neuron 117 and image 2: 4.067854293719213
# 🔍 Received output for Neuron 114 and image 2: 9.095843829423664
# 🔍 Received output for Neuron 116 and image 2: 3.501806495508082
# 🔍 Received output for Neuron 113 and image 2: 0.0
# 🔍 Received output for Neuron 120 and image 2: 3.9255170098256125
# 🔍 Received output for Neuron 115 and image 2: 0.0
# ✅ Activated Neuron 121 in layer_0 for image 2
# ✅ Activated Neuron 122 in layer_0 for image 2
# ✅ Activated Neuron 123 in layer_0 for image 2
# ✅ Activated Neuron 124 in layer_0 for image 2
# ✅ Activated Neuron 125 in layer_0 for image 2
# ✅ Activated Neuron 126 in layer_0 for image 2
# ✅ Activated Neuron 127 in layer_0 for image 2
# ✅ Activated Neuron 0 in layer_0 for image 3
# 🔍 Received output for Neuron 0 and image 3: 0.0
# 🔍 Received output for Neuron 124 and image 2: 0.0
# 🔍 Received output for Neuron 127 and image 2: 0.0
# 🔍 Received output for Neuron 126 and image 2: 0.0
# 🔍 Received output for Neuron 122 and image 2: 0.0
# 🔍 Received output for Neuron 121 and image 2: 0.0
# 🔍 Received output for Neuron 125 and image 2: 0.0
# 🔍 Received output for Neuron 123 and image 2: 0.0
# 🟢 Aggregating outputs for image 2 on layer layer_0
# 🚀 Activating next layer: layer_1 for image 2
# ✅ Activated Neuron 1 in layer_0 for image 3
# ✅ Activated Neuron 8 in layer_0 for image 3
# ✅ Activated Neuron 3 in layer_0 for image 3
# ✅ Activated Neuron 4 in layer_0 for image 3
# ✅ Activated Neuron 5 in layer_0 for image 3
# ✅ Activated Neuron 6 in layer_0 for image 3
# ✅ Activated Neuron 7 in layer_0 for image 3
# ✅ Activated Neuron 2 in layer_0 for image 3
# 🔍 Received output for Neuron 1 and image 3: 0.0
# ✅ Activated Neuron 0 in layer_1 for image 2
# ✅ Activated Neuron 4 in layer_1 for image 2
# ✅ Activated Neuron 1 in layer_1 for image 2
# ✅ Activated Neuron 5 in layer_1 for image 2
# ✅ Activated Neuron 2 in layer_1 for image 2
# ✅ Activated Neuron 6 in layer_1 for image 2
# ✅ Activated Neuron 7 in layer_1 for image 2
# ✅ Activated Neuron 3 in layer_1 for image 2
# 🔍 Received output for Neuron 2 and image 3: 2.7594002163159255🔍 Received output for Neuron 6 and image 2: -2.7462809191666566
#
# 🔍 Received output for Neuron 5 and image 3: 0.0
# 🔍 Received output for Neuron 7 and image 3: 0.0
# 🔍 Received output for Neuron 7 and image 2: -0.0015783463739884596
# 🔍 Received output for Neuron 4 and image 3: 0.0
# 🔍 Received output for Neuron 8 and image 3: 0.0
# 🔍 Received output for Neuron 3 and image 3: 0.0
# 🔍 Received output for Neuron 3 and image 2: -4.6039716658664895
# 🔍 Received output for Neuron 2 and image 2: -1.8329778696321806
# 🔍 Received output for Neuron 4 and image 2: -3.1335432391886666
# ✅ Activated Neuron 11 in layer_0 for image 3
# ✅ Activated Neuron 13 in layer_0 for image 3
# ✅ Activated Neuron 12 in layer_0 for image 3
# ✅ Activated Neuron 14 in layer_0 for image 3
# ✅ Activated Neuron 15 in layer_0 for image 3
# ✅ Activated Neuron 16 in layer_0 for image 3
# ✅ Activated Neuron 10 in layer_0 for image 3
# 🔍 Received output for Neuron 5 and image 2: -4.015411606677464
# ✅ Activated Neuron 9 in layer_0 for image 3
# 🔍 Received output for Neuron 6 and image 3: 8.269017094215393
# ✅ Activated Neuron 8 in layer_1 for image 2
# ✅ Activated Neuron 9 in layer_1 for image 2
# 🔍 Received output for Neuron 0 and image 2: -7.946612480963191
# 🔍 Received output for Neuron 1 and image 2: 3.8651437957351784
# 🔍 Received output for Neuron 12 and image 3: 9.307276194545379
# 🔍 Received output for Neuron 14 and image 3: 7.490746095700806
# 🔍 Received output for Neuron 13 and image 3: 0.0
# 🔍 Received output for Neuron 8 and image 2: -0.2995561323425415
# 🔍 Received output for Neuron 15 and image 3: 0.0
# 🔍 Received output for Neuron 11 and image 3: 0.0
# 🔍 Received output for Neuron 10 and image 3: 0.0
# 🔍 Received output for Neuron 20 and image 3: 0.0
# 🔍 Received output for Neuron 19 and image 3: 0.0
# 🔍 Received output for Neuron 9 and image 3: 0.0
# 🔍 Received output for Neuron 18 and image 3: 1.0014264267826718
# 🔍 Received output for Neuron 23 and image 3: 0.0
# 🔍 Received output for Neuron 9 and image 2: -6.002163032324886
# 🟢 Aggregating outputs for image 2 on layer layer_1
# 🔍 Received output for Neuron 22 and image 3: 9.975624297244192
# 🔍 Received output for Neuron 21 and image 3: 0.0
# 🔍 Received output for Neuron 17 and image 3: 0.0
# 🔍 Received output for Neuron 16 and image 3: 0.0
# 🎯 Final Prediction for image 2: 1
# ✅ Activated Neuron 18 in layer_0 for image 3
# ✅ Activated Neuron 19 in layer_0 for image 3
# ✅ Activated Neuron 21 in layer_0 for image 3
# ✅ Activated Neuron 22 in layer_0 for image 3
# ✅ Activated Neuron 23 in layer_0 for image 3
# ✅ Activated Neuron 24 in layer_0 for image 3
# ✅ Activated Neuron 20 in layer_0 for image 3
# ✅ Activated Neuron 17 in layer_0 for image 3
# 🔍 Received output for Neuron 24 and image 3: 0.0
# ✅ Activated Neuron 25 in layer_0 for image 3
# ✅ Activated Neuron 26 in layer_0 for image 3
# ✅ Activated Neuron 27 in layer_0 for image 3
# ✅ Activated Neuron 28 in layer_0 for image 3
# ✅ Activated Neuron 29 in layer_0 for image 3
# ✅ Activated Neuron 30 in layer_0 for image 3
# ✅ Activated Neuron 31 in layer_0 for image 3
# ✅ Activated Neuron 32 in layer_0 for image 3
# 🔍 Received output for Neuron 30 and image 3: 2.7270604684261763
# 🔍 Received output for Neuron 29 and image 3: 0.0
# 🔍 Received output for Neuron 28 and image 3: 0.0
# 🔍 Received output for Neuron 27 and image 3: 0.0
# 🔍 Received output for Neuron 32 and image 3: 10.019114380022366
# 🔍 Received output for Neuron 25 and image 3: 0.0
# ✅ Activated Neuron 33 in layer_0 for image 3
# ✅ Activated Neuron 35 in layer_0 for image 3
# ✅ Activated Neuron 36 in layer_0 for image 3
# ✅ Activated Neuron 38 in layer_0 for image 3
# ✅ Activated Neuron 37 in layer_0 for image 3
# ✅ Activated Neuron 39 in layer_0 for image 3
# ✅ Activated Neuron 40 in layer_0 for image 3
# ✅ Activated Neuron 34 in layer_0 for image 3
# 🔍 Received output for Neuron 31 and image 3: 0.0
# 🔍 Received output for Neuron 26 and image 3: 0.0
# 🔍 Received output for Neuron 37 and image 3: 1.1179554817086654
# 🔍 Received output for Neuron 38 and image 3: 0.0
# 🔍 Received output for Neuron 40 and image 3: 0.0
# 🔍 Received output for Neuron 34 and image 3: 0.0
# 🔍 Received output for Neuron 39 and image 3: 7.59207121416132
# 🔍 Received output for Neuron 36 and image 3: 0.0
# 🔍 Received output for Neuron 33 and image 3: 0.0
# 🔍 Received output for Neuron 35 and image 3: 0.0
# ✅ Activated Neuron 43 in layer_0 for image 3
# ✅ Activated Neuron 45 in layer_0 for image 3
# ✅ Activated Neuron 46 in layer_0 for image 3
# ✅ Activated Neuron 47 in layer_0 for image 3
# ✅ Activated Neuron 48 in layer_0 for image 3
# ✅ Activated Neuron 41 in layer_0 for image 3
# ✅ Activated Neuron 42 in layer_0 for image 3
# ✅ Activated Neuron 44 in layer_0 for image 3
# 🔍 Received output for Neuron 46 and image 3: 0.5575656237474135
# 🔍 Received output for Neuron 43 and image 3: 0.0
# 🔍 Received output for Neuron 47 and image 3: 0.0
# 🔍 Received output for Neuron 41 and image 3: 14.182674687243011
# 🔍 Received output for Neuron 48 and image 3: 0.0
# 🔍 Received output for Neuron 44 and image 3: 0.0
# 🔍 Received output for Neuron 42 and image 3: 0.0
# 🔍 Received output for Neuron 45 and image 3: 0.0
# ✅ Activated Neuron 51 in layer_0 for image 3
# ✅ Activated Neuron 53 in layer_0 for image 3
# ✅ Activated Neuron 54 in layer_0 for image 3
# ✅ Activated Neuron 55 in layer_0 for image 3
# ✅ Activated Neuron 56 in layer_0 for image 3
# ✅ Activated Neuron 50 in layer_0 for image 3
# ✅ Activated Neuron 52 in layer_0 for image 3
# ✅ Activated Neuron 49 in layer_0 for image 3
# 🔍 Received output for Neuron 49 and image 3: 0.0
# 🔍 Received output for Neuron 56 and image 3: 0.0
# 🔍 Received output for Neuron 54 and image 3: 2.15244281251792
# 🔍 Received output for Neuron 52 and image 3: 0.0
# ...
# 🔍 Received output for Neuron 70 and image 9: 0.0
# ✅ Activated Neuron 74 in layer_0 for image 9
# ✅ Activated Neuron 73 in layer_0 for image 9
# ✅ Activated Neuron 76 in layer_0 for image 9
# ✅ Activated Neuron 77 in layer_0 for image 9
# ✅ Activated Neuron 78 in layer_0 for image 9
# ✅ Activated Neuron 79 in layer_0 for image 9
# ✅ Activated Neuron 75 in layer_0 for image 9
# ✅ Activated Neuron 72 in layer_0 for image 9
# 🔍 Received output for Neuron 75 and image 9: 0.0
# 🔍 Received output for Neuron 76 and image 9: 0.0
# 🔍 Received output for Neuron 78 and image 9: 9.7716641361936
# 🔍 Received output for Neuron 79 and image 9: 2.6228173777494836
# 🔍 Received output for Neuron 73 and image 9: 0.0
# 🔍 Received output for Neuron 77 and image 9: 3.6856129852599975
# 🔍 Received output for Neuron 72 and image 9: 0.0
# 🔍 Received output for Neuron 74 and image 9: 0.0
# ✅ Activated Neuron 81 in layer_0 for image 9
# ✅ Activated Neuron 83 in layer_0 for image 9
# ✅ Activated Neuron 85 in layer_0 for image 9
# ✅ Activated Neuron 84 in layer_0 for image 9
# ✅ Activated Neuron 86 in layer_0 for image 9
# ✅ Activated Neuron 87 in layer_0 for image 9
# ✅ Activated Neuron 80 in layer_0 for image 9
# ✅ Activated Neuron 82 in layer_0 for image 9
# 🔍 Received output for Neuron 87 and image 9: 1.9435537017873037
# 🔍 Received output for Neuron 84 and image 9: 0.0
# 🔍 Received output for Neuron 85 and image 9: 0.0
# 🔍 Received output for Neuron 80 and image 9: 0.0
# 🔍 Received output for Neuron 86 and image 9: 0.0
# 🔍 Received output for Neuron 81 and image 9: 5.508156733111244
# 🔍 Received output for Neuron 83 and image 9: 6.386588172843824
# 🔍 Received output for Neuron 82 and image 9: 0.0
# ✅ Activated Neuron 88 in layer_0 for image 9
# ✅ Activated Neuron 89 in layer_0 for image 9
# ✅ Activated Neuron 91 in layer_0 for image 9
# ✅ Activated Neuron 92 in layer_0 for image 9
# ✅ Activated Neuron 93 in layer_0 for image 9
# ✅ Activated Neuron 94 in layer_0 for image 9
# ✅ Activated Neuron 95 in layer_0 for image 9
# ✅ Activated Neuron 90 in layer_0 for image 9
# 🔍 Received output for Neuron 93 and image 9: 0.0
# 🔍 Received output for Neuron 94 and image 9: 1.900232603810472
# 🔍 Received output for Neuron 91 and image 9: 0.0
# 🔍 Received output for Neuron 90 and image 9: 5.110902492403158
# 🔍 Received output for Neuron 88 and image 9: 0.0
# 🔍 Received output for Neuron 92 and image 9: 0.0
# 🔍 Received output for Neuron 89 and image 9: 0.0
# 🔍 Received output for Neuron 95 and image 9: 0.0
# ✅ Activated Neuron 97 in layer_0 for image 9
# ✅ Activated Neuron 99 in layer_0 for image 9
# ✅ Activated Neuron 100 in layer_0 for image 9
# ✅ Activated Neuron 101 in layer_0 for image 9
# ✅ Activated Neuron 102 in layer_0 for image 9
# ✅ Activated Neuron 103 in layer_0 for image 9
# ✅ Activated Neuron 96 in layer_0 for image 9
# ✅ Activated Neuron 98 in layer_0 for image 9
# 🔍 Received output for Neuron 98 and image 9: 0.0
# 🔍 Received output for Neuron 101 and image 9: 8.091172373328
# 🔍 Received output for Neuron 100 and image 9: 0.0
# 🔍 Received output for Neuron 99 and image 9: 0.0
# 🔍 Received output for Neuron 102 and image 9: 0.0
# 🔍 Received output for Neuron 97 and image 9: 0.0
# 🔍 Received output for Neuron 96 and image 9: 0.0
# 🔍 Received output for Neuron 103 and image 9: 0.0
# ✅ Activated Neuron 107 in layer_0 for image 9
# ✅ Activated Neuron 109 in layer_0 for image 9
# ✅ Activated Neuron 104 in layer_0 for image 9
# ✅ Activated Neuron 110 in layer_0 for image 9
# ✅ Activated Neuron 105 in layer_0 for image 9
# ✅ Activated Neuron 111 in layer_0 for image 9
# ✅ Activated Neuron 106 in layer_0 for image 9
# ✅ Activated Neuron 108 in layer_0 for image 9
# 🔍 Received output for Neuron 107 and image 9: 0.0
# 🔍 Received output for Neuron 109 and image 9: 0.0
# 🔍 Received output for Neuron 108 and image 9: 0.0
# 🔍 Received output for Neuron 111 and image 9: 4.372145894652366
# ✅ Activated Neuron 112 in layer_0 for image 9
# ✅ Activated Neuron 116 in layer_0 for image 9
# ✅ Activated Neuron 117 in layer_0 for image 9
# ✅ Activated Neuron 118 in layer_0 for image 9
# ✅ Activated Neuron 119 in layer_0 for image 9
# ✅ Activated Neuron 113 in layer_0 for image 9
# ✅ Activated Neuron 114 in layer_0 for image 9
# ✅ Activated Neuron 115 in layer_0 for image 9
# 🔍 Received output for Neuron 110 and image 9: 0.0
# 🔍 Received output for Neuron 104 and image 9: 7.169111388260195
# 🔍 Received output for Neuron 105 and image 9: 0.0
# 🔍 Received output for Neuron 106 and image 9: 1.4755923678346812
# 🔍 Received output for Neuron 115 and image 9: 0.0
# 🔍 Received output for Neuron 112 and image 9: 0.0
# 🔍 Received output for Neuron 114 and image 9: 2.639702687172382
# 🔍 Received output for Neuron 119 and image 9: 0.4969649083294101
# 🔍 Received output for Neuron 117 and image 9: 3.269977778913032
# 🔍 Received output for Neuron 118 and image 9: 0.0
# 🔍 Received output for Neuron 116 and image 9: 0.0
# 🔍 Received output for Neuron 113 and image 9: 0.0
# ✅ Activated Neuron 123 in layer_0 for image 9
# ✅ Activated Neuron 122 in layer_0 for image 9
# ✅ Activated Neuron 124 in layer_0 for image 9
# ✅ Activated Neuron 125 in layer_0 for image 9
# ✅ Activated Neuron 126 in layer_0 for image 9
# ✅ Activated Neuron 127 in layer_0 for image 9
# ✅ Activated Neuron 120 in layer_0 for image 9
# ✅ Activated Neuron 121 in layer_0 for image 9
# 🔍 Received output for Neuron 121 and image 9: 0.0
# 🔍 Received output for Neuron 123 and image 9: 0.0
# 🔍 Received output for Neuron 125 and image 9: 0.0
# 🔍 Received output for Neuron 124 and image 9: 0.0
# 🔍 Received output for Neuron 127 and image 9: 0.0
# 🔍 Received output for Neuron 122 and image 9: 0.0
# 🔍 Received output for Neuron 126 and image 9: 0.0
# 🔍 Received output for Neuron 120 and image 9: 0.0
# 🟢 Aggregating outputs for image 9 on layer layer_0
# 🚀 Activating next layer: layer_1 for image 9
# ✅ Activated Neuron 0 in layer_1 for image 9
# ✅ Activated Neuron 1 in layer_1 for image 9
# ✅ Activated Neuron 3 in layer_1 for image 9
# ✅ Activated Neuron 4 in layer_1 for image 9
# ✅ Activated Neuron 5 in layer_1 for image 9
# ✅ Activated Neuron 2 in layer_1 for image 9
# 🔍 Received output for Neuron 1 and image 9: -16.788759595942942
# ✅ Activated Neuron 6 in layer_1 for image 9
# ✅ Activated Neuron 8 in layer_1 for image 9
# ✅ Activated Neuron 9 in layer_1 for image 9
# ✅ Activated Neuron 7 in layer_1 for image 9
# 🔍 Received output for Neuron 2 and image 9: -9.390017834496225
# 🔍 Received output for Neuron 4 and image 9: 0.906443257234733
# 🔍 Received output for Neuron 5 and image 9: -6.124749915604316
# 🔍 Received output for Neuron 0 and image 9: -11.935084164856937
# 🔍 Received output for Neuron 6 and image 9: -15.212989041793895
# 🔍 Received output for Neuron 3 and image 9: -5.381783376115491
# 🔍 Received output for Neuron 7 and image 9: 2.4675733487772664
# 🔍 Received output for Neuron 8 and image 9: 2.29320358402897
# 🔍 Received output for Neuron 9 and image 9: 7.06329725320386
# 🟢 Aggregating outputs for image 9 on layer layer_1
# 🎯 Final Prediction for image 9: 9
# Exception in thread Thread-260:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/tmp/ipykernel_18/2001243465.py", line 174, in run
# AttributeError: 'Layer' object has no attribute 'neuron_id'
# No messages for 10 seconds in Neuron 1; stopping thread.
# No messages for 10 seconds in Neuron 3; stopping thread.
# No messages for 10 seconds in Neuron 7; stopping thread.
# No messages for 10 seconds in Neuron 2; stopping thread.
# No messages for 10 seconds in Neuron 0; stopping thread.
# No messages for 10 seconds in Neuron 5; stopping thread.
# No messages for 10 seconds in Neuron 4; stopping thread.
# No messages for 10 seconds in Neuron 6; stopping thread.
# No messages for 10 seconds in Neuron 12; stopping thread.
# No messages for 10 seconds in Neuron 11; stopping thread.
# No messages for 10 seconds in Neuron 9; stopping thread.
# No messages for 10 seconds in Neuron 13; stopping thread.
# No messages for 10 seconds in Neuron 15; stopping thread.
# No messages for 10 seconds in Neuron 14; stopping thread.
# No messages for 10 seconds in Neuron 8; stopping thread.
# No messages for 10 seconds in Neuron 10; stopping thread.
# No messages for 10 seconds in Neuron 20; stopping thread.
# No messages for 10 seconds in Neuron 25; stopping thread.
# No messages for 10 seconds in Neuron 24; stopping thread.
# No messages for 10 seconds in Neuron 19; stopping thread.
# No messages for 10 seconds in Neuron 21; stopping thread.
# No messages for 10 seconds in Neuron 26; stopping thread.
# No messages for 10 seconds in Neuron 30; stopping thread.
# No messages for 10 seconds in Neuron 22; stopping thread.
# No messages for 10 seconds in Neuron 23; stopping thread.
# No messages for 10 seconds in Neuron 17; stopping thread.
# No messages for 10 seconds in Neuron 29; stopping thread.
# No messages for 10 seconds in Neuron 28; stopping thread.
# No messages for 10 seconds in Neuron 18; stopping thread.
# No messages for 10 seconds in Neuron 27; stopping thread.
# No messages for 10 seconds in Neuron 31; stopping thread.
# No messages for 10 seconds in Neuron 16; stopping thread.
# No messages for 10 seconds in Neuron 34; stopping thread.
# No messages for 10 seconds in Neuron 36; stopping thread.
# No messages for 10 seconds in Neuron 39; stopping thread.
# No messages for 10 seconds in Neuron 33; stopping thread.
# No messages for 10 seconds in Neuron 37; stopping thread.
# No messages for 10 seconds in Neuron 35; stopping thread.
# No messages for 10 seconds in Neuron 38; stopping thread.
# No messages for 10 seconds in Neuron 32; stopping thread.
# No messages for 10 seconds in Neuron 45; stopping thread.
# No messages for 10 seconds in Neuron 46; stopping thread.
# No messages for 10 seconds in Neuron 47; stopping thread.
# No messages for 10 seconds in Neuron 41; stopping thread.
# No messages for 10 seconds in Neuron 43; stopping thread.
# No messages for 10 seconds in Neuron 40; stopping thread.
# No messages for 10 seconds in Neuron 44; stopping thread.
# No messages for 10 seconds in Neuron 42; stopping thread.
# No messages for 10 seconds in Neuron 53; stopping thread.
# No messages for 10 seconds in Neuron 49; stopping thread.
# No messages for 10 seconds in Neuron 55; stopping thread.
# No messages for 10 seconds in Neuron 50; stopping thread.
# No messages for 10 seconds in Neuron 51; stopping thread.
# No messages for 10 seconds in Neuron 52; stopping thread.
# No messages for 10 seconds in Neuron 48; stopping thread.
# No messages for 10 seconds in Neuron 54; stopping thread.
# No messages for 10 seconds in Neuron 60; stopping thread.
# No messages for 10 seconds in Neuron 57; stopping thread.
# No messages for 10 seconds in Neuron 58; stopping thread.
# No messages for 10 seconds in Neuron 61; stopping thread.
# No messages for 10 seconds in Neuron 62; stopping thread.
# No messages for 10 seconds in Neuron 56; stopping thread.
# No messages for 10 seconds in Neuron 59; stopping thread.
# No messages for 10 seconds in Neuron 63; stopping thread.
# No messages for 10 seconds in Neuron 65; stopping thread.
# No messages for 10 seconds in Neuron 69; stopping thread.
# No messages for 10 seconds in Neuron 66; stopping thread.
# No messages for 10 seconds in Neuron 68; stopping thread.
# No messages for 10 seconds in Neuron 71; stopping thread.
# No messages for 10 seconds in Neuron 64; stopping thread.
# No messages for 10 seconds in Neuron 67; stopping thread.
# No messages for 10 seconds in Neuron 70; stopping thread.
# No messages for 10 seconds in Neuron 76; stopping thread.
# No messages for 10 seconds in Neuron 77; stopping thread.
# No messages for 10 seconds in Neuron 79; stopping thread.
# No messages for 10 seconds in Neuron 75; stopping thread.
# No messages for 10 seconds in Neuron 78; stopping thread.
# No messages for 10 seconds in Neuron 73; stopping thread.
# No messages for 10 seconds in Neuron 72; stopping thread.
# No messages for 10 seconds in Neuron 74; stopping thread.
# No messages for 10 seconds in Neuron 86; stopping thread.
# No messages for 10 seconds in Neuron 84; stopping thread.
# No messages for 10 seconds in Neuron 80; stopping thread.
# No messages for 10 seconds in Neuron 87; stopping thread.
# No messages for 10 seconds in Neuron 85; stopping thread.
# No messages for 10 seconds in Neuron 82; stopping thread.
# No messages for 10 seconds in Neuron 83; stopping thread.
# No messages for 10 seconds in Neuron 81; stopping thread.
# No messages for 10 seconds in Neuron 94; stopping thread.
# No messages for 10 seconds in Neuron 91; stopping thread.
# No messages for 10 seconds in Neuron 90; stopping thread.
# No messages for 10 seconds in Neuron 88; stopping thread.
# No messages for 10 seconds in Neuron 89; stopping thread.
# No messages for 10 seconds in Neuron 93; stopping thread.
# No messages for 10 seconds in Neuron 92; stopping thread.
# No messages for 10 seconds in Neuron 95; stopping thread.
# No messages for 10 seconds in Neuron 98; stopping thread.
# No messages for 10 seconds in Neuron 101; stopping thread.
# No messages for 10 seconds in Neuron 102; stopping thread.
# No messages for 10 seconds in Neuron 96; stopping thread.
# No messages for 10 seconds in Neuron 100; stopping thread.
# No messages for 10 seconds in Neuron 99; stopping thread.
# No messages for 10 seconds in Neuron 103; stopping thread.
# No messages for 10 seconds in Neuron 97; stopping thread.
# No messages for 10 seconds in Neuron 108; stopping thread.
# No messages for 10 seconds in Neuron 110; stopping thread.
# No messages for 10 seconds in Neuron 109; stopping thread.
# No messages for 10 seconds in Neuron 107; stopping thread.
# No messages for 10 seconds in Neuron 104; stopping thread.
# No messages for 10 seconds in Neuron 111; stopping thread.
# No messages for 10 seconds in Neuron 106; stopping thread.
# No messages for 10 seconds in Neuron 105; stopping thread.
# No messages for 10 seconds in Neuron 115; stopping thread.
# No messages for 10 seconds in Neuron 112; stopping thread.
# No messages for 10 seconds in Neuron 119; stopping thread.
# No messages for 10 seconds in Neuron 114; stopping thread.
# No messages for 10 seconds in Neuron 116; stopping thread.
# No messages for 10 seconds in Neuron 117; stopping thread.
# No messages for 10 seconds in Neuron 118; stopping thread.
# No messages for 10 seconds in Neuron 113; stopping thread.
# Exception in thread Thread-262:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/tmp/ipykernel_18/2001243465.py", line 117, in run
# AttributeError: 'LayerCoordinator' object has no attribute 'neuron_id'
# Exception in thread Thread-284:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/tmp/ipykernel_18/2001243465.py", line 174, in run
# AttributeError: 'Layer' object has no attribute 'neuron_id'
# Exception in thread Thread-286:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/tmp/ipykernel_18/2001243465.py", line 117, in run
# AttributeError: 'LayerCoordinator' object has no attribute 'neuron_id'
# No messages for 10 seconds in Neuron 123; stopping thread.
# No messages for 10 seconds in Neuron 122; stopping thread.
# No messages for 10 seconds in Neuron 121; stopping thread.
# No messages for 10 seconds in Neuron 124; stopping thread.
# No messages for 10 seconds in Neuron 125; stopping thread.
# No messages for 10 seconds in Neuron 127; stopping thread.
# No messages for 10 seconds in Neuron 126; stopping thread.
# No messages for 10 seconds in Neuron 120; stopping thread.
# No messages for 10 seconds in Neuron 1; stopping thread.
# No messages for 10 seconds in Neuron 4; stopping thread.
# No messages for 10 seconds in Neuron 5; stopping thread.
# No messages for 10 seconds in Neuron 0; stopping thread.
# No messages for 10 seconds in Neuron 2; stopping thread.
# No messages for 10 seconds in Neuron 6; stopping thread.
# No messages for 10 seconds in Neuron 3; stopping thread.
# No messages for 10 seconds in Neuron 7; stopping thread.
# No messages for 10 seconds in Neuron 9; stopping thread.
# No messages for 10 seconds in Neuron 8; stopping thread.

# %%
from pcomp_utils.redis_utils import RedisHandler
import pandas as pd

def calculate_accuracy(file_path, limit=10):
    redis_handler = RedisHandler('host.docker.internal', 6379, 0)
    df = pd.read_csv(file_path).head(limit)
    predictions = redis_handler.hgetall('predictions')

    correct = 0
    total = 0

    for idx, row in df.iterrows():
        label = int(row['label'])
        prediction = predictions.get(str(idx).encode())  # Decode Redis key lookup

        if prediction is not None:
            prediction = int(prediction.decode())  # Decode the Redis stored value
            print(f"✅ Prediction for Image {idx}: {prediction}, Actual Label: {label}")

            if prediction == label:
                correct += 1
            total += 1
        else:
            print(f"⚠️ No prediction found for Image ID: {idx}")

    if total == 0:
        print("⚠️ No valid predictions to calculate accuracy.")
        return

    accuracy = correct / total
    print(f"🎯 Test Accuracy (First {limit} Images): {accuracy * 100:.2f}%")


calculate_accuracy('data/mnist.csv', 10)
# Out:
# ✅ Prediction for Image 0: 7, Actual Label: 7
# ✅ Prediction for Image 1: 2, Actual Label: 2
# ✅ Prediction for Image 2: 1, Actual Label: 1
# ✅ Prediction for Image 3: 0, Actual Label: 0
# ✅ Prediction for Image 4: 4, Actual Label: 4
# ✅ Prediction for Image 5: 1, Actual Label: 1
# ✅ Prediction for Image 6: 4, Actual Label: 4
# ✅ Prediction for Image 7: 9, Actual Label: 9
# ✅ Prediction for Image 8: 6, Actual Label: 5
# ✅ Prediction for Image 9: 9, Actual Label: 9
# 🎯 Test Accuracy (First 10 Images): 90.00%
