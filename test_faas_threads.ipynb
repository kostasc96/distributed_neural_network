# %%
import json
import numpy as np
import threading
import time
import pandas as pd
from pcomp_utils.kafka_producer_utils import KafkaProducerHandler
from pcomp_utils.kafka_consumer_utils import KafkaConsumerHandler
from pcomp_utils.activation_functions import ACTIVATIONS, relu, softmax
from pcomp_utils.redis_utils import RedisHandler

# Kafka Configuration
KAFKA_BROKER = 'kafka:9092'

class Neuron(threading.Thread):
    def __init__(self, layer_id, neuron_id, weights, bias, activation):
        threading.Thread.__init__(self)
        self.layer_id = layer_id
        self.layer_id_num = int(self.layer_id.replace("layer_", ""))
        self.neuron_id = neuron_id
        self.weights = np.array(weights)
        self.bias = np.array(bias)
        self.activation_func = ACTIVATIONS.get(activation, relu)
        self.consumer = KafkaConsumerHandler(f'layer-{self.layer_id_num}', KAFKA_BROKER, partition=self.neuron_id)
        self.producer = KafkaProducerHandler(KAFKA_BROKER)
        self.redis_handler = RedisHandler('host.docker.internal', 6379, 0)

    def fetch_input(self, image_id):
        key = "initial_data" if self.layer_id == 'layer_0' else f"layer_{int(self.layer_id[-1]) - 1}:{image_id}"
        while True:
            data = self.redis_handler.get(key)
            if data is not None:
                return data
            print(f"⏳ Neuron waiting for input data for key: {key}")
            time.sleep(0.5)
            
    def run(self):
        while True:
            for message in self.consumer.consume():
                if message.value.get('layer') == self.layer_id:
                    image_id = message.value.get('image_id')
                    redis_key = f"{self.layer_id}:neuron_{self.neuron_id}:{image_id}"
    
                    # if self.redis_handler.get(redis_key) is not None:
                    #     continue
    
                    input_data = self.fetch_input(image_id)
                    if self.layer_id == "layer_1":
                        print(f"Weights: {self.weights}")
                        print(f"previous layer data {input_data}")
                    if input_data is not None:
                        output = self.process_data(input_data)
                        #redis_key = f"{self.layer_id}:neuron_{self.neuron_id}:{image_id}"
                        self.redis_handler.set(redis_key, output)
                        #self.redis_handler.set(processed_key, True)
    
                        print(f"✅ Neuron {self.neuron_id} in {self.layer_id} processed and stored data for image {image_id}")
                        self.producer.send(f'layer-{self.layer_id_num}-complete', {'neuron_id': self.neuron_id, 'image_id': image_id}, self.layer_id_num)
                break
            time.sleep(1)

    def process_data(self, inputs):
        return self.activation_func(np.dot(inputs, self.weights) + self.bias)

class LayerCoordinator(threading.Thread):
    def __init__(self, layer_id, neuron_count, is_final_layer=False):
        threading.Thread.__init__(self)
        self.layer_id = layer_id
        self.layer_id_num = int(self.layer_id.replace("layer_", ""))
        self.neuron_count = neuron_count
        self.is_final_layer = is_final_layer
        self.completed_neurons = {}  # TODO: make a dictionary with image_id as the keys
        self.consumer = KafkaConsumerHandler(f'layer-{self.layer_id_num}-complete', KAFKA_BROKER, self.layer_id_num)
        self.producer = KafkaProducerHandler(KAFKA_BROKER)
        self.redis_handler = RedisHandler('host.docker.internal', 6379, 0)

    def run(self):
        while True:
            for message in self.consumer.consume():
                image_id = message.value.get('image_id')
                neuron_id = message.value.get('neuron_id')
                if image_id not in self.completed_neurons:
                    self.completed_neurons[image_id] = set()
                self.completed_neurons[image_id].add(neuron_id)
                print(f"✅ Coordinator for {self.layer_id} received completion from Neuron {neuron_id} for image {image_id}")

                if len(self.completed_neurons[image_id]) == self.neuron_count:
                    self.aggregate_neuron_outputs(image_id)
                    del self.completed_neurons[image_id]  # Clean up after processing
            time.sleep(1)

    def aggregate_neuron_outputs(self, image_id):
        # Initialize the aggregation with zeros to ensure the correct structure
        outputs = np.zeros(self.neuron_count, dtype=np.float32)
    
        for neuron_id in range(self.neuron_count):
            data = self.redis_handler.get(f"{self.layer_id}:neuron_{neuron_id}:{image_id}")
            if data is not None:
                outputs[neuron_id] = data  # Place the neuron's output in the correct position
    
        self.redis_handler.set(f"{self.layer_id}:{image_id}", outputs)
        print(f"📝 Aggregated data for {self.layer_id} and image {image_id} stored in Redis.")
    
        if self.is_final_layer:
            prediction = int(np.argmax(outputs))
            self.redis_handler.hset('predictions', image_id, prediction)
            print(f"🎯 Final Prediction for image {image_id}: {prediction}")
    
    def activate_next_layer(self, image_id):
        next_layer = f'layer_{self.layer_id_num + 1}'
        self.producer.send('activate-layer', {'layer': next_layer, 'image_id': image_id}, self.layer_id_num + 1)
        print(f"🚀 Activating next layer: {next_layer} for image {image_id}")
            

class Layer(threading.Thread):
    def __init__(self, layer_id, neuron_count):
        threading.Thread.__init__(self)
        self.layer_id = layer_id
        self.neuron_count = neuron_count
        self.producer = KafkaProducerHandler(KAFKA_BROKER)
        self.layer_id_num = int(self.layer_id.replace("layer_", ""))
        self.consumer = KafkaConsumerHandler('activate-layer', KAFKA_BROKER, self.layer_id_num)

    def run(self):
        while True:
            for message in self.consumer.consume():
                if message.value.get('layer') == self.layer_id:
                    image_id = message.value.get('image_id')
                    self.activate_neurons(image_id)
            time.sleep(1)

    def activate_neurons(self, image_id):
        for neuron_id in range(self.neuron_count):
            self.producer.send(f'layer-{self.layer_id_num}', {'layer': self.layer_id, 'image_id': image_id}, neuron_id)
            #print(f"✅ Activating Neuron {neuron_id} in {self.layer_id} for image {image_id}")

def store_initial_input_data(image_np):
    redis_handler = RedisHandler('host.docker.internal', 6379, 0)
    redis_handler.set("initial_data", image_np)
    print(f"📥 Initial input data stored in Redis.")

def activate_network(image_id):
    producer = KafkaProducerHandler(KAFKA_BROKER)
    producer.send('activate-layer', {'layer': 'layer_0', 'image_id': image_id}, 0)
    print(f"🚀 Initial activation sent to activate-layer for layer_0 and image {image_id}")
    producer.close()

# Load network and dataset
data = json.load(open("node_based_model.json"))
df = pd.read_csv('data/mnist.csv').head(2)

neurons = []
layers = []
coordinators = []

for layer_name, layer_info in data.items():
    neurons += [Neuron(layer_id=layer_name, neuron_id=i, weights=node['weights'], bias=node['biases'], activation=node['activation']) for i, node in enumerate(layer_info['nodes'])]
    layers.append(Layer(layer_id=layer_name, neuron_count=len(layer_info['nodes'])))
    coordinators.append(LayerCoordinator(layer_id=layer_name, neuron_count=len(layer_info['nodes']), is_final_layer=(layer_name == list(data.keys())[-1])))

# Start all threads
for thread in neurons + layers + coordinators:
    thread.start()

# %%
# Send images one by one with a 40-second delay
for idx, row in df.iterrows():
    image_np = row.iloc[:-1].values.astype(np.float32)
    store_initial_input_data(image_np)
    activate_network(idx)
    time.sleep(60)

# Wait for all threads to complete
for thread in neurons + layers + coordinators:
    thread.join()
# Out:
# 📥 Initial input data stored in Redis.
# 🚀 Initial activation sent to activate-layer for layer_0 and image 0
# ✅ Neuron 0 in layer_0 processed and stored data for image 0
# ✅ Neuron 1 in layer_0 processed and stored data for image 0
# ✅ Neuron 2 in layer_0 processed and stored data for image 0
# ✅ Neuron 3 in layer_0 processed and stored data for image 0
# ✅ Neuron 4 in layer_0 processed and stored data for image 0
# ✅ Neuron 6 in layer_0 processed and stored data for image 0
# ✅ Neuron 7 in layer_0 processed and stored data for image 0
# ✅ Neuron 5 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 4 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 5 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 7 for image 0
# ✅ Neuron 8 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 6 for image 0
# ✅ Neuron 9 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 8 for image 0
# ✅ Neuron 10 in layer_0 processed and stored data for image 0
# ✅ Neuron 11 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 9 for image 0
# ✅ Neuron 12 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 11 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 10 for image 0
# ✅ Neuron 13 in layer_0 processed and stored data for image 0
# ✅ Neuron 14 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 12 for image 0
# ✅ Neuron 15 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 13 for image 0
# ✅ Neuron 16 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 14 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 15 for image 0
# ✅ Neuron 17 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 16 for image 0
# ✅ Neuron 18 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 17 for image 0
# ✅ Neuron 19 in layer_0 processed and stored data for image 0
# ✅ Neuron 20 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 18 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 19 for image 0
# ✅ Neuron 21 in layer_0 processed and stored data for image 0
# ✅ Neuron 22 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 20 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 21 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 22 for image 0
# ✅ Neuron 23 in layer_0 processed and stored data for image 0
# ✅ Neuron 24 in layer_0 processed and stored data for image 0
# ✅ Neuron 25 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 23 for image 0
# ✅ Neuron 26 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 24 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 25 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 26 for image 0
# ✅ Neuron 27 in layer_0 processed and stored data for image 0
# ✅ Neuron 28 in layer_0 processed and stored data for image 0
# ✅ Neuron 29 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 27 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 28 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 29 for image 0
# ✅ Neuron 30 in layer_0 processed and stored data for image 0
# ✅ Neuron 31 in layer_0 processed and stored data for image 0
# ✅ Neuron 32 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 30 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 31 for image 0
# ✅ Neuron 33 in layer_0 processed and stored data for image 0
# ✅ Neuron 34 in layer_0 processed and stored data for image 0
# ✅ Neuron 35 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 32 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 33 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 35 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 34 for image 0
# ✅ Neuron 36 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 36 for image 0
# ✅ Neuron 37 in layer_0 processed and stored data for image 0
# ✅ Neuron 38 in layer_0 processed and stored data for image 0
# ✅ Neuron 39 in layer_0 processed and stored data for image 0
# ✅ Neuron 40 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 38 for image 0
# ✅ Neuron 41 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 37 for image 0
# ✅ Neuron 42 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 40 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 39 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 41 for image 0
# ✅ Neuron 43 in layer_0 processed and stored data for image 0
# ✅ Neuron 44 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 42 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 43 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 44 for image 0
# ✅ Neuron 45 in layer_0 processed and stored data for image 0
# ✅ Neuron 47 in layer_0 processed and stored data for image 0
# ✅ Neuron 46 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 45 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 47 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 46 for image 0
# ✅ Neuron 49 in layer_0 processed and stored data for image 0
# ✅ Neuron 48 in layer_0 processed and stored data for image 0
# ✅ Neuron 50 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 49 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 48 for image 0
# ✅ Neuron 51 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 50 for image 0
# ✅ Neuron 52 in layer_0 processed and stored data for image 0
# ✅ Neuron 54 in layer_0 processed and stored data for image 0
# ✅ Neuron 53 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 51 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 52 for image 0
# ✅ Neuron 55 in layer_0 processed and stored data for image 0
# ✅ Neuron 56 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 53 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 54 for image 0
# ✅ Neuron 57 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 55 for image 0
# ✅ Neuron 58 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 56 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 57 for image 0
# ✅ Neuron 59 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 58 for image 0
# ✅ Neuron 60 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 59 for image 0
# ✅ Neuron 61 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 60 for image 0
# ✅ Neuron 62 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 61 for image 0
# ✅ Neuron 63 in layer_0 processed and stored data for image 0
# ✅ Neuron 64 in layer_0 processed and stored data for image 0
# ✅ Neuron 65 in layer_0 processed and stored data for image 0
# ✅ Neuron 66 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 62 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 63 for image 0
# ✅ Neuron 67 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 64 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 65 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 66 for image 0
# ✅ Neuron 68 in layer_0 processed and stored data for image 0
# ✅ Neuron 69 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 67 for image 0
# ✅ Neuron 70 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 68 for image 0
# ✅ Neuron 71 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 69 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 70 for image 0
# ✅ Neuron 72 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 71 for image 0
# ✅ Neuron 73 in layer_0 processed and stored data for image 0
# ✅ Neuron 74 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 72 for image 0
# ✅ Neuron 75 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 73 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 74 for image 0
# ✅ Neuron 76 in layer_0 processed and stored data for image 0
# ✅ Neuron 77 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 75 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 76 for image 0
# ✅ Neuron 78 in layer_0 processed and stored data for image 0
# ✅ Neuron 79 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 77 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 78 for image 0
# ✅ Neuron 80 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 79 for image 0
# ✅ Neuron 81 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 80 for image 0
# ✅ Neuron 82 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 81 for image 0
# ✅ Neuron 84 in layer_0 processed and stored data for image 0
# ✅ Neuron 83 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 82 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 84 for image 0✅ Neuron 85 in layer_0 processed and stored data for image 0
#
# ✅ Coordinator for layer_0 received completion from Neuron 83 for image 0
# ✅ Neuron 86 in layer_0 processed and stored data for image 0
# ✅ Neuron 87 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 85 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 86 for image 0
# ✅ Neuron 88 in layer_0 processed and stored data for image 0
# ✅ Neuron 90 in layer_0 processed and stored data for image 0
# ✅ Neuron 89 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 87 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 88 for image 0
# ✅ Neuron 91 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 89 for image 0
# ✅ Neuron 92 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 90 for image 0
# ✅ Neuron 93 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 91 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 93 for image 0
# ✅ Neuron 94 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 92 for image 0
# ✅ Neuron 95 in layer_0 processed and stored data for image 0
# ✅ Neuron 96 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 94 for image 0
# ✅ Neuron 97 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 96 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 95 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 97 for image 0
# ✅ Neuron 98 in layer_0 processed and stored data for image 0
# ✅ Neuron 99 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 98 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 99 for image 0
# ✅ Neuron 100 in layer_0 processed and stored data for image 0
# ✅ Neuron 102 in layer_0 processed and stored data for image 0
# ✅ Neuron 101 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 100 for image 0
# ✅ Neuron 103 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 101 for image 0
# ✅ Neuron 104 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 102 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 103 for image 0✅ Neuron 105 in layer_0 processed and stored data for image 0
#
# ✅ Coordinator for layer_0 received completion from Neuron 104 for image 0
# ✅ Neuron 106 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 105 for image 0
# ✅ Neuron 107 in layer_0 processed and stored data for image 0
# ✅ Neuron 108 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 106 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 107 for image 0
# ✅ Neuron 109 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 108 for image 0
# ✅ Neuron 110 in layer_0 processed and stored data for image 0
# ✅ Neuron 111 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 109 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 110 for image 0
# ✅ Neuron 112 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 111 for image 0
# ✅ Neuron 114 in layer_0 processed and stored data for image 0
# ✅ Neuron 113 in layer_0 processed and stored data for image 0
# ✅ Neuron 115 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 112 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 113 for image 0
# ✅ Neuron 116 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 114 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 115 for image 0
# ✅ Neuron 117 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 116 for image 0
# ✅ Neuron 118 in layer_0 processed and stored data for image 0
# ✅ Neuron 119 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 117 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 118 for image 0
# ✅ Neuron 120 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 119 for image 0
# ✅ Neuron 123 in layer_0 processed and stored data for image 0
# ✅ Neuron 121 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 120 for image 0
# ✅ Neuron 122 in layer_0 processed and stored data for image 0
# ✅ Neuron 124 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 121 for image 0
# ✅ Neuron 125 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 123 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 125 for image 0
# ✅ Neuron 126 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 122 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 124 for image 0
# ✅ Neuron 127 in layer_0 processed and stored data for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 126 for image 0
# ✅ Coordinator for layer_0 received completion from Neuron 127 for image 0
# 📥 Initial input data stored in Redis.
# 🚀 Initial activation sent to activate-layer for layer_0 and image 1
# ✅ Neuron 0 in layer_0 processed and stored data for image 1
# ✅ Neuron 1 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 0 for image 1
# ✅ Neuron 2 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 1 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 2 for image 1
# ✅ Neuron 3 in layer_0 processed and stored data for image 1
# ✅ Neuron 4 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 3 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 4 for image 1
# ✅ Neuron 5 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 5 for image 1
# ✅ Neuron 6 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 6 for image 1
# ✅ Neuron 7 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 7 for image 1
# ✅ Neuron 8 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 8 for image 1
# ✅ Neuron 9 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 9 for image 1
# ✅ Neuron 10 in layer_0 processed and stored data for image 1
# ✅ Neuron 11 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 10 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 11 for image 1
# ✅ Neuron 12 in layer_0 processed and stored data for image 1
# ✅ Neuron 13 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 12 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 13 for image 1
# ✅ Neuron 14 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 14 for image 1
# ✅ Neuron 15 in layer_0 processed and stored data for image 1
# ✅ Neuron 16 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 15 for image 1
# ✅ Neuron 17 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 16 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 17 for image 1
# ✅ Neuron 18 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 18 for image 1
# ✅ Neuron 19 in layer_0 processed and stored data for image 1
# ✅ Neuron 20 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 20 for image 1
# ✅ Neuron 21 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 19 for image 1
# ✅ Neuron 22 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 21 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 22 for image 1
# ✅ Neuron 23 in layer_0 processed and stored data for image 1
# ✅ Neuron 24 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 23 for image 1
# ✅ Neuron 25 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 24 for image 1
# ✅ Neuron 26 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 25 for image 1
# ✅ Neuron 27 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 26 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 27 for image 1
# ✅ Neuron 28 in layer_0 processed and stored data for image 1
# ✅ Neuron 29 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 28 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 29 for image 1
# ✅ Neuron 30 in layer_0 processed and stored data for image 1
# ✅ Neuron 31 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 30 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 31 for image 1
# ✅ Neuron 32 in layer_0 processed and stored data for image 1
# ✅ Neuron 33 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 32 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 33 for image 1
# ✅ Neuron 34 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 34 for image 1
# ✅ Neuron 35 in layer_0 processed and stored data for image 1
# ✅ Neuron 36 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 35 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 36 for image 1
# ✅ Neuron 37 in layer_0 processed and stored data for image 1
# ✅ Neuron 38 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 37 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 38 for image 1
# ✅ Neuron 39 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 39 for image 1
# ✅ Neuron 40 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 40 for image 1
# ✅ Neuron 41 in layer_0 processed and stored data for image 1
# ✅ Neuron 42 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 41 for image 1
# ✅ Neuron 43 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 42 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 43 for image 1
# ✅ Neuron 44 in layer_0 processed and stored data for image 1
# ✅ Neuron 45 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 44 for image 1
# ✅ Neuron 46 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 45 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 46 for image 1
# ✅ Neuron 47 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 47 for image 1
# ✅ Neuron 48 in layer_0 processed and stored data for image 1
# ✅ Neuron 49 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 48 for image 1
# ✅ Neuron 50 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 49 for image 1
# ✅ Neuron 51 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 50 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 51 for image 1
# ✅ Neuron 52 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 52 for image 1
# ✅ Neuron 53 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 53 for image 1
# ✅ Neuron 54 in layer_0 processed and stored data for image 1
# ✅ Neuron 55 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 54 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 55 for image 1
# ✅ Neuron 56 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 56 for image 1
# ✅ Neuron 57 in layer_0 processed and stored data for image 1
# ✅ Neuron 58 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 57 for image 1
# ✅ Neuron 59 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 58 for image 1
# ✅ Neuron 60 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 59 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 60 for image 1
# ✅ Neuron 61 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 61 for image 1
# ✅ Neuron 62 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 62 for image 1
# ✅ Neuron 63 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 63 for image 1
# ✅ Neuron 64 in layer_0 processed and stored data for image 1
# ✅ Neuron 65 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 64 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 65 for image 1
# ✅ Neuron 66 in layer_0 processed and stored data for image 1
# ✅ Neuron 67 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 66 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 67 for image 1
# ✅ Neuron 68 in layer_0 processed and stored data for image 1
# ✅ Neuron 69 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 69 for image 1
# ✅ Neuron 70 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 68 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 70 for image 1
# ✅ Neuron 71 in layer_0 processed and stored data for image 1
# ✅ Neuron 72 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 71 for image 1
# ✅ Neuron 73 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 72 for image 1
# ✅ Neuron 74 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 73 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 74 for image 1
# ✅ Neuron 75 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 75 for image 1
# ✅ Neuron 76 in layer_0 processed and stored data for image 1
# ✅ Neuron 77 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 76 for image 1
# ✅ Neuron 78 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 77 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 78 for image 1
# ✅ Neuron 79 in layer_0 processed and stored data for image 1
# ✅ Neuron 80 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 79 for image 1
# ✅ Neuron 81 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 81 for image 1
# ✅ Neuron 82 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 80 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 82 for image 1
# ✅ Neuron 84 in layer_0 processed and stored data for image 1
# ✅ Neuron 83 in layer_0 processed and stored data for image 1
# ✅ Neuron 85 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 83 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 84 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 85 for image 1
# ✅ Neuron 86 in layer_0 processed and stored data for image 1
# ✅ Neuron 87 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 86 for image 1
# ✅ Neuron 88 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 87 for image 1
# ✅ Neuron 89 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 88 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 89 for image 1
# ✅ Neuron 90 in layer_0 processed and stored data for image 1
# ✅ Neuron 91 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 90 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 91 for image 1
# ✅ Neuron 92 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 92 for image 1
# ✅ Neuron 93 in layer_0 processed and stored data for image 1
# ✅ Neuron 95 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 93 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 95 for image 1
# ✅ Neuron 94 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 94 for image 1
# ✅ Neuron 96 in layer_0 processed and stored data for image 1
# ✅ Neuron 97 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 96 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 97 for image 1
# ✅ Neuron 98 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 98 for image 1
# ✅ Neuron 99 in layer_0 processed and stored data for image 1
# ✅ Neuron 100 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 99 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 100 for image 1
# ✅ Neuron 101 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 101 for image 1
# ✅ Neuron 102 in layer_0 processed and stored data for image 1
# ✅ Neuron 103 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 102 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 103 for image 1
# ✅ Neuron 104 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 104 for image 1
# ✅ Neuron 105 in layer_0 processed and stored data for image 1
# ✅ Neuron 106 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 105 for image 1
# ✅ Neuron 107 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 106 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 107 for image 1
# ✅ Neuron 108 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 108 for image 1
# ✅ Neuron 109 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 109 for image 1
# ✅ Neuron 110 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 110 for image 1
# ✅ Neuron 112 in layer_0 processed and stored data for image 1
# ✅ Neuron 111 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 112 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 111 for image 1
# ✅ Neuron 113 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 113 for image 1
# ✅ Neuron 114 in layer_0 processed and stored data for image 1
# ✅ Neuron 115 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 114 for image 1
# ✅ Neuron 116 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 115 for image 1
# ✅ Neuron 117 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 116 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 117 for image 1
# ✅ Neuron 118 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 118 for image 1
# ✅ Neuron 119 in layer_0 processed and stored data for image 1
# ✅ Neuron 120 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 119 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 120 for image 1
# ✅ Neuron 122 in layer_0 processed and stored data for image 1
# ✅ Neuron 121 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 121 for image 1
# ✅ Neuron 123 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 122 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 123 for image 1
# ✅ Neuron 124 in layer_0 processed and stored data for image 1
# ✅ Neuron 125 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 124 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 125 for image 1
# ✅ Neuron 126 in layer_0 processed and stored data for image 1
# ✅ Neuron 127 in layer_0 processed and stored data for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 126 for image 1
# ✅ Coordinator for layer_0 received completion from Neuron 127 for image 1
# /tmp/ipykernel_24/851748055.py:98: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   outputs[neuron_id] = data  # Place the neuron's output in the correct position
# 📝 Aggregated data for layer_0 and image 1 stored in Redis.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 10
#       8 # Wait for all threads to complete
#       9 for thread in neurons + layers + coordinators:
# ---> 10     thread.join()
#
# File /usr/local/lib/python3.9/threading.py:1060, in Thread.join(self, timeout)
#    1057     raise RuntimeError("cannot join current thread")
#    1059 if timeout is None:
# -> 1060     self._wait_for_tstate_lock()
#    1061 else:
#    1062     # the behavior of a negative timeout isn't documented, but
#    1063     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1064     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /usr/local/lib/python3.9/threading.py:1080, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1077     return
#    1079 try:
# -> 1080     if lock.acquire(block, timeout):
#    1081         lock.release()
#    1082         self._stop()
#
# KeyboardInterrupt:
